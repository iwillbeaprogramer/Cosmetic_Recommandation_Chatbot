# %% [markdown]
# ## 단순 어휘 빈도에 근거한 키워드 추출
# 키워드를 특정 문헌의 내용을 요약적으로 표현하는 형태소의 집합이라고 정의할 때에 가장 먼저 시도할 수 있는 키워드 추출 방법은 형태소 빈도에 의한 방법이다.
# 즉, 특정 문헌에서 많이 나타나는 형태소가 그 문헌의 내용을 나타낼 가능성이 높다는 가정을 하는 것이다.
#
# 다음 스크립트는 문헌별 단순 어휘 빈도에 근거한 문헌별 키워드 추출을 수행한다.

# %% [markdown]
# >문헌별 단순 어휘 빈도를 문헌 정보학에서는 용어로 용어 빈도(term frequency)라 부른다.

# %% [markdown]
# 일반명사(NNG), 고유명사(NNP), 어근(XR) 형태소를 추출한 뒤 이들의 용어 빈도를 측정한 다음 상위 10개만 키워드로 추출한다.

# %% [markdown]
# ## 용어 빈도 역문헌 빈도에 근거한 키워드 추출
# 위에서 보인 용어 빈도에 근거한 키워드 추출 결과는 제법 유용하다.
# 하지만 어떤 키워드들은 해당 논문의 내용을 나타낸다고 할 수는 있지만 너무 흔하게 쓰이는 용어여서 해당 논문만의 특징적인 내용을 나타내기에는 부적합할 수도 있다.
# 즉, 용어 빈도에 근거해 추출한 키워드들 가운데에는 특정성(specificity)이 부족한 것들이 있다.
# 특정성이 높은 용어들의 특징은 상대적으로 드물게 쓰인다는 것이다.
# 다른 말로 하면, 넓게 쓰이지 않는다고 할 수 있으며, 결국 어떤 용어가 하나의 문헌에서도 많이 사용되고 그 문헌이 속한 전체 문헌 집합에 속한 다수의 다른 문헌들에서 널리 쓰였다면 이 용어는 특정성이 떨어지는 용어이다.
# 이 때 특정 용어가 사용된 문헌의 수를 문헌 빈도(DF: document frequency)라고 부르며, 이의 역에 해당하는 역문헌 빈도(IDF: inverse document frequency)도 정의할 수 있다.
# 수식으로는 다음과 같이 표현할 수 있다.

# %% [markdown]
# $$
#     \operatorname{idf}(t, D) = \log\frac{|D|}{|\{d \in D: t \in d\}|}
# $$
#
# * $|D|$: 전체 문헌 집합 $D$의 크기, 곧 전체 문헌의 수
# * $|\{d \in D: t \in d\}|$: 용어 $t$가 포함된 문헌의 수

# %% [markdown]
# 위의 수식의 의미는 주어진 용어 $t$와 전체 문헌 집합 $D$에 대한 역문헌 빈도는 전체 문헌의 수를 주어진 용어가 출현한 문헌들의 수, 즉 문헌 빈도로 나눈 값에 로그를 취한 값으로 정의한다는 것이다.
# 주어진 용어 $t$가 출현한 문서의 수가 많으면 많을수록 역문헌 빈도의 값이 작아지며, 그러한 문서의 수가 적으면 적을수록 역문헌 빈도의 값이 커진다.
# 즉, 특정성이 커진다.
# 나누기 연산을 통해 얻어진 값에 로그를 취하여 스케일링을 하면 값이 평탄화가 이루어진다.
# 한편, 어떤 용어의 문헌 빈도가 0일 경우에 대해서도 역문헌 빈도를 정의해야 할 수 있기 때문에 실제로는 다음과 같이 최소 문헌 빈도를 1로 설정한 값이 많이 사용된다.

# %% [markdown]
# $$
#     \operatorname{idf}(t, D) = \log\frac{|D|}{|\{d \in D: t \in d\}|+1}
# $$

# %% [markdown]
# 실제 자료 처리에 있어서는 용어 빈도도 다음과 같이 평탄화하여 사용한다.

# %% [markdown]
# $$
#     \operatorname{tf}(t, d) = \log(\operatorname{tf}(t, d)+1)
# $$

# %% [markdown]
# TFIDF를 구하는 위의 과정을 앞서 용어 빈도에 근거한 키워드 추출 스크립트에 추가하여 구현한 스크립트의 소스는 다음과 같다.
# 추출한 키워드는 다수의 문헌이 포함된 문헌 집합 내에서 특정 문헌을 향한 특정성, 즉 역문헌 빈도를 이용하여 용어 빈도를 조정함으로 하여 추출된 것이다.

# %%
# 용어 빈도 역문헌 빈도에 의한 키워드 추출

import ujson
import math
from collections import Counter

FEATURE_POSES = ["NNG", "NNP", "NR", "NP", "XR", "MAG", "VA", "VV"]
MA_KEYS = ["question_ma", "answer_ma"]
TOP_N = 20


def read_documents(input_file):
    """형태소 분석 문서 집합을 읽어서 돌려준다."""
    
    print_log("Reading input file.")
    documents = []

    for line in input_file:
        json_obj = ujson.loads(line)

        if not check_ma_keys(json_obj):
            continue

        morphs = []

        for ma_key in MA_KEYS:
            for morph_lex, morph_cat in json_obj[ma_key]:
                if morph_cat not in FEATURE_POSES:
                    continue
                    
                morphs.append(morph_lex)
        #print("문답[{}] 키워드 추출대상 단어[{}]".format(json_obj["no"], morphs))
        document = {
            "no": json_obj["no"],
            "question": json_obj["question"],
            "answer": json_obj["refine_answer"], 
            "morphs": morphs
        }
        documents.append(document)

    return documents


def check_ma_keys(json_obj):
    """JSON 객체에 형태소 분석 키가 존재하는지 검사한다."""
    
    for ma_key in MA_KEYS:
        if ma_key not in json_obj or not json_obj[ma_key]:
            return False
        
    return True


def get_term_freq_counters(documents):
    """문서 집합으로부터 문서별 용어 빈도 계수 결과를 생성한다."""
    
    print_log("Getting term frequency counters.")
    term_freq_counters = []

    for document in documents:
        term_freq_counter = Counter(document["morphs"])
        term_freq_counters.append(term_freq_counter)

    return term_freq_counters


def extract_tf_keywords(term_freq_counters):
    """용어 빈도에 의거하여 키워드를 추출한다."""
    
    print_log("Extracting TF keywords.")
    tf_keywords = []

    for term_freq_counter in term_freq_counters:
        keywords = []
        
        for term, term_freq in term_freq_counter.most_common(TOP_N):
            keywords.append(term)
            
        tf_keywords.append(keywords)

    return tf_keywords


def get_doc_freq_counter(documents):
    """주어진 문서 집합으로부터 문헌 빈도를 계수하여 돌려준다."""
    
    print_log("Getting document frequency counter.")
    doc_freq_counter = Counter()

    for document in documents:
        doc_freq_counter.update(set(document["morphs"]))

    return doc_freq_counter


def get_tfidf_counters(term_freq_counters, doc_freq_counter):
    """주어진 용어 빈도, 문헌 빈도 계수 결과에서 tfidf를 얻어서 돌려준다."""

    tfidf_counters = []
    num_docs = len(term_freq_counters)

    for term_freq_counter in term_freq_counters:
        tfidf_counter = Counter()

        for term, term_freq in term_freq_counter.items():
            tf = math.log(term_freq + 1)
            df = doc_freq_counter[term] + 1
            idf = math.log(num_docs / df)
            tfidf = tf * idf
            tfidf_counter[term] = tfidf

        tfidf_counters.append(tfidf_counter)

    return tfidf_counters


def extract_tfidf_keywords(tfidf_counters):
    """tfidf에 의거한 키워드를 추출한다."""
    
    print_log("Extracting TFIDF keywords.")
    tfidf_keywords = []

    for tfidf_counter in tfidf_counters:
        keywords = []

        for term, tfidf in tfidf_counter.most_common(20):
            keywords.append(term)

        tfidf_keywords.append(keywords)

    return tfidf_keywords


def write_keywords(output_file, documents, tf_keywords, tfidf_keywords):
    """출력 파일에 문헌별 키워드를 기록한다."""
    
    print_log("Writing keywords to output file.")

    for document, tf_keywords, tfidf_keywords in zip(documents, tf_keywords,
                                                     tfidf_keywords):
        print("질문[{}]: {}".format(document["no"],document["question"]), file=output_file)
        print("답변: {}".format(document["answer"]), file=output_file)
        print("TF키워드: {}".format(", ".join(tf_keywords)), file=output_file)
        print("TFIDF키워드: {}".format(", ".join(tfidf_keywords)),
              file=output_file)
        print("=" * 60, file=output_file)

        
def print_log(msg):
    """주어진 로그 메시지를 출력한다."""
    
    print(msg, flush=True)
    

def main():
    """tfidf에 의거하여 키워드를 추출한다."""
    
    input_file_name = "data/catechism/catechism.ma.txt"
    output_file_name = "data/catechism/catechism.kw.tfidf.txt"
    doc_no = 0
    with open(input_file_name, "r", encoding="utf-8") as input_file, \
            open(output_file_name, "w", encoding="utf-8") as output_file:
        documents = read_documents(input_file)
        term_freq_counters = get_term_freq_counters(documents)
        tf_keywords = extract_tf_keywords(term_freq_counters)
        doc_freq_counter = get_doc_freq_counter(documents)
        tfidf_counters = get_tfidf_counters(term_freq_counters, doc_freq_counter)
        tfidf_keywords = extract_tfidf_keywords(tfidf_counters)
        write_keywords(output_file, documents, tf_keywords, tfidf_keywords)

    for document, tf_keywords, tfidf_keywords in zip(documents, tf_keywords, tfidf_keywords):
        print("질문[{}]   : {}".format(document["no"],document["question"]))
        print("답변[{}]   : {}".format(document["no"],document["answer"]))
        print("TF키워드   : {}".format(", ".join(tf_keywords)))
        print("TFIDF키워드: {}".format(", ".join(tfidf_keywords)))
        print("*"*100)
        
#        
# 실행
#
main()
# Out:
# Reading input file.
# Getting term frequency counters.
# Extracting TF keywords.
# Getting document frequency counter.
# Extracting TFIDF keywords.
# Writing keywords to output file.
# 질문[1]   : 사람의 제일 되는 목적이 무엇인가?
# 답변[1]   : 사람의 제일 되는 목적은 하나님을 영화롭게 하는 것과 영원토록 그를 즐거워하는 것이다.
# TF키워드   : 사람, 제일, 되, 목적, 무엇, 하나님, 영화, 하, 영원, 그, 즐거워하
# TFIDF키워드: 목적, 제일, 즐거워하, 되, 영화, 영원, 사람, 그, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[2]   : 하나님께서 무슨 규칙을 우리에게 주시어 어떻게 자기를 영화롭게 하고 즐거워할 것을 지시하셨는가?
# 답변[2]   : 신구약 성경에 기재된 하나님의 말씀은 어떻게 우리가 그를 영화롭게 하고 즐거워할 것을 지시하는 유일한 규칙이다.
# TF키워드   : 하나님, 규칙, 우리, 어떻, 영화, 하, 즐거워하, 지시, 자기, 신구약, 성경, 기재, 말씀, 그, 유일한
# TFIDF키워드: 규칙, 지시, 즐거워하, 영화, 신구약, 기재, 성경, 유일한, 어떻, 자기, 말씀, 그, 우리, 하, 하나님
# ****************************************************************************************************
# 질문[3]   : 성경이 제일 요긴하게 교훈하는 것이 무엇인가?
# 답변[3]   : 성경이 제일 요긴하게 교훈하는 것은 사람이 하나님에 대하여 어떻게 믿을 것과 하나님께서 사람에게 요구하시는 본분이다.
# TF키워드   : 성경, 제일, 요긴, 교훈, 사람, 하나님, 무엇, 대하, 어떻, 믿, 요구, 본분
# TFIDF키워드: 요긴, 성경, 제일, 교훈, 본분, 요구, 대하, 믿, 사람, 어떻, 하나님, 무엇
# ****************************************************************************************************
# 질문[4]   : 하나님은 어떤 분이신가?
# 답변[4]   : 하나님은 신이신데 그의 존재하심과 지혜와 권능과 거룩하심과 공의와 인자하심과 진실하심이 무한하시며, 무궁하시며, 불변하시다.
# TF키워드   : 하나님, 이신, 그, 존재, 지혜, 권능, 거룩, 공의, 인자, 진실, 무한, 무궁, 불변
# TFIDF키워드: 존재, 인자, 무한, 무궁, 불변, 지혜, 이신, 공의, 진실, 권능, 거룩, 그, 하나님
# ****************************************************************************************************
# 질문[5]   : 하나님 한분밖에 또 다른 하나님이 계신가?
# 답변[5]   : 한분뿐이시니 참되시며 살아 계신 하나님이시다.
# TF키워드   : 하나님, 참되, 살, 계시
# TFIDF키워드: 참되, 살, 계시, 하나님
# ****************************************************************************************************
# 질문[6]   : 하나님의 신격에 몇 위가 계신가?
# 답변[6]   : 하나님의 신격에 삼위가 계시니 성부와 성자와 성령이신데 이 삼위는 한 하나님이시다. 본체는 하나요 권능과 영광은 동등이시다.
# TF키워드   : 하나님, 신격, 삼위, 위, 계시, 성부, 성자, 성령, 이신
# TFIDF키워드: 신격, 삼위, 성부, 성자, 위, 이신, 계시, 성령, 하나님
# ****************************************************************************************************
# 질문[7]   : 하나님의 예정이 무엇인가?
# 답변[7]   : 하나님의 예정은 그 뜻대로 하신 영원한 경륜이신데, 이로 말미암아 자기의 영광을 위하여 모든 되어가는 일을 미리 작정하신 것이다.
# TF키워드   : 하나님, 예정, 무엇, 뜻대로, 하, 영원, 경륜, 이신, 이, 말미암, 자기, 영광, 위하, 되, 일, 미리, 작정
# TFIDF키워드: 예정, 경륜, 미리, 뜻대로, 작정, 이신, 영원, 영광, 말미암, 위하, 자기, 일, 이, 되, 하나님, 하, 무엇
# ****************************************************************************************************
# 질문[8]   : 하나님께서 그 예정을 어떻게 이루시는가?
# 답변[8]   : 하나님께서 그 예정을 이루시는 것은 창조와 섭리하시는 일로 하신다.
# TF키워드   : 하나님, 예정, 이루, 어떻, 창조, 섭리, 일, 하
# TFIDF키워드: 예정, 이루, 섭리, 창조, 일, 어떻, 하나님, 하
# ****************************************************************************************************
# 질문[9]   : 창조하신 일이 무엇인가?
# 답변[9]   : 창조하신 일은 하나님께서 엿새 동안에 아무 것도 없는 중에서 그 권능의 말씀으로써  만물을 지으신 일인데 다 매우 좋았다.
# TF키워드   : 창조, 일, 무엇, 하나님, 엿새, 동안, 없, 권능, 말씀, 만물, 다, 매우, 좋
# TFIDF키워드: 창조, 매우, 엿새, 만물, 좋, 동안, 권능, 다, 없, 일, 말씀, 하나님, 무엇
# ****************************************************************************************************
# 질문[10]   : 하나님께서 사람을 어떻게 지으셨는가?
# 답변[10]   : 하나님께서 사람을 남녀로 지으시되 자기의 형상대로 지식과 공의와 거룩함이 있게   지으사 모든 생물을 주관하게 하셨다.
# TF키워드   : 하나님, 사람, 어떻, 남녀, 자기, 형상, 지식, 공의, 거룩, 있, 지, 으, 사, 생물, 주관, 하
# TFIDF키워드: 남녀, 지식, 생물, 주관, 형상, 지, 으, 공의, 사람, 사, 자기, 거룩, 어떻, 있, 하나님, 하
# ****************************************************************************************************
# 질문[11]   : 하나님의 섭리하시는 일이 무엇인가?
# 답변[11]   : 하나님의 섭리하시는 일은 지극히 거룩함과 지혜와 권능으로써 모든 창조물과 그 모 든 행동을 보존하시며 치리하시는 일이다.
# TF키워드   : 하나님, 섭리, 일, 무엇, 지극히, 거룩, 지혜, 권능, 창조물, 들, 행동, 보존, 치
# TFIDF키워드: 섭리, 지극히, 창조물, 지혜, 권능, 들, 보존, 행동, 치, 일, 거룩, 하나님, 무엇
# ****************************************************************************************************
# 질문[12]   : 사람이 창조함을 받은 본 지위에 있을 때에 하나님께서 저를 향하여 섭리하시는 중 에 무슨 특별한 작정을 하셨는가?
# 답변[12]   : 하나님께서 사람을 창조하신 후에 완전히 순복하는 것을 조건으로 삼아 생명의 언약을 맺고 선악을 분별하는 나무의 실과를 먹는 것은 사망의 벌로써 금하셨다.
# TF키워드   : 사람, 창조, 하나님, 받, 보, 지위, 있, 때, 저, 향하, 섭리, 특별, 작정, 하, 후, 완전히, 순, 복, 조건, 삼
# TFIDF키워드: 창조, 향하, 특별, 순, 조건, 맺, 선악, 나무, 작정, 분별, 실과, 사망, 벌, 저, 섭리, 후, 먹, 보, 완전히, 복
# ****************************************************************************************************
# 질문[13]   : 우리 시조가 창조함을 받은 본 지위에 그대로 있었는가?
# 답변[13]   : 우리 시조가 임의대로 자유함을 인하여 하나님께 죄를 범하므로 창조함을 받은 본 지위에서 타락하였다.
# TF키워드   : 우리, 시조, 창조, 받, 보, 지위, 그대로, 임의, 자유, 인하, 하나님, 죄, 범하, 타락
# TFIDF키워드: 시조, 보, 창조, 임의, 자유, 그대로, 지위, 인하, 범하, 받, 타락, 죄, 우리, 하나님
# ****************************************************************************************************
# 질문[14]   : 죄가 무엇인가?
# 답변[14]   : 죄는 하나님의 법을 순종함에 부족한 것이나 혹 어기는 것이다.
# TF키워드   : 죄, 무엇, 하나님, 법, 순종, 부족, 혹, 어기
# TFIDF키워드: 부족, 어기, 순종, 혹, 법, 죄, 하나님, 무엇
# ****************************************************************************************************
# 질문[15]   : 우리 시조가 창조함을 받은 본 지위에서 타락하게 된 죄가 무엇인가?
# 답변[15]   : 우리 시조가 창조함을 받은 본 지위에서 타락하게 된 죄는 그 금하신 실과를 먹은 것 이다.
# TF키워드   : 우리, 시조, 창조, 받, 보, 지위, 타락, 되, 죄, 무엇, 금하, 실과, 먹
# TFIDF키워드: 시조, 보, 창조, 타락, 실과, 지위, 먹, 되, 받, 죄, 금하, 우리, 무엇
# ****************************************************************************************************
# 질문[16]   : 모든 인종은 아담의 첫 범죄 중에 타락하였는가?
# 답변[16]   : 아담으로 더불어 언약을 세운 것은 저만 위하여 하신 것이 아니요, 그 후 자손까지 위하여 하신 것이므로 그로부터 보통 생육법으로 출생하는 인종은 모두 그의 안에 있어서 그의 첫 범죄에 참여하여 그와 함께 타락하였다.
# TF키워드   : 그, 인종, 아담, 범죄, 타락, 위하, 하, 더불, 언약, 세우, 저, 그 후, 자손, 보통, 생육, 법, 출생, 모두, 안, 있
# TFIDF키워드: 아담, 범죄, 인종, 타락, 자손, 생육, 출생, 모두, 위하, 그, 그 후, 더불, 세우, 저, 참여, 함께, 언약, 보통, 안, 법
# ****************************************************************************************************
# 질문[17]   : 이 타락이 인종으로 하여금 어떠한 지위에 이르게 하였는가?
# 답변[17]   : 이 타락은 인종으로 하여금 죄와 비참한 처지에 이르게 하였다.
# TF키워드   : 타락, 인종, 하여금, 이르, 하, 어떠, 지위, 죄, 비참, 처지
# TFIDF키워드: 인종, 타락, 하여금, 이르, 처지, 어떠, 비참, 지위, 죄, 하
# ****************************************************************************************************
# 질문[18]   : 사람이 타락한 지위에서 죄되는 것이 무엇인가?
# 답변[18]   : 사람이 타락한 지위에서 죄되는 것은 아담의 첫 범죄에 유죄한 것과 근본 의가 없는 것과 온 성품이 부패한 것인데 이것은 보통으로 원죄라 하는 것이요, 아울러 원죄로 말미암아 나오는 모든 죄다.
# TF키워드   : 죄, 사람, 타락, 지위, 원죄, 무엇, 아담, 범죄, 유죄, 근본, 의, 없, 오, 성품, 부패, 이것, 보통, 하, 아울러, 말미암
# TFIDF키워드: 원죄, 타락, 유죄, 근본, 부패, 이것, 아담, 범죄, 아울러, 지위, 성품, 죄, 의, 보통, 나오, 사람, 오, 말미암, 없, 하
# ****************************************************************************************************
# 질문[19]   : 사람이 타락한 지위에서 비참한 것이 무엇인가?
# 답변[19]   : 모든 인종이 타락함을 인하여 하나님과 교제가 끊어지고 또 그의 진노와 저주 아래 있어서 생전에 모든 비참함과 사망과 영원한 지옥의 벌을 받게 되었다.
# TF키워드   : 타락, 비참, 사람, 지위, 무엇, 인종, 인하, 하나님, 교제, 끊어지, 그, 진노, 저주, 아래, 있, 생전, 사망, 영원, 지옥, 벌
# TFIDF키워드: 비참, 타락, 교제, 끊어지, 생전, 지옥, 사망, 벌, 아래, 인종, 진노, 저주, 인하, 영원, 지위, 되, 받, 사람, 그, 있
# ****************************************************************************************************
# 질문[20]   : 하나님께서 모든 인종을 죄와 비참한 지위에서 멸망하게 버려두셨는가?
# 답변[20]   : 하나님께서 홀로 그 선하신 뜻대로 영원부터 구속받을 자들을 영생 얻게 하시려고 선 택하시고 은혜의 언약을 세우셔서 구속자로 말미암아 저희를 죄와 비참한 지위에서 건   져 내시고 구원의 자리에 이르게 하려 하셨다.
# TF키워드   : 하, 하나님, 죄, 비참, 지위, 인종, 멸망, 버려두, 홀로, 선, 뜻대로, 영원, 구속, 받, 영생, 얻, 서, 택하, 은혜, 언약
# TFIDF키워드: 비참, 버려두, 선, 영생, 택하, 자리, 멸망, 홀로, 뜻대로, 서, 저희, 지위, 세우, 인종, 구속, 언약, 구속자, 영원, 죄, 말미암
# ****************************************************************************************************
# 질문[21]   : 하나님의 선택하신 자의 구속자가 누구신가?
# 답변[21]   : 하나님의 선택하신 자의 구속자는 다만 주 예수 그리스도뿐이신데, 그는 하나님의 영원한 아들로서 사람이 되셨으니 그후로 한 위에 특수한 두 가지 성품이 있어 영원토록   하나님이시오 사람이시다.
# TF키워드   : 하나님, 선택, 구속자, 영원, 사람, 누구, 신가, 예수, 그리스도, 그, 아들, 되, 후, 위, 특수, 성품, 있
# TFIDF키워드: 선택, 구속자, 영원, 누구, 신가, 특수, 아들, 후, 위, 성품, 예수, 사람, 되, 그, 있, 그리스도, 하나님
# ****************************************************************************************************
# 질문[22]   : 그리스도께서 하나님의 아들로서 어떻게 사람이 되셨는가?
# 답변[22]   : 하나님의 아들 그리스도께서 사람이 되신 것은 참 몸과 지각있는 영혼을 취하사 성령 의 권능으로 동정녀 마리아에게 잉태되어 탄생하셨으나 죄는 없으시다.
# TF키워드   : 그리스도, 하나님, 아들, 사람, 되, 어떻, 참, 몸, 지각, 있, 영혼, 취하, 성령, 의, 권능, 동정녀, 마리아, 잉태, 탄생, 죄
# TFIDF키워드: 아들, 지각, 취하, 동정녀, 마리아, 잉태, 탄생, 영혼, 참, 몸, 의, 권능, 되, 사람, 성령, 없, 그리스도, 어떻, 있, 죄
# ****************************************************************************************************
# 질문[23]   : 그리스도께서 우리의 구속자로 무슨 직분을 행하시는가?
# 답변[23]   : 그리스도께서 우리의 구속자로 선지자와 제사장과 왕의 직분을 행하시되 낮아지시고 높아지신 두 지위에서 하신다.
# TF키워드   : 그리스도, 우리, 구속자, 직분, 행하, 선지자, 제사장, 왕, 낮, 높, 지위, 하
# TFIDF키워드: 구속자, 직분, 제사장, 행하, 선지자, 낮, 높, 왕, 지위, 그리스도, 우리, 하
# ****************************************************************************************************
# 질문[24]   : 그리스도께서 어떻게 선지자의 직분을 행하시는가?
# 답변[24]   : 그리스도께서 선지자의 직분을 행하시는 것은 우리를 구원하시고자 하시는 하나님의 뜻을 그 말씀과 성령으로 말미암아 우리에게 나타내시는 것이다.
# TF키워드   : 그리스도, 선지자, 직분, 행하, 우리, 어떻, 구원, 하, 하나님, 뜻, 말씀, 성령, 말미암, 나타내
# TFIDF키워드: 선지자, 직분, 행하, 뜻, 성령, 말미암, 구원, 나타내, 그리스도, 말씀, 어떻, 우리, 하, 하나님
# ****************************************************************************************************
# 질문[25]   : 그리스도께서 어떻게 제사장의 직분을 행하시는가?
# 답변[25]   : 그리스도께서 제사장의 직분을 행하시는 것은 단번에 자기를 제물로 드려 하나님의  공의에 만족하게 하며 우리를 하나님으로 더불어 화목하게 하시고 또 우리를 위하여    항상 간구하시는 것이다.
# TF키워드   : 그리스도, 사장, 직분, 행하, 하나님, 하, 우리, 어떻, 단번에, 자기, 제물, 드리, 공의, 만족, 더불, 화목, 위하, 항상, 간구
# TFIDF키워드: 사장, 직분, 단번에, 제물, 화목, 행하, 드리, 만족, 항상, 공의, 더불, 간구, 위하, 그리스도, 자기, 어떻, 우리, 하, 하나님
# ****************************************************************************************************
# 질문[26]   : 그리스도께서 어떻게 왕의 직분을 행하시는가?
# 답변[26]   : 그리스도께서 왕의 직분을 행하시는 것은 우리로 하여금 자기에게 복종하게 하시고  리를 다스리시며 보호하시고 자기와 우리의 모든 원수를 막아 이기시는 것이다.
# TF키워드   : 그리스도, 왕, 직분, 행하, 우리, 자기, 어떻, 하여금, 복종, 하, 다스리, 보호, 원수, 막, 이기
# TFIDF키워드: 왕, 직분, 다스리, 원수, 이기, 행하, 막, 자기, 보호, 복종, 하여금, 그리스도, 어떻, 우리, 하
# ****************************************************************************************************
# 질문[27]   : 그리스도의 낮아지심이 어떠한가?
# 답변[27]   : 그리스도의 낮아지심은 곧 그의 강생하심인데 또한 비천한 지위에 나셔서 율법 아래 복종하시고 금생에 여러 가지 비참함과 하나님의 진노하심과 십자가에서 저주의 죽음    을 받으시고 묻히셔서 얼마 동안 죽음의 권세 아래 거하신 것이다.
# TF키워드   : 그리스도, 낮, 하심, 아래, 죽음, 어떠, 곧, 그, 강생, 비천, 지위, 나, 율법, 복종, 금, 비참, 하나님, 진노, 십자가, 저주
# TFIDF키워드: 죽음, 낮, 아래, 하심, 강생, 비천, 율법, 십자가, 묻히, 얼마, 거하, 을, 권세, 동안, 금, 진노, 저주, 어떠, 나, 복종
# ****************************************************************************************************
# 질문[28]   : 그리스도의 높아지심이 어떠한가?
# 답변[28]   : 그리스도의 높아지심은 사흘 만에 죽은 가운데서 다시 살아나신 것과 하늘로 올라가 신 것과 하나님 아버지의 우편에 앉아 계신 것과 마지막 날에 세상을 심판하러 오시는   것이다.
# TF키워드   : 그리스도, 높, 어떠, 사흘, 죽, 가운데, 다시, 살아나, 하늘, 올라가, 신, 하나님, 아버지, 우편, 앉, 계시, 마지막, 날, 세상, 심판
# TFIDF키워드: 높, 사흘, 가운데, 살아나, 올라가, 우편, 앉, 오시, 다시, 마지막, 아버지, 심판, 죽, 하늘, 신, 계시, 어떠, 세상, 날, 그리스도
# ****************************************************************************************************
# 질문[29]   : 우리로 어떻게 그리스도의 사신 구속에 참여하게 하시는가?
# 답변[29]   : 우리로 그리스도의 사신 구속에 참여하게 하시는 것은 그의 성령께서 우리에게 구속 을 효력있게 적용하심을 인함이다.
# TF키워드   : 우리, 구속, 그리스도, 사신, 참여, 하, 어떻, 그, 성령, 을, 효력, 있, 적용, 인하
# TFIDF키워드: 구속, 사신, 참여, 을, 적용, 인하, 효력, 성령, 그리스도, 어떻, 우리, 그, 있, 하
# ****************************************************************************************************
# 질문[30]   : 성령께서 그리스도의 사신 구속을 우리에게 어떻게 적용하셨는가?
# 답변[30]   : 성령께서 그리스도의 사신 구속을 우리에게 적용하시는 것은 우리 안에 믿음을 일으 키시고 또 효력있는 부르심으로써 우리를 그리스도와 연합하게 하시는 것이다.
# TF키워드   : 우리, 그리스도, 성령, 사신, 구속, 적용, 어떻, 안, 믿음, 일, 으, 키시, 효력, 있, 부르, 연합, 하
# TFIDF키워드: 사신, 적용, 구속, 키시, 성령, 으, 연합, 부르, 안, 믿음, 그리스도, 효력, 우리, 일, 어떻, 있, 하
# ****************************************************************************************************
# 질문[31]   : 효력있는 부름심이 무엇인가?
# 답변[31]   : 효력 있는 부르심은 하나님의 신이 하시는 일이니 우리의 죄와 비참을 깨닫게 하시고 또 우리의 마음을 밝혀 그리스도를 알게 하시고 우리의 의지를 새롭게 하시고 우리를    권하사 능히 복음 중에 값 없이 주시는 예수 그리스도를 믿도록 하시는 것이다.
# TF키워드   : 하, 우리, 효력, 있, 그리스도, 부름, 심, 무엇, 부르, 하나님, 신이, 죄, 비참, 깨닫, 마음, 밝히, 알, 의지, 새롭, 하사
# TFIDF키워드: 효력, 부름, 심, 하사, 밝히, 의지, 새롭, 복음, 없이, 주시, 부르, 신이, 깨닫, 예수, 비참, 값, 알, 능히, 믿, 있
# ****************************************************************************************************
# 질문[32]   : 효력 있는 부르심을 받은 자들은금생에서 무슨 유익을 얻는가?
# 답변[32]   : 효력 있는 부르심을 받은 자들은 금생에서 의롭다 하심과 양자로 삼는 것과 거룩하게 하심을 얻고 또 금생에서 이와 함께 받는 여러 가지 유익과 여기서 나오는 여러 가지 유익을 받는다.
# TF키워드   : 받, 금, 유익, 효력, 있, 부르, 얻, 하심, 의롭, 양자, 삼, 거룩, 이, 함께, 여기, 나오
# TFIDF키워드: 금, 부르, 유익, 하심, 받, 효력, 얻, 양자, 함께, 나오, 의롭, 있, 여기, 삼, 거룩, 이
# ****************************************************************************************************
# 질문[33]   : 의롭다 하심은 무엇인가?
# 답변[33]   : 의롭다 하심은 하나님의 값 없는 은혜로 정하신 것인데 저가 우리의 모든 죄를 사유 하시고 그 앞에서 우리를 옳게 여겨 받으시는 것이니 이는 다만 그리스도의 의를 우 리에게 돌려 주심인데 우리는 오직 믿음만으로 받는 것이다.
# TF키워드   : 하, 우리, 의롭, 받, 무엇, 하나님, 값, 없, 은혜, 정하, 저, 죄, 사유, 앞, 옳, 여기, 이, 그리스도, 의, 우
# TFIDF키워드: 의롭, 사유, 옳, 우, 주심, 오직, 돌리, 저, 앞, 의, 값, 정하, 받, 믿음, 여기, 없, 은혜, 이, 우리, 죄
# ****************************************************************************************************
# 질문[34]   : 양자로 삼는 것이 무엇인가?
# 답변[34]   : 양자로 삼는 것은 하나님의 값 없는 은혜로 정하신 것인데 이로써 우리를 하나님의 자녀의 수효중에 들게 하시고 그 모든 특권을 누리게 하시는 것이다.
# TF키워드   : 양자, 삼, 하나님, 하, 무엇, 값, 없, 은혜, 정하, 이, 우리, 자녀, 수효, 들, 특권, 누리
# TFIDF키워드: 양자, 수효, 특권, 누리, 삼, 자녀, 들, 값, 정하, 없, 은혜, 이, 하, 우리, 하나님, 무엇
# ****************************************************************************************************
# 질문[35]   : 거룩하게 하신 것이 무엇인가?
# 답변[35]   : 거룩하게 하신 것은 하나님의 값 없는 은혜의 역사이신데 이로써 우리가 하나님의형 상을 좇아 온 사람이 새로워짐을 얻고 점점 죄에 대하여서는 능히 죽고, 의에 대하여  서는 능히 살게 되는 것이다.
# TF키워드   : 거룩, 하, 하나님, 대하, 능히, 무엇, 값, 없, 은혜, 역사, 이, 우리, 의형, 상, 좇, 오, 사람, 새롭, 얻, 점점
# TFIDF키워드: 대하, 능히, 의형, 상, 좇, 점점, 역사, 새롭, 서, 살, 거룩, 죽, 의, 값, 오, 없, 얻, 은혜, 이, 되
# ****************************************************************************************************
# 질문[36]   : 금생에서 의롭다 하심과 양자로 삼으신 것과 거룩하게 하심에서 함께 받는 유익과 여기서 나오는 유익이 무엇인가?
# 답변[36]   : 금생에서 의롭다 하심과 양자로 삼으신 것과 거룩하게 하심에서 함께 받는 유익과 여기서 나오는 유익은 하나님의 사랑을 확실히 아는 것과 양심의 화평한 것과 성령 안에서 얻는 쾌락과 은혜의 증가함과 끝까지 굳게 참는 것이다.
# TF키워드   : 하심, 유익, 금, 의롭, 양자, 삼, 거룩, 함께, 받, 여기, 나오, 무엇, 하나님, 사랑, 확실히, 알, 양심, 화평, 한, 성령
# TFIDF키워드: 하심, 유익, 양자, 함께, 금, 나오, 의롭, 여기, 확실히, 양심, 화평, 한, 쾌락, 증가, 굳, 삼, 끝, 거룩, 안, 참
# ****************************************************************************************************
# 질문[37]   : 신자가 죽을 때에 그리스도에게서 무슨 유익을 받는가?
# 답변[37]   : 신자가 죽을 때에 그 영혼이 완전히 거룩하게 되어 즉시 영광중에 들어가고 그 몸은 여전히 그리스도께 연합하여 부활활때까지 무덤에서 쉰다.
# TF키워드   : 때, 신자, 죽, 그리스도, 유익, 받, 영혼, 완전히, 거룩, 되, 즉시, 영광, 들어가, 몸, 여전히, 연합, 부활, 활, 무덤, 쉬
# TFIDF키워드: 때, 신자, 죽, 즉시, 여전히, 활, 무덤, 영혼, 들어가, 연합, 쉬, 부활, 완전히, 몸, 유익, 영광, 그리스도, 거룩, 되, 받
# ****************************************************************************************************
# 질문[38]   : 신자가 부활할 때에는 그리스도에게서 무슨 유익을 받는가?
# 답변[38]   : 신자가 부활할 때에는 영광 중에 다시 살아남을 입어 심판날에 밝히 안다 하심과 죄 없다 하심을 받고 완전히 복을 받아 영원토록 하나님을 흡족하게 즐거워하는 것이다.
# TF키워드   : 받, 신자, 부활, 때, 하심, 그리스도, 유익, 영광, 다시, 살아남, 입, 심판, 날, 밝히, 안다, 죄, 없, 완전히, 복, 영원
# TFIDF키워드: 부활, 신자, 하심, 때, 살아남, 입, 안다, 흡족, 다시, 밝히, 받, 심판, 즐거워하, 완전히, 복, 영원, 유익, 영광, 날, 없
# ****************************************************************************************************
# 질문[39]   : 하나님께서 사람에게 요구하시는 본분이 무엇인가?
# 답변[39]   : 하나님께서 사람에게 요구하시는 본분은 그 나타내 보이신 뜻을 복종하는 것이다.
# TF키워드   : 하나님, 사람, 요구, 본분, 무엇, 나타내, 보이, 뜻, 복종
# TFIDF키워드: 본분, 요구, 보이, 복종, 뜻, 사람, 나타내, 하나님, 무엇
# ****************************************************************************************************
# 질문[40]   : 하나님께서 자기에게 복종할 규칙으로 사람에게 처음 나타내 보이신 것이 무엇인가?
# 답변[40]   : 하나님께서 자기에게 복종할 규칙으로 사람에게 처음 나타내 보이신 것은 도덕의 법칙이다.
# TF키워드   : 하나님, 자기, 복종, 규칙, 사람, 처음, 나타내, 보이, 무엇, 도덕, 법칙
# TFIDF키워드: 처음, 규칙, 보이, 복종, 나타내, 도덕, 자기, 법칙, 사람, 하나님, 무엇
# ****************************************************************************************************
# 질문[41]   : 이 도덕의 법칙이 어디에 간략히 포함되었는가?
# 답변[41]   : 이 도덕의 법칙은 십계명에 간략히 포함되었다.
# TF키워드   : 도덕, 법칙, 간략히, 포함, 어디, 십계명
# TFIDF키워드: 간략히, 포함, 도덕, 법칙, 어디, 십계명
# ****************************************************************************************************
# 질문[42]   : 십계명의 대강령이 무엇인가?
# 답변[42]   : 십계명의 대강령은 우리의 마음을 다하고 성품을 다하고 뜻을 다하고 힘을 다하여 주 우리 하나님을 사랑하고 또 이웃 사랑하기를 자기 몸과 같이 하라 하신 것이다.
# TF키워드   : 다, 십계명, 강령, 우리, 사랑, 하, 무엇, 마음, 성품, 뜻, 힘, 하나님, 이웃, 자기, 몸, 같이
# TFIDF키워드: 다, 강령, 십계명, 사랑, 힘, 성품, 같이, 몸, 뜻, 마음, 이웃, 자기, 우리, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[43]   : 십계명의 서문이 무엇인가?
# 답변[43]   : 십계명의 서문은 이러한 말이니 곧 나는 너희 하나님이시니 너를 종되었던 애굽 땅에서 나오게 한 자로다 하신 것이다.
# TF키워드   : 십계명, 서문, 무엇, 이러, 말, 곧, 나, 너희, 하나님, 이, 시니, 너, 종, 애, 굽, 땅, 나오, 자로, 하
# TFIDF키워드: 서문, 십계명, 이러, 시니, 종, 애, 굽, 자로, 너, 너희, 땅, 나오, 나, 말, 곧, 이, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[44]   : 십계명의 서문이 우리에게 교훈하는 것이 무엇인가?
# 답변[44]   : 십계명의 서문이 우리에게 교훈하는 것은 하나님께서 주도되시고, 우리 하나님도 되시고 또 우리의 구속자도 되시는 고로 우리가 마땅히 그의 계명을 지켜야 하겠다 하는 것이다.
# TF키워드   : 우리, 십계명, 서문, 교훈, 하나님, 되, 하, 무엇, 주도, 구속자, 고로, 마땅히, 그, 계명, 지키
# TFIDF키워드: 서문, 십계명, 교훈, 주도, 고로, 구속자, 되, 마땅히, 지키, 우리, 그, 계명, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[45]   : 제일 계명이 무엇인가?
# 답변[45]   : 제일 계명은 나 외에 다른 신을 위하지 말라 하신 것이다.
# TF키워드   : 제일, 계명, 무엇, 나, 신, 위하, 말라, 하
# TFIDF키워드: 제일, 신, 나, 말라, 위하, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[46]   : 제일 계명이 명하는 것은 무엇인가?
# 답변[46]   : 제일 계명이 우리에게 명하는 것은 하나님은 유일한 참 신이되심과 우리의 하나님이 되심을 알고 승인하여 그대로 긍게 경배하며 영화롭게 하라 하는 것이다.
# TF키워드   : 제일, 계명, 우리, 하나님, 하, 무엇, 유일한, 참, 신이, 되, 알, 승인, 그대로, 경배, 영화
# TFIDF키워드: 제일, 승인, 유일한, 그대로, 신이, 참, 경배, 영화, 알, 되, 계명, 우리, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[47]   : 제일 계명이 금하는 것은 무엇인가?
# 답변[47]   : 제 일 계명이 금하는 것은 참 신을 하나님으로 알지 아니하거나 우리의 하나님으로 경배하지 않고 영화롭게도 하지 아니하는 것과 그에게만 드리기에 합당한 경배와 영화를 다른 이에게 드리는 것이다.
# TF키워드   : 계명, 금하, 하나님, 경배, 영화, 드리, 제일, 무엇, 참, 신, 알, 우리, 하, 그, 합당, 이
# TFIDF키워드: 드리, 경배, 영화, 금하, 참, 신, 합당, 제일, 알, 이, 그, 계명, 우리, 하나님, 하, 무엇
# ****************************************************************************************************
# 질문[48]   : 제 일 계명중에 「나 외에」라 한 말씀이 우리에게 특별히 교훈하는 것이 무엇인가?
# 답변[48]   : 제 일 계명중에 나 외에라 한 말씀이 우리에게 특별히 교훈하는 것은 만물을 보시는 하나님이 아무 다른 신을 위하는 죄를 내려다 보시고 분하게 여기시는 것이다.
# TF키워드   : 계명, 나, 말씀, 우리, 특별히, 교훈, 보, 라, 무엇, 만물, 하나님, 신, 위하, 죄, 내리, 분하, 여기
# TFIDF키워드: 보, 나, 특별히, 교훈, 라, 내리, 분하, 만물, 말씀, 신, 여기, 위하, 계명, 죄, 우리, 하나님, 무엇
# ****************************************************************************************************
# 질문[49]   : 제 이 계명이 무엇인가?
# 답변[49]   : 제 이 계명은 우상을 만들지 말지니 위로 하늘에 있는 것이나 아래로 땅에 있는 것이나 땅 아래 물속에 있는 것의 무슨 형상이든지 만들지 말고 절하지 말고 섬기지 말라. 나 여호와 너의 하나님은 진노하는 신이시니 나를 미워하는 자에게는 아비의 죄를 자손 삼사 대까지 이르게 하고 나를 사랑하며 내 계명을 지키는 자에게는 은혜를 수천 대까지 베풀리라 하신 것이다.
# TF키워드   : 있, 계명, 만들, 아래, 땅, 무엇, 우상, 말, 지니, 위, 하늘, 물속, 형상, 절, 섬기
# TFIDF키워드: 만들, 아래, 땅, 지니, 물속, 절, 섬기, 우상, 형상, 있, 위, 하늘, 말, 계명, 무엇
# ****************************************************************************************************
# 질문[50]   : 제 이 계명이 명하는 것이 무엇인가?
# 답변[50]   : 제 이 계명이 명하는 것은 하나님이 그 말씀 중에 정하신 종교상 모든 예배와 규례를 받아 순종하며 깨끗하고 완전하게 지키라 하는 것이다.
# TF키워드   : 계명, 무엇, 하나님, 말씀, 정하, 종교, 예배, 규례, 받, 순종, 깨끗, 완전, 지키, 하
# TFIDF키워드: 종교, 완전, 예배, 깨끗, 규례, 순종, 정하, 지키, 말씀, 받, 계명, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[51]   : 제 이 계명이 금하는 것이 무엇인가?
# 답변[51]   : 제 이 계명이 금하는 것은 우상으로 하나님을 경배하거나, 하나님의 말씀에 정하지 아니한 어떤 다른 방법으로 경배하는 것이다.
# TF키워드   : 계명, 금하, 하나님, 경배, 무엇, 우상, 말씀, 정하, 방법
# TFIDF키워드: 경배, 우상, 금하, 방법, 정하, 말씀, 계명, 하나님, 무엇
# ****************************************************************************************************
# 질문[52]   : 제 이 계명이 「지키라」한 이유가 무엇인가?
# 답변[52]   : 제 이 계명에 지키라 한 이유는 하나님이 우리의 주재가 되시며 우리의 소유자가 되시며 홀로 자기에게만 경배하는 것을 바라시는 것이다.
# TF키워드   : 계명, 지키, 이유, 우리, 되, 무엇, 하나님, 주재, 소유자, 홀로, 자기, 경배, 바라
# TFIDF키워드: 이유, 주재, 소유자, 바라, 지키, 홀로, 경배, 되, 자기, 계명, 우리, 하나님, 무엇
# ****************************************************************************************************
# 질문[53]   : 제 삼 계명이 무엇인가?
# 답변[53]   : 제 삼 계명은 너희 하나님 여호와의 이름을 망령되이 일컫지 말라 여호와의 이름을 망령되이 일컫는 자를 죄 없다 아니하리라 하신 것이다.
# TF키워드   : 삼, 계명, 여호와, 이름, 망령, 일컫, 무엇, 너희, 하나님, 말라, 죄, 없, 하
# TFIDF키워드: 망령, 일컫, 여호와, 이름, 삼, 너희, 말라, 없, 계명, 죄, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[54]   : 제 삼 계명이 명하는 것은 무엇인가?
# 답변[54]   : 제 삼 계명이 명하는 것은 하나님의 이름과 칭호와 속성과 규례와 말씀과 행사를 거룩하고 존경하는 마음으로 사용하라 하는 것이다.
# TF키워드   : 삼, 계명, 무엇, 하나님, 이름, 칭호, 속성, 규례, 말씀, 행사, 거룩, 존경, 마음, 사용, 하
# TFIDF키워드: 칭호, 속성, 행사, 존경, 삼, 규례, 사용, 이름, 마음, 말씀, 거룩, 계명, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[55]   : 제 삼 계명이 금하는 것은 무엇인가?
# 답변[55]   : 제 삼 계명이 금하는 것은 무엇이든지 하나님이 자기를 나타내신 것을 훼방하거나 악용하는 것이다.
# TF키워드   : 삼, 계명, 금하, 무엇, 하나님, 자기, 나타내, 훼방, 악용
# TFIDF키워드: 훼방, 악용, 삼, 금하, 나타내, 자기, 계명, 무엇, 하나님
# ****************************************************************************************************
# 질문[56]   : 제 삼 계명이 「지키라」한 이유가 무엇인가?
# 답변[56]   : 제 삼 계명에 지키라 한 이유는 이 계명을 범하는 자가 비록 사람에게는 형벌을 피할지라도 주 우리 하나님은 저희로 하여금 그 의로우신 심판을 피하지 못하게 하시는 것이다.
# TF키워드   : 계명, 삼, 지키, 이유, 피하, 무엇, 범하, 비록, 사람, 형벌, 우리, 하나님, 저희, 하여금, 의롭, 심판, 하
# TFIDF키워드: 피하, 이유, 비록, 형벌, 지키, 저희, 삼, 심판, 범하, 의롭, 하여금, 계명, 사람, 우리, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[57]   : 제 사 계명이 무엇인가?
# 답변[57]   : 제 사 계명은 안식일을 기억하여 거룩한 날로 지키라 엿새 동안에 네 모든 일을 힘써 하고 제 칠 일은 너희 하나님 여호와의 안식일이니 너나 네 자녀나 네 노비나 네 육축이나 네 문안에 유하는 객이라도 일하지 말라. 엿새 동안에 여호와가 하늘과 땅과 바다와 그 가운데 만물을 지으시고 제 칠 일에 쉬셨으니 그러므로 여호와가 안식일을 거룩한 날로 삼고 복을 주셨느니라 하신 것이다.
# TF키워드   : 사, 계명, 안식일, 일, 무엇, 기억, 거룩, 날로, 지키, 엿새, 동안, 힘쓰, 하, 치, 너희, 하나님, 여호와, 너, 자녀, 노비
# TFIDF키워드: 안식일, 사, 기억, 날로, 축, 문안, 유하, 객, 엿새, 여호와, 너, 노비, 동안, 힘쓰, 너희, 자녀, 일, 육, 지키, 치
# ****************************************************************************************************
# 질문[58]   : 제 사 계명이 명하는 것은 무엇인가?
# 답변[58]   : 제 사 계명이 명하는 것은 하나님의 말씀 중에 명하신 절기를 그의 앞에 거룩히 지키는 것이니 특별히 칠 일 중에 하루를 종일토록 그의 거루룩하신 안식일로 삼으라 하는 것이다.
# TF키워드   : 사, 계명, 그, 무엇, 하나님, 말씀, 명하, 절기, 앞, 지키, 특별히, 치, 하루, 종일토록, 루, 룩, 안식일, 삼, 하
# TFIDF키워드: 사, 절기, 하루, 종일토록, 루, 룩, 명하, 앞, 특별히, 안식일, 그, 지키, 치, 삼, 말씀, 계명, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[59]   : 하나님께서 칠 일 중에 어느 날을 안식일로 명하셨는가?
# 답변[59]   : 세상 시작으로부터 그리스도의 부활하시기까지는 하나님이 이레 중에 일곱째 날을 안식일로 명하셨고, 그 후로부터 세상 끝날에 이르기까지는 이레 중에 첫날로 명하셨으니 곧 그리스도인의 안식일이다.
# TF키워드   : 날, 안식일, 명하, 하나님, 세상, 이레, 치, 시작, 그리스도, 부활, 일곱째, 그 후, 끝, 이르, 첫날, 곧, 그리스도인
# TFIDF키워드: 명하, 이레, 안식일, 날, 세상, 시작, 일곱째, 첫날, 그리스도인, 그 후, 부활, 끝, 이르, 치, 곧, 그리스도, 하나님
# ****************************************************************************************************
# 질문[60]   : 어떻게 하여야 안식일을 거룩하게 하겠는가?
# 답변[60]   : 안식일을 거룩하게 하는 것은 그날 종일을 거룩하게 쉼으로할 것이니 다른 날에 합당한 여러 가지 세상 일과 오락까지 그치고 그 시간을 공사간의 예배에 바쳐 사용할 것이요, 그 외에는 사세 부득이한 일과 자선 사업에 사용할 수 있다.
# TF키워드   : 하, 거룩, 안식일, 일, 사용, 어떻, 그날, 종일, 쉬, 날, 합당, 세상, 오락, 그치, 시간, 공사, 간의, 예배, 바치, 사세
# TFIDF키워드: 사용, 안식일, 그날, 종일, 그치, 시간, 공사, 간의, 바치, 사세, 부득이, 자선, 사업, 거룩, 쉬, 오락, 예배, 일, 합당, 세상
# ****************************************************************************************************
# 질문[61]   : 제 사 계명이 금하는 것은 무엇인가?
# 답변[61]   : 제 사 계명이 금하는 것은 그 명한 바 의무를 이행하지 아니하거나 혹 주의하지 아니하여 나태함으로써 그 날을 더럽게 하거나 죄되는 일을 행하거나 세상의 여러 가지 일과 오락에 대하여 불필요한 생각과 말과 행동을 하는 것이다.
# TF키워드   : 사, 계명, 금하, 하, 일, 무엇, 의무, 이행, 혹, 주의, 나태, 날, 더럽, 죄, 행하, 세상, 오락, 대하, 불필요, 생각
# TFIDF키워드: 사, 의무, 이행, 나태, 더럽, 불필요, 오락, 금하, 주의, 일, 혹, 생각, 세상, 대하, 말, 행동, 날, 행하, 계명, 죄
# ****************************************************************************************************
# 질문[62]   : 제 사 계명이 「지키라」한 이유가 무엇인가?
# 답변[62]   : 제 사 계명에 지키라 한 이유는 하나님이 우리의 행할 여러가지 일을 위하여 여섯 날을 허락하시고 제 칠 일은 자기가 특별히 주장하는 이가 되었다 하심과 자기가 친히 모범을 보이신 것과 안식일을 축복하신 것이다.
# TF키워드   : 사, 계명, 지키, 이유, 자기, 무엇, 하나님, 우리, 행하, 일, 위하, 여섯, 날, 허락, 치, 특별히, 주장, 이, 되, 하심
# TFIDF키워드: 이유, 사, 여섯, 주장, 친히, 모범, 지키, 허락, 자기, 보이, 축복, 특별히, 하심, 안식일, 날, 행하, 위하, 치, 일, 이
# ****************************************************************************************************
# 질문[63]   : 제 오 계명이 무엇인가?
# 답변[63]   : 제 오 계명은 네 부모를 공경하라. 그리하면 너희 하나님이 준 땅에서 네가 오래 살리라 하신 것이다.
# TF키워드   : 오, 계명, 무엇, 부모, 공경
# TFIDF키워드: 부모, 오, 공경, 계명, 무엇
# ****************************************************************************************************
# 질문[64]   : 제 오 계명이 명하는 것은 무엇인가?
# 답변[64]   : 제 오 계명이 명하는 것은 각 사람에게 그 속한 지위와 인륜관계 곧 상하와 평등을 따라 높일 자를 높이고 행할 일을 하라하는 것이다.
# TF키워드   : 오, 계명, 높이, 무엇, 사람, 속, 지위, 인륜, 관계, 곧, 상하, 평등, 따르, 행하, 일, 하
# TFIDF키워드: 높이, 상하, 평등, 오, 인륜, 관계, 따르, 속, 행하, 지위, 곧, 일, 사람, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[65]   : 제 오 계명이 금하는 것이 무엇인가?
# 답변[65]   : 제 오 계명이 금하는 것은 각 사람에게 그 속한 지위와 인륜관계를 따라 마땅히 높일 것과 행할 일을 하게 하지 아니하는 것이나 막는 것이다.
# TF키워드   : 오, 계명, 금하, 하, 무엇, 사람, 속, 지위, 인륜, 관계, 따르, 마땅히, 높이, 행하, 일, 막
# TFIDF키워드: 오, 인륜, 관계, 따르, 높이, 막, 금하, 속, 마땅히, 행하, 지위, 일, 사람, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[66]   : 제 오 계명이 「지키라」한 이유가 무엇인가?
# 답변[66]   : 제 오 계명에 지키라 한 이유는 이 계명을 지키는 모든 자에게 장수함과 흥왕하는 복을 허락하심이니 다만 하나님께 영광을 돌리고 사람에게 이익이 있도록만 주시는 것이다.
# TF키워드   : 계명, 지키, 오, 이유, 무엇, 장수, 흥, 왕, 복, 허락, 하나님, 영광, 돌리, 사람, 이익, 있, 주시
# TFIDF키워드: 이유, 지키, 장수, 이익, 오, 흥, 허락, 돌리, 주시, 왕, 복, 영광, 계명, 사람, 있, 하나님, 무엇
# ****************************************************************************************************
# 질문[67]   : 제 육 계명이 무엇인가?
# 답변[67]   : 제 육 계명은 살인하지 말라 하신 것이다.
# TF키워드   : 육, 계명, 무엇, 살인, 말라, 하
# TFIDF키워드: 육, 살인, 말라, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[68]   : 제 육 계명이 명하는 것은 무엇인가?
# 답변[68]   : 제 육 계명이 명하는 것은 일체 합리한 법대로 우리의 생명과 남의 생명을 힘써 보전하라 하는 것이다.
# TF키워드   : 육, 계명, 생명, 무엇, 일체, 합리, 법, 우리, 남, 힘쓰, 보전, 하
# TFIDF키워드: 육, 생명, 일체, 보전, 합리, 남, 힘쓰, 법, 계명, 우리, 하, 무엇
# ****************************************************************************************************
# 질문[69]   : 제 육 계명이 금하는 것은 무엇인가?
# 답변[69]   : 제 육 계명이 금하는 것은 불의하게 우리의 생명이나 이웃의 생명을 빼앗거나 해하는 일들이다.
# TF키워드   : 육, 계명, 금하, 생명, 무엇, 불의, 우리, 이웃, 빼앗, 해, 일
# TFIDF키워드: 육, 생명, 빼앗, 금하, 불의, 해, 이웃, 일, 계명, 우리, 무엇
# ****************************************************************************************************
# 질문[70]   : 제 칠 계명이 무엇인가?
# 답변[70]   : 제 칠 계명은 간음하지 말라 하신 것이다.
# TF키워드   : 치, 계명, 무엇, 간음, 말라, 하
# TFIDF키워드: 간음, 치, 말라, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[71]   : 제 칠 계명이 명하는 것은 무엇인가?
# 답변[71]   : 제 칠 계명이 명하는 것은 생각과 말과 행동으로 우리와 및 이웃의 정조를 보존하라 하는 것이다.
# TF키워드   : 치, 계명, 무엇, 생각, 말, 행동, 우리, 이웃, 정조, 보존, 하
# TFIDF키워드: 정조, 치, 보존, 생각, 말, 행동, 이웃, 계명, 우리, 하, 무엇
# ****************************************************************************************************
# 질문[72]   : 제 칠 계명이 금하는 것은 무엇인가?
# 답변[72]   : 제 칠 계명이 금하는 것은 모든 깨끗지 못한 생각과 말과 행동이다.
# TF키워드   : 치, 계명, 금하, 무엇, 깨끗, 지, 생각, 말, 행동
# TFIDF키워드: 치, 깨끗, 지, 금하, 생각, 말, 행동, 계명, 무엇
# ****************************************************************************************************
# 질문[73]   : 제 팔 계명이 무엇인가?
# 답변[73]   : 제 팔 계명은 도적질하지 말라 하신 것이다.
# TF키워드   : 팔, 계명, 무엇, 도적, 말라, 하
# TFIDF키워드: 팔, 도적, 말라, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[74]   : 제 팔 계명이 명하는 것은 무엇인가?
# 답변[74]   : 제 팔 계명이 명하는 것은 합리한 법대로 우리와 남의 재물과 산업을 얻고 또 증진하라 하는 것이다.
# TF키워드   : 팔, 계명, 무엇, 합리, 법, 우리, 남, 재물, 산업, 얻, 증진, 하
# TFIDF키워드: 팔, 합리, 재물, 산업, 남, 증진, 법, 얻, 계명, 우리, 하, 무엇
# ****************************************************************************************************
# 질문[75]   : 제 팔 계명이 금하는 것은 무엇인가?
# 답변[75]   : 제 팔 계명이 금하는 것은 우리의 남의 재물과 산업을 불의하게 방해하거나 혹 방해될 만한 일이다.
# TF키워드   : 팔, 계명, 금하, 방해, 무엇, 우리, 남, 재물, 산업, 불의, 혹
# TFIDF키워드: 방해, 팔, 재물, 산업, 금하, 남, 불의, 혹, 계명, 우리, 무엇
# ****************************************************************************************************
# 질문[76]   : 제 구 계명이 무엇인가?
# 답변[76]   : 제 구 계명은 네 이웃을 해하려고 거짓 증거하지 말라 하신 것이다.
# TF키워드   : 구, 계명, 무엇, 이웃, 해, 거짓, 증거, 말라, 하
# TFIDF키워드: 구, 거짓, 증거, 해, 말라, 이웃, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[77]   : 제 구 계명이 명하는 것은 무엇인가?
# 답변[77]   : 제 구 계명이 명하는 것은 특히 증거할 때에 피차 진실함과 또 우리와 이웃의 명예를 보존하며 증진하게 하라 하는 것이다.
# TF키워드   : 구, 계명, 하, 무엇, 특히, 증거, 때, 피차, 진실, 우리, 이웃, 명예, 보존, 증진
# TFIDF키워드: 구, 피차, 특히, 증거, 명예, 진실, 증진, 보존, 때, 이웃, 계명, 하, 우리, 무엇
# ****************************************************************************************************
# 질문[78]   : 제 구 계명이 금하는 것은 무엇인가?
# 답변[78]   : 제 구 계명이 금하는 것은 무엇이든지 진실함에 해되는 일이나 혹은 이웃의 명예를 보존하며 증진하게 하라 하는 것이다.
# TF키워드   : 구, 계명, 금하, 무엇, 하, 진실, 해, 일, 이웃, 명예, 보존, 증진
# TFIDF키워드: 구, 명예, 금하, 진실, 해, 증진, 보존, 이웃, 일, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[79]   : 제 십 계명이 무엇인가?
# 답변[79]   : 제 십 계명은 네 이웃의 집이나 아내나 노비나 소나 나귀나 네 이웃에게 있는 것을 탐내지 말라 하신 것이다.
# TF키워드   : 십, 계명, 이웃, 무엇, 집, 아내, 노비, 소나, 나, 귀, 있, 탐내, 말라, 하
# TFIDF키워드: 십, 집, 아내, 소나, 귀, 탐내, 이웃, 노비, 나, 말라, 있, 계명, 하, 무엇
# ****************************************************************************************************
# 질문[80]   : 제 십 계명이 명하는 것은 무엇인가?
# 답변[80]   : 제 십 계명이 명하는 것은 우리 처지를 만족히 여기며 이웃과 그 있는 모든 것에 대하여 의롭고 사랑하는 마음을 품으라 하는 것이다.
# TF키워드   : 십, 계명, 무엇, 우리, 처지, 만, 족히, 여기, 이웃, 있, 대하, 의롭, 사랑, 마음, 품, 하
# TFIDF키워드: 십, 만, 품, 족히, 처지, 의롭, 사랑, 대하, 여기, 마음, 이웃, 있, 계명, 우리, 하, 무엇
# ****************************************************************************************************
# 질문[81]   : 제 십 계명에 금하는 것이 무엇인가?
# 답변[81]   : 제 십 계명에 금하는 것은 우리의 처지를 부족히 여기거나 이웃의 행복을 시기하거나 한하거나 이웃에 있는 모든 물건에대한 불의한 행동과 감정이다.
# TF키워드   : 십, 계명, 금하, 이웃, 무엇, 우리, 처지, 부, 족히, 여기, 행복, 시기, 한하, 있, 물건, 대하, 불의, 행동, 감정
# TFIDF키워드: 십, 부, 행복, 시기, 한하, 물건, 감정, 이웃, 족히, 금하, 처지, 불의, 대하, 행동, 여기, 있, 계명, 우리, 무엇
# ****************************************************************************************************
# 질문[82]   : 아무 사람이나 능히 하나님의 계명을 완전히 지킬 수 있는가?
# 답변[82]   : 타락한 후로 사람만으로는 금생에서 하나님의 계명을 완전히 지킬 수 없고 날마다 생각과 말과 행동으로써 범한다.
# TF키워드   : 사람, 하나님, 계명, 완전히, 지키, 능히, 타락, 후, 금, 없, 날, 생각, 말, 행동, 범하
# TFIDF키워드: 완전히, 지키, 후, 금, 생각, 범하, 능히, 말, 행동, 사람, 타락, 날, 없, 계명, 하나님
# ****************************************************************************************************
# 질문[83]   : 법을 범한 모든 죄가 다 같이 악한가?
# 답변[83]   : 어떠한 죄는 그 본질과 여러 가지 얽힌 끝이 있으므로 하나님 앞에서다른 죄보다 더 악함이 있다.
# TF키워드   : 죄, 악하, 법, 범하, 다, 같이, 어떠, 본질, 얽히, 끝, 있, 하나님, 앞, 다르, 더
# TFIDF키워드: 악하, 본질, 얽히, 다르, 더, 같이, 끝, 앞, 죄, 다, 법, 범하, 어떠, 있, 하나님
# ****************************************************************************************************
# 질문[84]   : 범한 죄마다 마땅히 받을 보응이 무엇인가?
# 답변[84]   : 범한 죄마다 받을 보응은 이 세상과 오는 세상에서 하나님의 진노와 저주다.
# TF키워드   : 범하, 죄, 받, 보응, 세상, 마땅히, 무엇, 오, 하나님, 진노, 저주
# TFIDF키워드: 보응, 범하, 세상, 진노, 저주, 받, 마땅히, 죄, 오, 하나님, 무엇
# ****************************************************************************************************
# 질문[85]   : 우리가 죄를 인하여 하나님께 받을 진노의 저주를 피하게 하려고 하나님이 우리에게 요구하시는 것이 무엇인가?
# 답변[85]   : 우리가 죄를 인하여 하나님께 마땅히 받을 진노와 저주를 피하게 하려고 하나님이 우리에게 요구하시는 것은 예수 그리스도를 믿는 것과 생명에 이르는 회개와그리스도가 우리에게 구속의 유익을 전하는 여러 가지 나타내는 방법을 힘써 사용하라는 것이다.
# TF키워드   : 우리, 하나님, 죄, 인하, 받, 진노, 저주, 피하, 하, 요구, 그리스도, 무엇, 마땅히, 예수, 믿, 생명, 이르, 회개, 구속, 유익
# TFIDF키워드: 피하, 요구, 진노, 저주, 인하, 전하, 힘쓰, 사용, 예수, 회개, 구속, 방법, 생명, 받, 마땅히, 믿, 유익, 죄, 이르, 나타내
# ****************************************************************************************************
# 질문[86]   : 예수 그리스도를 믿는 것은 무엇인가?
# 답변[86]   : 예수 그리스도를 믿는 것은 곧 구원 얻는 은혜인데 이로 말미암아 복음 중에 우리에게 주신 대로 구원을 얻기 위하여 우리가 예수를 영접하고 그에게만 의지하는 것이다.
# TF키워드   : 예수, 그리스도, 믿, 구원, 얻, 우리, 무엇, 곧, 은혜, 이, 말미암, 복음, 위하, 영접, 그, 의지
# TFIDF키워드: 예수, 믿, 영접, 구원, 얻, 복음, 의지, 말미암, 위하, 은혜, 그리스도, 곧, 이, 그, 우리, 무엇
# ****************************************************************************************************
# 질문[87]   : 생명에 이르는 회개가 무엇인가?
# 답변[87]   : 생명에 이르는 회개는 곧 구원 얻는 은혜인데 이로 말미암아 죄인이 자기 죄를 참으로 알고 또 그리스도 안에서 하나님의 긍휼하심을 깨달아 자기 죄를 원통히 여기고 미워함으로 죄에서 떠나 하나님께로 돌아가서 든든하게 결심하고 마음과 힘을 다하여 새로이 순종하는 것이다.
# TF키워드   : 죄, 생명, 이르, 회개, 자기, 하나님, 무엇, 곧, 구원, 얻, 은혜, 이, 말미암, 죄인, 참으로, 알, 그리스도, 안, 깨닫, 여기
# TFIDF키워드: 회개, 생명, 참으로, 미워하, 떠나, 돌아가, 결심, 새로이, 이르, 죄인, 든든, 힘, 자기, 깨닫, 죄, 안, 다, 순종, 알, 여기
# ****************************************************************************************************
# 질문[88]   : 그리스도께서 우리에게 구원의 유익을 전하시려고 나타내시는 보통 방법이 무엇인가?
# 답변[88]   : 그리스도께서 우리에게 구원의 유익을 전하시려고 나타내시는 보통 방법은그의 규례인데 특별히 하나님의 말씀과 성례와 기도이다. 이것이 모두 그 택하신 자에게 효력이 되어 구원을 얻게 한다.
# TF키워드   : 그리스도, 우리, 구원, 유익, 전하, 나타내, 보통, 방법, 무엇, 그, 규례, 특별히, 하나님, 말씀, 기도
# TFIDF키워드: 전하, 보통, 방법, 유익, 구원, 나타내, 규례, 특별히, 그리스도, 기도, 말씀, 그, 우리, 하나님, 무엇
# ****************************************************************************************************
# 질문[89]   : 하나님의 말씀이 어떻게 효력이 되어 구원을 얻게 하는가?
# 답변[89]   : 하나님의 말씀을 읽는것과 특히 강설하는 것으로써 하나님의 신이 효력있는 방법을 삼아 죄인을 반성시켜 회개하게 하시며 또 믿음으로 말미암아 거룩함과 위로를 더하셔서 구원에 이르게 하신다.
# TF키워드   : 하나님, 말씀, 효력, 구원, 하, 어떻, 되, 얻, 읽, 특히, 강, 설, 신이, 있, 방법, 삼, 죄인, 반성, 회개, 믿음
# TFIDF키워드: 효력, 강, 설, 반성, 위로, 더하, 구원, 읽, 특히, 죄인, 신이, 말씀, 방법, 회개, 믿음, 말미암, 이르, 얻, 삼, 거룩
# ****************************************************************************************************
# 질문[90]   : 하나님의 말씀을 어떻게 읽고 들어야 효력이 되어 구원을 얻는 방도가 되는가?
# 답변[90]   : 하나님의 말씀이 우리로 하여금 구원을 얻게 하는 방도가 되게 하려면 마땅히 부지런함과 예비함과 기도함으로써 생각하며 믿음과 사랑을 우리 마음에 두고 행실에 나타낼 것이다.
# TF키워드   : 되, 하나님, 말씀, 구원, 얻, 방도, 우리, 하, 어떻, 읽, 들, 효력, 하여금, 마땅히, 부지런, 예비, 기도, 생각, 믿음, 사랑
# TFIDF키워드: 방도, 부지런, 두, 행실, 구원, 되, 얻, 읽, 예비, 말씀, 들, 생각, 사랑, 마땅히, 믿음, 효력, 마음, 하여금, 나타내, 기도
# ****************************************************************************************************
# 질문[91]   : 성례가 어떻게 효력이 되어 구원을 얻게 하는 방도가 되는가?
# 답변[91]   : 성례가 효력이 되어 구원을 얻게 하는 방도가 되는 것은 성례 자체로 말미암음도 아니요, 베푸는 자의 덕으로 됨이 아니라, 다만 그리스도의 축복함으로 되며 또 믿음으로 성례를 받는자 속에 성령이 역사하심으로 되는 것이다.
# TF키워드   : 되, 효력, 구원, 얻, 하, 방도, 어떻, 자체, 말미암, 베풀, 덕, 그리스도, 축복, 믿음, 받, 속, 성령, 역사
# TFIDF키워드: 방도, 되, 효력, 자체, 덕, 구원, 얻, 역사, 베풀, 축복, 속, 믿음, 말미암, 성령, 어떻, 받, 그리스도, 하
# ****************************************************************************************************
# 질문[92]   : 성례가 무엇인가?
# 답변[92]   : 성례는 그리스도께서 세우신 거룩한 예식인데 그리스도와 그 새 언약의 유익을 깨닫는 표로써 표시하여 인쳐 신자들에게 적용하는 것이다.
# TF키워드   : 그리스도, 무엇, 세우, 거룩, 예식, 언약, 유익, 깨닫, 표, 표시, 인, 치, 신자, 적용
# TFIDF키워드: 예식, 표, 표시, 인, 세우, 깨닫, 적용, 언약, 신자, 유익, 치, 그리스도, 거룩, 무엇
# ****************************************************************************************************
# 질문[93]   : 신약의 성례가 무엇인가?
# 답변[93]   : 신약의 성례는 세례와 성찬이다.
# TF키워드   : 신약, 무엇, 세례, 성찬
# TFIDF키워드: 신약, 세례, 성찬, 무엇
# ****************************************************************************************************
# 질문[94]   : 세례가 무엇인가?
# 답변[94]   : 세례는 물을 가지고 성부와 성자와 성령의 이름으로 씻는 성례인데 우리가 그리스도에게 접합
# TF키워드   : 세례, 무엇, 물, 가지, 성부, 성자, 성령, 이름, 씻, 우리, 그리스도, 접합
# TFIDF키워드: 세례, 물, 가지, 씻, 접합, 성부, 성자, 이름, 성령, 그리스도, 우리, 무엇
# ****************************************************************************************************
# 질문[95]   : 세례는 어떠한 사람에게 베푸는가?
# 답변[95]   : 세례는 불신자들이 그리스도를 믿고 고백하며 그에게 복종하는 데까지 이르러야 베풀 것이요, 또 입교한 자의 자녀에게 베푸는 것이다.
# TF키워드   : 베풀, 세례, 어떠, 사람, 신자, 그리스도, 믿, 고백, 그, 복종, 이르, 입교, 자녀
# TFIDF키워드: 베풀, 세례, 고백, 입교, 자녀, 신자, 어떠, 복종, 믿, 이르, 사람, 그, 그리스도
# ****************************************************************************************************
# 질문[96]   : 주의 성찬이 무엇인가?
# 답변[96]   : 주의 성찬은 곧 성례이니 그리스도의 정하신 대로 떡과 포도즙을 주며 받는 것으로 그 죽으심을 나타냄이다. 합당하게 받는 자들은 육체와 정욕으로 참여함이 아니요, 믿음으로써 그의 몸과 피에 참여하여 자기의 신령하게 받은 양육과 은혜 중에서 장성함으로 그의 모든 효험을 받음이다.
# TF키워드   : 주의, 성찬, 무엇, 곧, 그리스도, 정하, 떡, 포도, 즙, 받, 죽, 나타내
# TFIDF키워드: 주의, 성찬, 떡, 포도, 즙, 죽, 정하, 나타내, 곧, 받, 그리스도, 무엇
# ****************************************************************************************************
# 질문[97]   : 주의 성찬에 합당하게 참여하려면 어떻게 하여야 하는가?
# 답변[97]   : 주의 성찬에 합당하게 참여하려면 마땅히 주님의 몸을 분별할줄 아는 것과 주님으로써 양식을 삼는 믿음과 회개와 사랑과 서로 순종함에 대하여 스스로 살필 것이니 합당하지 않게 참여하면 두렵건대 먹고 마시는 것이 정죄함을 자청함이 될 것이다.
# TF키워드   : 합당, 참여, 주의, 성찬, 주님, 어떻, 하, 마땅히, 몸, 분별, 알, 양식, 삼, 믿음, 회개, 사랑, 서로, 순종, 대하, 스스로
# TFIDF키워드: 참여, 주님, 합당, 주의, 성찬, 서로, 스스로, 살피, 두렵, 마시, 정죄, 자청, 분별, 양식, 먹, 몸, 회개, 순종, 사랑, 마땅히
# ****************************************************************************************************
# 질문[98]   : 기도가 무엇인가?
# 답변[98]   : 기도는 그리스도의 이름으로 우리의 기원을 하나님께 고하고 그의 뜻에 합당한 것을 간구하여 죄를 자복하며 그의 자비하신 모든 은혜를 감사하는 것이다.
# TF키워드   : 기도, 그, 무엇, 그리스도, 이름, 우리, 기원, 하나님, 고하, 뜻, 합당, 간구, 죄, 자, 복, 자비, 은혜, 감사
# TFIDF키워드: 기원, 고하, 자, 자비, 감사, 기도, 간구, 합당, 복, 이름, 뜻, 그, 은혜, 죄, 그리스도, 우리, 하나님, 무엇
# ****************************************************************************************************
# 질문[99]   : 하나님께서 우리의 기도를 지시하시려고 주신 법칙이 무엇인가?
# 답변[99]   : 하나님의 모든 말씀이 우리의 기도를 지시함에 유용한 것이나 특별히 지시하신 법칙은 그리스도께서 그 제자들에게 가르치신 기도니 보통으로 주기도문이라 하는 것이다.
# TF키워드   : 기도, 지시, 하나님, 우리, 법칙, 무엇, 말씀, 유용, 특별히, 그리스도, 제자, 가르치, 보통, 주기, 도문, 하
# TFIDF키워드: 지시, 법칙, 기도, 유용, 제자, 가르치, 보통, 특별히, 주기, 도문, 말씀, 우리, 그리스도, 하나님, 하, 무엇
# ****************************************************************************************************
# 질문[100]   : 주기도문의 첫 말씀이 우리에게 무엇을 교훈하는가?
# 답변[100]   : 주기도문의 첫 말씀은 곧 하늘에 계신 우리 아버지여 한 것이니 이는 자식이 그 능하고 보호하시기를 예비한 아버지에게 가는 것과 같이 우리가 모든 거룩하게 공경하는 뜻과 든든한 마음으로 하나님께 가까이 오는 것을 가르치고 또 우리가 다른 사람으로 더불어 기도하고 다른 사람을 위하여 기도하라 가르친 것이다.
# TF키워드   : 우리, 주기, 도문, 첫, 말씀, 가르치, 사람, 기도, 무엇, 교훈, 곧, 하늘, 계시, 우리 아버지, 이, 자식, 능하, 보호, 예비, 아버지
# TFIDF키워드: 첫, 가르치, 우리 아버지, 자식, 능하, 가, 가까이, 주기, 도문, 예비, 공경, 든든, 기도, 보호, 아버지, 같이, 더불, 말씀, 하늘, 계시
# ****************************************************************************************************
# 질문[101]   : 첫 기도에 우리가 무엇을 구하는가?
# 답변[101]   : 주기도문 첫 기도는 곧 이름을 거룩하게 하옵소서 함인데 하나님께서 자기를 나타내시는 모든 일에 우리와 다른 이로 하여금 능히 그를 영화롭게 하고 또 모든 것을 처리하여 하나님의영광에 이르게 하옵심을 구하는 것이다.
# TF키워드   : 하, 첫, 기도, 우리, 구하, 하나님, 무엇, 주기, 도문, 곧, 이름, 거룩, 함, 자기, 나타내, 일, 이, 하여금, 능히, 그
# TFIDF키워드: 첫, 구하, 처리, 기도, 함, 이름, 영화, 능히, 영광, 하여금, 이르, 주기, 도문, 나타내, 자기, 곧, 거룩, 일, 이, 그
# ****************************************************************************************************
# 질문[102]   : 둘째 기도에 우리가 무엇을 구하는가?
# 답변[102]   : 주기도문의 둘째 기도에 나라이 임하옵소서 함은 사단의 나라가 멸망하고 은혜의 나라가 흥왕하여 우리와 다른 사람으로 하여금 그리로 들어가 항상 있게 하시고 또 영광의 나라가 속히 임하게 하옵심을 구하는 것이다.
# TF키워드   : 나라, 하, 둘째, 기도, 우리, 구하, 임하, 무엇, 주기, 도문, 이, 사단, 멸망, 은혜, 흥, 왕, 사람, 하여금, 그리로, 들어가
# TFIDF키워드: 나라, 둘째, 임하, 구하, 사단, 그리로, 속히, 멸망, 흥, 들어가, 항상, 기도, 왕, 영광, 하여금, 주기, 도문, 은혜, 이, 사람
# ****************************************************************************************************
# 질문[103]   : 주기도문의 셋째 기도에 우리가 무엇을 구하는가?
# 답변[103]   : 주기도문의 셋째 기도는 뜻이 하늘에서 이룬 것같이 땅에서도 이루어지이다 함인데 하나님께서 은혜를 베푸시사 우리로 하여금 능히 감심
# TF키워드   : 주기, 도문, 셋째, 기도, 우리, 무엇, 구하, 뜻, 하늘, 이루, 땅, 이루어지, 함, 하나님, 은혜, 베풀, 하여금, 능히, 감
# TFIDF키워드: 셋째, 이루어지, 감, 주기, 도문, 이루, 기도, 땅, 베풀, 하늘, 함, 구하, 뜻, 능히, 하여금, 은혜, 우리, 하나님, 무엇
# ****************************************************************************************************
# 질문[104]   : 주기도문의 넷째 기도에 우리가 무엇을 구하는가?
# 답변[104]   : 주기도문의 넷째 기도는 곧 오늘날 우리에게 일용할 양식을 주옵소서 함인데 하나님의 은사로써 이 세상에서 여러 가지 좋은 것 중에 만족할 부분을 받게 하시며 아울러 그의 축복을 누리게 하옵심을 구하는 것이다.
# TF키워드   : 주기, 도문, 넷째, 기도, 우리, 구하, 하, 무엇, 곧, 오늘날, 일용, 양식, 함, 하나님, 은사, 세상, 좋, 만족, 부분, 받
# TFIDF키워드: 넷째, 구하, 오늘날, 일용, 은사, 부분, 주기, 도문, 양식, 좋, 만족, 아울러, 누리, 기도, 축복, 함, 세상, 곧, 받, 그
# ****************************************************************************************************
# 질문[105]   : 주기도문의 다섯째 기도에 우리가 무엇을 구하는가?
# 답변[105]   : 주기도문의 다섯째 기도는 곧 우리가 우리에게 죄 지은 자를 사하여 준 것같이 우리의 죄를 사하여 주옵소서 함이니 하나님께서 그리스도를 인하여 우리의 모든 죄를 값 없이 사하여 주옵소서 함인데 우리가 그의 은혜를 힘입어 능히 진심으로 다른 이의 죄를 사하였은즉 더욱 용감히 간구하는 것이다.
# TF키워드   : 우리, 죄, 사, 주기, 도문, 다섯째, 기도, 함, 무엇, 구하, 곧, 하나님, 그리스도, 인하, 값, 없이, 그, 은혜, 힘입, 능히
# TFIDF키워드: 다섯째, 사, 함, 힘입, 진심, 더욱, 용감히, 죄, 주기, 도문, 없이, 기도, 간구, 인하, 값, 구하, 능히, 우리, 은혜, 곧
# ****************************************************************************************************
# 질문[106]   : 주기도문의 여섯째 기도에 우리가 무엇을 구하는가?
# 답변[106]   : 주기도문의 여섯째 기도는 곧 우리를 시험에 들지 말게 하옵시고 다만 악에서 구원하옵소서 하는 것이니 이는 하나님이 혹 우리를 시험에 들지 아니하게 하시거나 시험을 당할때에 우리를 보호하여 구원하옵소서 하는 기도이다.
# TF키워드   : 우리, 하, 기도, 시험, 주기, 도문, 여섯째, 들, 구원, 무엇, 구하, 곧, 악, 이, 하나님, 혹, 당하, 때, 보호
# TFIDF키워드: 시험, 여섯째, 들, 기도, 악, 당하, 주기, 도문, 구원, 보호, 혹, 구하, 때, 곧, 우리, 이, 하, 하나님, 무엇
# ****************************************************************************************************
# 질문[107]   : 주기도문의 마지막 구절이 우리에게 무엇을 교훈하는가?
# 답변[107]   : 주기도문의 마지막 말씀은 곧 대개 나라와 권세와 영광이 아버지께 영원히 있사옵나이다 아멘 하는 것이니 이는 우리로 하여금 기도할 때에 하나님만 믿고 또 기도할 때에 그를 찬송하여 나라와 권세와 영광이 아버지께 있다 하라고 가르친 것이다. 또 우리가 우리의 원하는 뜻의 증거와 들으실 줄 아는 표로 아멘 하는 것이다.
# TF키워드   : 주기, 도문, 마지막, 우리, 나라, 권세, 영광, 아버지, 있, 하, 기도, 때, 구절, 무엇, 교훈, 말씀, 곧, 대개, 영원히, 사
# TFIDF키워드: 마지막, 나라, 권세, 아버지, 때, 영광, 구절, 대개, 영원히, 아멘, 찬송, 주기, 도문, 기도, 가르치, 교훈, 믿, 있, 사, 하여금
# ****************************************************************************************************
