# %% [markdown]
# ## 소요리문답 조건부 형태소 빈도 계수
# 빈도 계수 결과의 다중 키 정렬
# 소요리 문답 형태소 분석 결괴를 sorted() 함수를 연속적으로 사용하여 (빈도 역순 + 어휘 정순 + 품사 정순)의 다중 키 정렬을 수행한다.

# %%
"""
소요리 문답의 주요 품사 형태소 빈도를 계수하여 다중 키로 정렬하여 출력한다.
"""

from collections import Counter
from operator import itemgetter
import mmap
# from tqdm import tqdm_notebook
from tqdm import tqdm
import ujson

MA_KEY1 = "question_ma"
MA_KEY2 = "answer_ma"

MAJOR_POSES = ["NNG", "NNP", "NP", "XR", "VV", "VA", "MAG", "MAJ"]
PRED_POSES = ["VV", "VA"]


def get_num_lines(file_path):
    """빠른 속도로 텍스트 파일의 줄 수를 세어 돌려준다.
    https://blog.nelsonliu.me/2016/07/29/progress-bars-for-python-file-reading-with-tqdm/
    """
    
    fp = open(file_path, "r+")
    buf = mmap.mmap(fp.fileno(), 0)
    lines = 0
    while buf.readline():
        lines += 1
    return lines


def filter_morph_anal(morph_anals):
    """주어진 형태소 분석 결과 리스트에서 필요한 형태소만 골라서 돌려준다."""
    
    morph_anals = [(lex, pos) for lex, pos in morph_anals if is_major_pos(pos)]
    
    return morph_anals


def is_major_pos(pos):
    """주어진 품사의 주요 품사 여부를 판단하여 돌려준다."""
    
    #if pos in MAJOR_POSES:
    #    return True
    #
    #return False
    
    #모든 품사 대상으로 변경
    return True

def is_pred_pos(pos):
    """주어진 품사가 용언 품사인지를 판단하여 돌려준다."""
    
    if pos in PRED_POSES:
        return True
    
    return False


def main():
    """소요리 문답의 주요 품사 형태소 빈도를 계수하여 다중 키로 정렬하여 출력한다."""
    
    morph_counter = Counter()
    input_file_name = "data/catechism/catechism.ma.txt"
    doc_row = []
    with open(input_file_name, "r", encoding="utf-8") as input_file:
        for line in tqdm(input_file, desc="Reading documents", 
                                  total=get_num_lines(input_file_name)):
            doc = ujson.loads(line)
            doc_row = doc[MA_KEY1]+doc[MA_KEY2]            
            #print("{}".format(doc_row))
            #print("-"*100)
            sent_ma = filter_morph_anal(doc_row)
            #print(sent_ma)
            morph_counter.update(sent_ma)
            #print(morph_counter)
            #print("="*100)
                
    morph_counts = [(l, p, c) for (l, p), c in morph_counter.items()]
    # sorted() 함수를 연속적으로 사용하여 (빈도 역순 + 어휘 정순 + 품사 정순)의 다중 키 정렬을 수행
    print("morph_counts=[{}]".format(morph_counts))
    
    # 어휘,품사,빈도 자료에서 품사 정순으로 정렬
    #print("="*100)
    sorted_morph_counts = sorted(morph_counts, key=itemgetter(1))
    #print("품사 정순으로 정렬, key=itemgetter(1)=[{}]".format(sorted_morph_counts))

    # 어휘,품사,빈도 자료에서 어휘 정순으로 정렬
    #print("*"*100)
    sorted_morph_counts = sorted(sorted_morph_counts, key=itemgetter(0))
    #print("어휘 정순으로 정렬, key=itemgetter(0)=[{}]".format(sorted_morph_counts))

    # 어휘,품사,빈도 자료에서 빈도 정순으로 정렬
    #print("+"*100)
    #sorted_morph_counts = sorted(sorted_morph_counts, key=itemgetter(2), reverse=True)
    #print("빈도 정순으로 정렬, key=itemgetter(2)=[{}]".format(sorted_morph_counts))
                
    for lex, pos, count in sorted_morph_counts:
        if is_pred_pos(pos):
            lex += "다"
            
        print("{}\t{}\t{}".format(lex, pos, count))

#
# 실행
#
main()
# Out:
# Reading documents: 100%|██████████████████████████████████████████████████████████| 107/107 [00:00<00:00, 11924.18it/s]
# morph_counts=[[('사람', 'NNG', 30), ('의', 'JKG', 169), ('제일', 'NNG', 9), ('되', 'VV', 29), ('는', 'ETM', 206), ('목적', 'NNG', 2), ('이', 'JKS', 137), ('무엇', 'NP', 75), ('이', 'VCP', 191), ('ㄴ가', 'EF', 71), ('?', 'SF', 107), ('은', 'JX', 102), ('하나님', 'NNG', 8), ('을', 'JKO', 159), ('영화', 'NNG', 7), ('롭', 'XSA', 6), ('게', 'EC', 91), ('하', 'VV', 96), ('것', 'NNB', 192), ('과', 'JKB', 32), ('영원', 'NNG', 6), ('하', 'XSV', 207), ('도록', 'EC', 5), ('그', 'NP', 24), ('를', 'JKO', 72), ('즐거워하', 'VV', 4), ('다', 'EF', 96), ('.', 'SF', 105), ('하나님', 'NNP', 94), ('께서', 'JKS', 38), ('무슨', 'MM', 7), ('규칙', 'NNG', 4), ('우리', 'NP', 92), ('에게', 'JKB', 47), ('주', 'VX', 8), ('시', 'EP', 173), ('어', 'EC', 30), ('어떻', 'VA', 16), ('자기', 'NP', 16), ('고', 'EC', 63), ('ㄹ', 'ETM', 44), ('지시', 'NNG', 5), ('었', 'EP', 20), ('는가', 'EF', 35), ('신구약', 'NNG', 1), ('성경', 'NNP', 3), ('에', 'JKB', 107), ('기재', 'NNG', 1), ('되', 'XSV', 14), ('ㄴ', 'ETM', 115), ('말씀', 'NNG', 18), ('가', 'JKS', 55), ('유일한', 'NNP', 2), ('요긴', 'XR', 2), ('하', 'XSA', 65), ('교훈', 'NNG', 8), ('대하', 'VV', 7), ('아', 'EC', 61), ('믿', 'VV', 7), ('을', 'ETM', 10), ('요구', 'NNG', 5), ('본분', 'NNG', 3), ('어떤', 'MM', 2), ('분', 'NNB', 3), ('신', 'XPN', 1), ('이신', 'NNP', 3), ('데', 'NNB', 4), ('존재', 'NNG', 1), ('ㅁ', 'ETN', 58), ('지혜', 'NNG', 2), ('와', 'JC', 33), ('권능', 'NNG', 4), ('과', 'JC', 47), ('거룩', 'XR', 18), ('공의', 'NNG', 3), ('인자', 'XR', 1), ('진실', 'NNG', 3), ('무한', 'NNG', 1), ('며', 'EC', 20), (',', 'SP', 14), ('무궁', 'XR', 1), ('불변', 'NNG', 1), ('한', 'MM', 16), ('밖에', 'JX', 1), ('또', 'MAJ', 18), ('다른', 'MM', 11), ('계시', 'VX', 2), ('뿐', 'NNB', 2), ('니', 'EC', 15), ('참되', 'VA', 1), ('살', 'VV', 2), ('계시', 'VV', 4), ('신격', 'NNP', 2), ('몇', 'MM', 1), ('위', 'NNG', 3), ('삼위', 'NNP', 2), ('성부', 'NNP', 2), ('성자', 'NNP', 2), ('성령', 'NNP', 9), ('이', 'MM', 17), ('는', 'JX', 39), ('예정', 'NNG', 4), ('그', 'MM', 28), ('뜻대로', 'MAG', 2), ('경륜', 'NNP', 1), ('이', 'NP', 14), ('로', 'JKB', 36), ('말미암', 'VV', 8), ('영광', 'NNG', 3), ('위하', 'VV', 9), ('모든', 'MM', 24), ('가', 'VX', 1), ('일', 'NNG', 17), ('미리', 'MAG', 1), ('작정', 'NNG', 2), ('이루', 'VV', 3), ('창조', 'NNG', 9), ('섭리', 'NNG', 4), ('ㄴ다', 'EF', 5), ('일', 'NNB', 13), ('엿새', 'NNG', 2), ('동안', 'NNG', 3), ('아무', 'MM', 3), ('도', 'JX', 6), ('없', 'VA', 9), ('중', 'NNB', 17), ('에서', 'JKB', 31), ('으로써', 'JKB', 8), ('만물', 'NNG', 2), ('지', 'VX', 12), ('으시', 'EP', 9), ('ㄴ데', 'EC', 16), ('다', 'MAG', 7), ('매우', 'MAG', 1), ('좋', 'VA', 2), ('았', 'EP', 7), ('남녀', 'NNG', 1), ('되', 'EC', 2), ('형상', 'NNP', 1), ('대로', 'JX', 4), ('지식', 'NNG', 1), ('있', 'VV', 24), ('지', 'NNG', 2), ('으', 'NNG', 2), ('사', 'NNG', 13), ('생물', 'NNG', 1), ('주관', 'NNG', 1), ('지극히', 'MAG', 1), ('창조물', 'NNG', 1), ('모', 'MM', 1), ('들', 'VV', 5), ('행동', 'NNG', 6), ('보존', 'NNG', 4), ('치', 'VV', 12), ('리', 'EC', 1), ('하', 'VX', 4), ('받', 'VV', 28), ('은', 'ETM', 11), ('보', 'VV', 7), ('지위', 'NNG', 15), ('때', 'NNG', 10), ('저', 'NP', 3), ('향하', 'VV', 1), ('특별', 'XR', 1), ('후', 'NNG', 3), ('완전히', 'MAG', 5), ('순', 'NNG', 1), ('복', 'NNG', 4), ('조건', 'NNG', 1), ('으로', 'JKB', 34), ('삼', 'VV', 9), ('생명', 'NNG', 8), ('언약', 'NNG', 4), ('맺', 'VV', 1), ('선악', 'NNG', 1), ('분별', 'NNG', 2), ('나무', 'NNG', 1), ('실과', 'NNG', 2), ('먹', 'VV', 3), ('사망', 'NNG', 2), ('벌', 'NNG', 2), ('로써', 'JKB', 5), ('금하', 'VV', 22), ('시조', 'NNG', 4), ('그대로', 'MAG', 2), ('있', 'VX', 4), ('임의', 'NNG', 1), ('자유', 'NNG', 1), ('인하', 'VV', 6), ('께', 'JKB', 9), ('죄', 'NNG', 33), ('범하', 'VV', 6), ('므로', 'EC', 2), ('타락', 'NNG', 12), ('법', 'NNG', 5), ('순종', 'NNG', 4), ('부족', 'NNG', 1), ('이나', 'JX', 5), ('혹', 'MAG', 4), ('어기', 'VV', 1), ('인종', 'NNP', 5), ('아담', 'NNP', 3), ('첫', 'MM', 3), ('범죄', 'NNG', 3), ('더불', 'VV', 3), ('세우', 'VV', 3), ('만', 'JX', 7), ('아니요', 'IC', 2), ('그 후', 'NNP', 2), ('자손', 'NNG', 1), ('까지', 'JX', 7), ('로부터', 'JKB', 2), ('보통', 'MAG', 3), ('생육', 'NNG', 1), ('출생', 'NNG', 1), ('모두', 'MAG', 1), ('안', 'NNG', 4), ('어서', 'EC', 6), ('참여', 'NNG', 6), ('와', 'JKB', 8), ('함께', 'MAG', 4), ('하여금', 'MAG', 9), ('어떠', 'XR', 5), ('이르', 'VV', 10), ('비참', 'NNG', 7), ('처지', 'NNG', 3), ...
# ,	SP	14
# .	SF	105
# ?	SF	107
# ㄴ	ETM	115
# ㄴ가	EF	71
# ㄴ다	EF	5
# ㄴ데	EC	16
# ㄹ	ETM	44
# ㄹ지라도	EC	1
# ㅁ	ETN	58
# 가	JKS	55
# 가다	VV	1
# 가	VX	1
# 가까이	MAG	1
# 가르치다	VV	4
# 가운데	NNG	1
# 가지	NNB	10
# 가지다	VV	1
# 각	MM	2
# 간구	XR	3
# 간략히	MAG	2
# 간음	NNG	1
# 간의	NNP	1
# 감다	VV	1
# 감사	NNG	1
# 감정	NNG	1
# 값	NNG	5
# 강	NNP	1
# 강령	NNG	2
# 강생	NNP	1
# 같이	JKB	2
# 같이	MAG	3
# 객	NNG	1
# 거나	EC	12
# 거룩	XR	18
# 거룩히	NA	1
# 거짓	NNG	1
# 거하다	VV	1
# 건	NNB	1
# 건대	EC	1
# 것	NNB	192
# 게	EC	91
# 겠	EP	2
# 결심	NNG	1
# 경륜	NNP	1
# 경배	NNG	6
# 계명	NNP	75
# 계시다	VV	4
# 계시	VX	2
# 고	EC	63
# 고로	MAG	1
# 고백	NNG	1
# 고자	EC	1
# 고하다	VV	1
# 곧	MAG	13
# 공경	NNG	2
# 공사	NNP	1
# 공의	NNG	3
# 과	JC	47
# 과	JKB	32
# 관계	NNG	2
# 교제	NNG	1
# 교훈	NNG	8
# 구	NNG	6
# 구속	NNG	7
# 구속자	NNG	6
# 구원	NNG	10
# 구원	NNP	5
# 구절	NNG	1
# 구하다	VV	9
# 굳다	VA	1
# 굽	NNG	1
# 권	NNB	1
# 권능	NNG	4
# 권세	NNG	3
# 귀	NNG	1
# 규례	NNP	3
# 규칙	NNG	4
# 그	MM	28
# 그	NP	24
# 그 후	NNP	2
# 그날	NNG	1
# 그대로	MAG	2
# 그리로	MAG	1
# 그리스도	NNP	43
# 그리스도인	NNG	1
# 그치다	VV	1
# 근본	NNG	1
# 금	NNG	7
# 금하다	VV	22
# 긍게	NA	1
# 긍휼하심을	NA	1
# 기	ETN	6
# 기도	NNG	24
# 기억	NNG	1
# 기원	NNG	1
# 기재	NNG	1
# 까지	JX	7
# 깨끗	XR	2
# 깨닫다	VV	3
# 께	JKB	9
# 께	XSN	1
# 께서	JKS	38
# 끊어지다	VV	1
# 끝	NNG	3
# 나	JC	5
# 나	JX	1
# 나	NP	5
# 나다	VV	1
# 나라	NNG	6
# 나무	NNG	1
# 나오다	VV	5
# 나이다	EC	1
# 나타내다	VV	11
# 나태	NNG	1
# 날	NNG	9
# 날로	MAG	1
# 남	NNP	3
# 남녀	NNG	1
# 낮다	VA	3
# 내	VX	1
# 내리다	VV	1
# 너	NP	2
# 너희	NP	3
# 네	MM	9
# 넷째	NR	2
# 노비	NNP	2
# 높다	VA	3
# 높이다	VV	3
# 누구	NNP	1
# 누리다	VV	2
# 는	ETM	206
# 는	JX	39
# 는가	EF	35
# 는다	EF	1
# 능하다	VA	1
# 능히	MAG	7
# 니	EC	15
# 다	EC	10
# 다	EF	96
# 다	JX	2
# 다	MAG	7
# 다르다	VA	1
# 다른	MM	11
# 다만	MAJ	5
# 다섯째	NR	2
# 다스리다	VV	1
# 다시	MAG	2
# 단번에	MAG	1
# 당하다	VV	1
# 대	XPN	2
# 대개	MAG	1
# 대로	JX	4
# 대로	NNB	2
# 대하다	VV	7
# 더	MAG	1
# 더럽다	VA	1
# 더불다	VV	3
# 더욱	MAG	1
# 더하다	VV	1
# 덕	NNG	1
# 던	ETM	1
# 데	NNB	4
# 도	JX	6
# 도덕	NNG	3
# 도록	EC	5
# 도문	NNP	15
# 도적	NNG	1
# 돌리다	VV	2
# 돌아가다	VV	1
# 동안	NNG	3
# 동정녀	NNG	1
# 되	EC	2
# 되다	VV	29
# 되	XSV	14
# 두	MM	2
# 두다	VV	1
# 두렵다	VA	1
# 둘째	NR	2
# 드리다	VV	3
# 든든	XR	2
# 든지	EC	3
# 들다	VV	5
# 들	XSN	7
# 들어가다	VV	2
# 따르다	VV	2
# 땅	NNG	4
# 때	NNG	10
# 떠나다	VV	1
# 떡	NNG	1
# 또	MAJ	18
# 또한	MAJ	1
# 뜻	NNG	6
# 뜻대로	MAG	2
# 라	EC	24
# 라	EF	3
# 라	NNG	1
# 라고	EC	1
# 라는	ETM	1
# 라도	EC	1
# 러	EC	1
# 려	EC	1
# 려고	EC	7
# 려면	EC	3
# 로	JKB	36
# 로부터	JKB	2
# 로서	JKB	2
# 로써	JKB	5
# 롭	XSA	6
# 루	NNG	1
# 룩	NNG	1
# 를	JKO	72
# 리	EC	1
# 리	NNB	2
# 리라	EC	1
# 마다	JX	3
# 마땅히	MAG	6
# 마리아	NNP	1
# 마시다	VV	1
# 마음	NNG	7
# 마지막	NNG	3
# 막다	VV	2
# 만	JX	7
# 만	NNB	3
# 만	NR	1
# 만들다	VV	2
# 만물	NNG	2
# 만족	NNG	2
# 말	NNG	6
# 말	VX	5
# 말라	NNP	7
# 말미암다	VV	8
# 말씀	NNG	18
# 망령	NNG	2
# 매우	MAG	1
# 맺다	VV	1
# 먹다	VV	3
# 며	EC	20
# 면	EC	1
# 멸망	NNG	2
# 명	NNB	21
# 명예	NNG	2
# 명하다	VV	4
# 몇	MM	1
# 모	MM	1
# 모두	MAG	1
# 모든	MM	24
# 모범	NNG	1
# 목적	NNG	2
# 몸	NNG	4
# 못하	VX	2
# 무궁	XR	1
# 무덤	NNG	1
# 무슨	MM	7
# 무엇	NP	75
# 무한	NNG	1
# 문안	NNG	1
# 묻히다	VV	1
# 물	NNG	1
# 물건	NNG	1
# 물속	NNG	1
# 므로	EC	2
# 미리	MAG	1
# 미워하다	VV	1
# 믿다	VV	7
# 믿음	NNG	5
# 믿음	NNP	1
# 및	MAJ	1
# 바	NNB	1
# 바라다	VV	1
# 바치다	VV	1
# 밖에	JX	1
# 반성	NNG	1
# 받다	VV	28
# 밝히	MAG	1
# 밝히다	VV	1
# 방도	NNP	4
# 방법	NNG	5
# 방해	NNG	2
# 버려두다	VV	1
# 벌	NNG	2
# 범죄	NNG	3
# 범하다	VV	6
# 법	NNG	5
# 법칙	NNG	5
# 베풀다	VV	5
# 보다	VV	7
# 보다	JKB	1
# 보응	NNP	2
# 보이다	VV	4
# 보전	NNG	1
# 보존	NNG	4
# 보통	MAG	3
# 보통	NNG	2
# 보호	NNG	3
# 복	NNG	4
# 복음	NNP	2
# 복종	NNG	6
# 본분	NNG	3
# 본질	NNG	1
# 부	NNG	1
# 부득이	MAG	1
# 부르다	VV	4
# 부름	NNG	1
# 부모	NNG	1
# 부분	NNG	1
# 부족	NNG	1
# 부지런	NNG	1
# 부터	JX	1
# 부패	NNG	1
# 부활	NNG	3
# 부활	NNP	1
# 분	NNB	3
# 분별	NNG	2
# 분하다	VA	1
# 불	XPN	1
# 불변	NNG	1
# 불의	NNG	3
# 불필요	NNG	1
# 비록	MAG	1
# 비참	NNG	7
# 비천	XR	1
# 빼앗다	VV	1
# 뿐	NNB	2
# 사	EC	2
# 사	NNG	13
# 사다	VV	1
# 사단	NNP	1
# 사람	NNG	30
# 사랑	NNG	6
# 사망	NNG	2
# 사세	NNG	1
# 사신	NNP	4
# 사업	NNG	1
# 사용	NNG	4
# 사유	NNP	1
# 사장	NNP	2
# 사흘	NNG	1
# 산업	NNG	2
# 살다	VV	2
# 살아나다	VV	1
# 살아남다	VV	1
# 살인	NNG	1
# 살피다	VV	1
# 삼	NR	8
# 삼다	VV	9
# 삼위	NNP	2
# 상	NNG	1
# 상	XSN	1
# 상하	NNG	1
# 새	MM	1
# 새로이	MAG	1
# 새롭다	VA	2
# 생	XSN	7
# 생각	NNG	5
# 생명	NNG	8
# 생물	NNG	1
# 생육	NNG	1
# 생전	NNG	1
# 서	JKB	4
# 서다	VV	2
# 서로	MAG	1
# 서문	NNP	4
# 선	NNG	1
# 선악	NNG	1
# 선지자	NNG	3
# 선택	NNG	2
# 설	NNG	1
# 섬기다	VV	1
# 섭리	NNG	4
# 성경	NNP	3
# 성령	NNP	9
# 성례	NA	1
# 성례가	NA	4
# 성례는	NA	2
# 성례를	NA	1
# 성례와	NA	1
# 성례이니	NA	1
# 성례인데	NA	1
# 성부	NNP	2
# 성자	NNP	2
# 성찬	NNP	5
# 성품	NNP	3
# 세례	NNP	5
# 세상	NNG	8
# 세우다	VV	3
# 셋째	NR	2
# 소나	NNP	1
# 소서	EC	7
# 소유자	NNG	1
# 속	NNG	3
# 속성	NNP	1
# 속히	MAG	1
# 수	NNB	3
# 수효	NNG	1
# 순	NNG	1
# 순종	NNG	4
# 쉬다	VV	2
# 스스로	MAG	1
# 승인	NNG	1
# 시	EP	173
# 시간	NNG	1
# 시기	NNG	1
# 시니	NNP	1
# 시작	NNG	1
# 시조	NNG	4
# 시키	XSV	1
# 시험	NNG	3
# 신	NNG	4
# 신	XPN	1
# 신가	NNP	1
# 신격	NNP	2
# 신구약	NNG	1
# 신약	NNG	2
# 신이	NNG	1
# 신이	NNP	2
# 신자	NNG	6
# 실과	NNG	2
# 심	NNP	1
# 심판	NNG	2
# 심판	NNP	1
# 십	NR	6
# 십계명	NNP	7
# 십자가	NNP	1
# 씻다	VV	1
# 아	EC	61
# 아내	NNG	1
# 아니	VCN	1
# 아니요	IC	2
# 아니하	VX	8
# 아담	NNP	3
# 아들	NNG	3
# 아래	NNG	5
# 아멘	NNP	1
# 아무	MM	3
# 아버지	NNG	4
# 아서	EC	2
# 아야	EC	2
# 아울러	MAG	2
# 악	NNG	1
# 악용	NNG	1
# 악하다	VA	2
# 안	NNG	4
# 안다	NNP	1
# 안식일	NNP	9
# 앉다	VV	1
# 않	VX	2
# 알다	VV	6
# 았	EP	7
# 앞	NNG	3
# 애	NNG	1
# 양식	NNG	2
# 양심	NNP	1
# 양자	NNG	5
# 어	EC	30
# 어기다	VV	1
# 어느	MM	1
# 어다	EC	1
# 어디	NP	1
# 어떠	XR	5
# 어떤	MM	2
# 어떻다	VA	16
# 어서	EC	6
# 어야	EC	3
# 언약	NNG	4
# 얻다	VV	14
# 얼마	NNG	1
# 얽히다	VV	1
# 없다	VA	9
# 없이	MAG	2
# 었	EP	20
# 에	JKB	107
# 에게	JKB	47
# 에게서	JKB	2
# 에서	JKB	31
# 여기	NP	3
# 여기다	VV	5
# 여러	MM	9
# 여섯	NR	1
# 여섯째	NR	2
# 여전히	MAG	1
# 여호와	NNP	3
# 역사	NNG	2
# 연합	NNG	2
# 엿새	NNG	2
# 영광	NNG	3
# 영광	NNP	5
# 영생	NNP	1
# 영원	NNG	6
# 영원	NNP	1
# 영원히	MAG	1
# 영접	NNG	1
# 영혼	NNG	2
# 영화	NNG	7
# 예배	NNP	2
# 예비	NNG	2
# 예수	NNP	6
# 예식	NNG	1
# 예정	NNG	4
# 오	EC	1
# 오	NNP	8
# 오다	VV	4
# 오늘날	NNG	1
# 오락	NNP	2
# 오시	NNP	1
# 오직	MAG	1
# 올라가다	VV	1
# 옳다	VA	1
# 옵	EP	12
# 와	JC	33
# 와	JKB	8
# 완전	NNG	1
# 완전히	MAG	5
# 왕	NNG	5
# 외	NNB	4
# 요	EC	3
# 요구	NNG	5
# 요긴	XR	2
# 용감히	MAG	1
# 우	NNP	1
# 우리	NP	92
# 우리 아버지	NNP	1
# 우상	NNG	1
# 우상	NNP	1
# 우편	NNG	1
# 원수	NNG	1
# 원죄	NNP	2
# 원통히	NA	1
# 위	NNG	3
# 위로	NNG	1
# 위하다	VV	9
# 유용	XR	1
# 유익	NNG	13
# 유일한	NNP	2
# 유죄	NNG	1
# 유하	NNP	1
# 육	NNG	1
# 육	NR	6
# 율법	NNP	1
# 으	NNG	2
# 으나	EC	1
# 으니	EC	2
# 으라	EC	2
# 으로	JKB	34
# 으로부터	JKB	1
# 으로써	JKB	8
# 으므로	EC	1
# 으시	EP	9
# 은	ETM	11
# 은	JX	102
# 은사	NNG	1
# 은즉	EC	1
# 은혜	NNG	7
# 은혜	NNP	4
# 을	ETM	10
# 을	JKO	159
# 을	NNG	2
# 음	ETN	1
# 의	JKG	169
# 의	NNG	4
# 의롭다	VA	7
# 의무	NNG	1
# 의지	NNG	2
# 의형	NNP	1
# 이	EC	3
# 이	JKS	137
# 이	MM	17
# 이	NNP	2
# 이	NP	14
# 이	VCP	191
# 이것	NP	1
# 이기다	VV	1
# 이나	JC	5
# 이나	JX	5
# 이러	XR	1
# 이레	NNP	2
# 이루다	VV	3
# 이루어지다	VV	1
# 이르다	VV	10
# 이름	NNG	6
# 이신	NNP	3
# 이웃	NNG	11
# 이유	NNG	8
# 이익	NNG	1
# 이행	NNG	1
# 인	NNG	1
# 인륜	NNG	2
# 인자	XR	1
# 인종	NNG	1
# 인종	NNP	5
# 인하다	VV	6
# 일	NNB	13
# 일	NNG	17
# 일곱째	NR	1
# 일용	NNG	1
# 일체	MAG	1
# 일컫다	VV	2
# 읽다	VV	2
# 임의	NNG	1
# 임하다	VV	2
# 입다	VV	1
# 입교	NNG	1
# 있다	VV	24
# 있	VX	4
# 잉태	NNG	1
# 자	NNB	13
# 자	NNG	1
# 자기	NP	16
# 자녀	NNG	3
# 자로	NNP	1
# 자리	NNG	1
# 자비	NNG	1
# 자선	NNP	1
# 자손	NNG	1
# 자식	NNG	1
# 자유	NNG	1
# 자청	NNG	1
# 자체	NNG	1
# 작정	NNG	2
# 장수	NNG	1
# 재물	NNG	2
# 저	NP	3
# 저주	NNP	5
# 저희	NP	2
# 적용	NNG	4
# 전하다	VV	3
# 절	NNG	1
# 절기	NNP	1
# 점점	MAG	1
# 접합	NNP	1
# 정조	NNG	1
# 정죄	NNG	1
# 정하다	VV	5
# 제	XPN	69
# 제물	NNP	1
# 제사장	NNG	1
# 제일	NNG	9
# 제자	NNG	1
# 조건	NNG	1
# 족히	MAG	2
# 존경	NNG	1
# 존재	NNG	1
# 종	NNG	1
# 종교	NNG	1
# 종일	NNG	1
# 종일토록	MAG	1
# 좇다	VV	1
# 좋다	VA	2
# 죄	NNG	33
# 죄다	VV	1
# 죄인	NNG	2
# 주	MM	3
# 주	VX	8
# 주관	NNG	1
# 주기	NNP	15
# 주님	NNG	2
# 주도	NNG	1
# 주시	NNP	2
# 주심	NNG	1
# 주의	NNG	5
# 주장	NNG	1
# 주재	NNG	1
# 죽다	VV	5
# 죽음	NNG	2
# 줄	NNB	1
# 중	NNB	17
# 즉시	MAG	1
# 즐거워하다	VV	4
# 즙	NNG	1
# 증가	NNG	1
# 증거	NNG	2
# 증진	NNG	3
# 지	EC	23
# 지	NNG	2
# 지	VX	12
# 지각	NNG	1
# 지극히	MAG	1
# 지니	NNP	1
# 지시	NNG	5
# 지식	NNG	1
# 지옥	NNP	1
# 지위	NNG	15
# 지키다	VV	15
# 지혜	NNG	2
# 직분	NNG	8
# 진노	NNP	5
# 진실	NNG	3
# 진심	NNP	1
# 질	XSN	1
# 집	NNG	1
# 찬송	NNG	1
# 참	MAG	3
# 참다	VV	1
# 참되다	VA	1
# 참여	NNG	6
# 참으로	MAG	1
# 창조	NNG	9
# 창조물	NNG	1
# 처리	NNG	1
# 처음	NNG	2
# 처지	NNG	3
# 첫	MM	3
# 첫	NR	4
# 첫날	NNG	1
# 축	NNG	1
# 축복	NNG	3
# 출생	NNG	1
# 취하다	VV	1
# 치다	VV	12
# 친히	MAG	1
# 칭호	NNP	1
# 쾌락	NNG	1
# 키시	NNP	1
# 타락	NNG	12
# 탄생	NNG	1
# 탐내다	VV	1
# 택하다	VV	1
# 특권	NNG	1
# 특별	XR	1
# 특별히	MAG	6
# 특수	NNG	1
# 특히	MAG	2
# 팔다	VV	6
# 평등	NNG	1
# 포도	NNP	1
# 포함	NNG	2
# 표	NNG	1
# 표시	NNG	1
# 품다	VV	1
# 피차	NNG	1
# 피하다	VV	4
# 하다	VV	96
# 하	VX	4
# 하	XSA	65
# 하	XSV	207
# 하나님	NNG	8
# 하나님	NNP	94
# 하늘	NNG	4
# 하루	NNG	1
# 하사	NNP	1
# 하심	NNG	11
# 하여금	MAG	9
# 한	MM	16
# 한	NNP	1
# 한하다	VV	1
# 함	NNG	5
# 함께	MAG	4
# 합당	XR	6
# 합리	NNG	2
# 항상	MAG	2
# 해	NNG	3
# 행동	NNG	6
# 행복	NNG	1
# 행사	NNG	1
# 행실	NNG	1
# 행하다	VV	12
# 향하다	VV	1
# 허락	NNG	2
# 형벌	NNP	1
# 형상	NNG	1
# 형상	NNP	1
# 혹	MAG	4
# 혹은	MAJ	1
# 홀로	MAG	2
# 화목	NNG	1
# 화평	NNP	1
# 확실히	MAG	1
# 활	NNG	1
# 회개	NNG	1
# 회개	NNP	4
# 효력	NNG	11
# 후	NNG	3
# 훼방	NNG	1
# 흡족	NNG	1
# 흥	NNG	2
# 힘	NNG	2
# 힘쓰다	VV	3
# 힘입다	VV	1

# %% [markdown]
# ## 소요리 문답 워드크라우드 그리기
# 소요리 문답 형태소 분석 결과에서 일반명사(NNG), 고유명사(NNP), 어근(XR)을 대상으로 워드크라우드 그리기를 수행한다.

# %%
# 워드 클라우드 그리기

import sys
from collections import defaultdict
from collections import Counter
import ujson
import wordcloud
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import mmap

FEATURE_POSES = ["NNG", "NNP", "XR"]
MA_KEY1 = "question_ma"
MA_KEY2 = "answer_ma"
PRES_KEY = "president"
NUM_WORDS = 200


def read_president_documents(input_file_name):
    """형태소 분석된 소요리 문답 JSON 파일을 읽어서 돌려준다."""
    
    president_documents = defaultdict(list)

    with open(input_file_name, "r", encoding="utf-8") as input_file:
        for line in tqdm(input_file, desc="Reading documents", 
                         total=get_num_lines(input_file_name)):
            json_obj = ujson.loads(line)
            #president = json_obj[PRES_KEY]
            president = "소요리문답"
            doc_row = json_obj[MA_KEY1]+json_obj[MA_KEY2]
            morphs = []

            for morph_lex, morph_cat in doc_row:
                if morph_cat not in FEATURE_POSES:
                    continue
                    
                morphs.append(morph_lex)
            #print("대상 키워드[{}]".format(morphs))
                    
            president_documents[president].extend(morphs)
            
    presidents = []
    documents = []
    
    for president, document in president_documents.items():
        presidents.append(president)
        documents.append(" ".join(document))
            
    return presidents, documents


def get_num_lines(file_path):
    """빠른 속도로 텍스트 파일의 줄 수를 세어 돌려준다.
    https://blog.nelsonliu.me/2016/07/29/progress-bars-for-python-file-reading-with-tqdm/
    """
    
    fp = open(file_path, "r+")
    buf = mmap.mmap(fp.fileno(), 0)
    lines = 0
    while buf.readline():
        lines += 1
    return lines


def read_mask(mask_file_name):
    """주어진 이름의 파일에서 마스킹 이미지 데이터를 읽어서 돌려준다."""
    
    mask = np.array(Image.open(mask_file_name))
    
    return mask
    

def get_word_counts(documents):
    """Get word counts for given documents."""
    
    word_counts = [Counter(document.split()) for document in documents]
    
    return word_counts


def draw_word_clouds(presidents, word_counts, mask):
    """전직 대통령별 연설문의 워드 클라우드를 그린다."""
    
    font_path = get_font_path()
    
    for president, word_count in zip(presidents, word_counts):
        cloud = build_cloud(word_count, font_path, mask)
        show_cloud(president, cloud, mask)
    

def get_font_path():
    """플랫폼에 따라 글꼴 경로를 설정한다."""

    if sys.platform == "win32" or sys.platform == "win64":
        font_path = "C:/Windows/Fonts/malgun.ttf"
    elif sys.platform == "darwin":
        font_path = "/Library/Fonts/AppleGothic.ttf"
        
    return font_path


def build_cloud(word_counts, font_path, mask):
    """주어진 어휘 계수 결과와 글꼴 경로를 이용하여 워드 클라우드를 생성하여 돌려준다."""


    cloud_gen = wordcloud.WordCloud(background_color="white",
                                    font_path=font_path, max_words=NUM_WORDS,
                                    mask=mask, collocations=False)
    cloud = cloud_gen.generate_from_frequencies(word_counts)

    return cloud


def show_cloud(president, cloud, mask):
    """워드 클라우드를 화면에 표시한다."""
    
    print(president)
    plt.imshow(cloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()   
    
    
def main():
    """소요리 문답을 워드 클라우드로 시각화한다."""
    
    input_file_name = "data/catechism/catechism.ma.txt"
    mask_file_name = "data/catechism/bible.png"
    presidents, documents = read_president_documents(input_file_name)
    mask = read_mask(mask_file_name)
    word_counts = get_word_counts(documents)
    draw_word_clouds(presidents, word_counts, mask)

#  
# 실행
#

main()
# Out:
# Reading documents: 100%|██████████████████████████████████████████████████████████| 107/107 [00:00<00:00, 21441.43it/s]
# 소요리문답
