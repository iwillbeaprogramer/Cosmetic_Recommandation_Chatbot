# %% [markdown]
# ## 크롤링한 소요리문답자료를 형태소분석한다.
#
# ### 크롤링한 소요리문답 JSON파일을 읽어서 문장단위로 나누어 형태소 분석을 한다.
# 1. 소요리문답 JSON파일을 읽는다.
# 1. 질문과 답변을 문장단위로 나누어 형태소 분석을 한다.
# 1. 형태소 분석 결과를 후처리 한다.
# 1. 형태소 분석 결과를 파일로 저장한다.
#
# ### 형태소 분석 결과를 다시 JSON파일로 저장한다.

# %%
from konlpy.tag import Komoran
from konlpy.tag import Hannanum
import itertools
import mmap
# from tqdm import tqdm_notebook
from tqdm import tqdm
import ujson
import re

def split_sentences(text):
    """주어진 텍스트를 문장 단위로 분절하여 돌려준다."""
    
    all_sentences = []
    lines = [line for line in text.strip().splitlines() if line.strip]
    
    for line in lines:
        sentences = re.split("(?<=[.?!]) ", line)
        all_sentences += sentences
    
    return all_sentences


def get_morph_anal(analyzer, text):
    """주어진 형태소 분석기 객체로 텍스트를 문장 단위로 형태소 분석하여 돌려준다."""
    
    sent_morph_anals = []
    sentences = split_sentences(text)
    
    for sentence in sentences:
        sent_morph_anal = analyzer.pos(sentence)
        sent_morph_anals.append(sent_morph_anal)
        
    return sent_morph_anals

def find_sublists(seq, sublist):
    length = len(sublist)
    for index, value in enumerate(seq):
        if value == sublist[0] and seq[index:index+length] == sublist:
            yield index, index+length
            

def replace_sublist(seq, target, replacement, maxreplace=None):
    sublists = find_sublists(seq, target)
    if maxreplace:
        sublists = itertools.islice(sublists, maxreplace)
    for start, end in sublists:
        seq[start:end] = replacement


def get_num_lines(file_path):
    """빠른 속도로 텍스트 파일의 줄 수를 세어 돌려준다.
    https://blog.nelsonliu.me/2016/07/29/progress-bars-for-python-file-reading-with-tqdm/
    """
    
    fp = open(file_path, "r+")
    buf = mmap.mmap(fp.fileno(), 0)
    lines = 0
    while buf.readline():
        lines += 1
    return lines

def refine_answer(answer):
    """소요리문답의 성경구절이 있는 부분을 형태소분석을 위해 제거"""
    
    #print("소스:{}".format(answer))
    find_str = "(" 
    str_index = answer.find(find_str)
    if str_index > -1:
        answer_desc = answer[:str_index]
    else:
        answer_desc = answer
        
    refined_answer = answer_desc.translate({ ord('「'): '',ord('」'): ' ' })
        
    return refined_answer
    
def parse_row(row):
    """주어진 행을 열 단위로 분절하여 돌려준다."""

    qna_no = row["no"]
    question_source = row["question"]
    answer_source = row["answer"]
    
    return qna_no, question_source, answer_source


def compose_json_doc(qna_no, question_source, answer_source, refine_answer, question_ma, answer_ma):
    """주어진 문서 요소들로 JSON 문서를 생성하여 돌려준다."""
    
    json_doc = {
        "no": int(qna_no), 
        "question": question_source, 
        "answer": answer_source, 
        "refine_answer": refine_answer, 
        "question_ma": question_ma, 
        "answer_ma": answer_ma              
    }   
        
    return json_doc


def write_json_doc(output_file, json_doc):
    """주어진 JSON 문서를 출력 파일에 기록한다."""
        
    json_str = ujson.dumps(json_doc, ensure_ascii=False)
    print(json_str, file=output_file)

#=============================================================#
# 부분 리스트 치환에 의한 형태소 분석 결과 후처리
post_proc_pairs = [
    ([('신', 'XPN'), ('구약 성경', 'NNP')], [('신구약', 'NNG'), ('성경', 'NNG')]),
    ([('제', 'XPN'), ('일', 'NNB'), ('계명', 'NNG')], [('제 일 계명', 'NNG')]),
    ([('제', 'XPN'), ('이', 'MM'), ('계명', 'NNG')], [('제 이 계명', 'NNG')]),
    ([('제', 'XPN'), ('삼', 'NR'), ('계명', 'NNG')], [('제 삼 계명', 'NNG')]),
    ([('제', 'XPN'), ('사', 'NNG'), ('계명', 'NNG')], [('제 사 계명', 'NNG')]),
    ([('제', 'XPN'), ('오', 'NR'), ('계명', 'NNG')], [('제 오 계명', 'NNG')]),
    ([('제', 'XPN'), ('육', 'NR'), ('계명', 'NNG')], [('제 육 계명', 'NNG')]),
    ([('제', 'XPN'), ('치', 'VV'), ('ㄹ', 'ETM'), ('계명', 'NNG')], [('제 칠 계명', 'NNG')]),
    ([('제', 'XPN'), ('팔', 'VV'), ('ㄹ', 'ETM'), ('계명', 'NNG')], [('제 팔 계명', 'NNG')]),
    ([('제', 'XPN'), ('구', 'NNG'), ('계명', 'NNG')], [('제 구 계명', 'NNG')]),
    ([('제', 'XPN'), ('십', 'NR'), ('계명', 'NNG')], [('제 십 계명', 'NNG')]),
    ([('첫','MM'), ('말씀','NNG')], [('첫','NR'),('말씀','NNG')]),
    ([('첫','MM'), ('기도','NNG')], [('첫','NR'),('기도','NNG')])
]


input_file_name = "data/crawling/catechism.txt"
output_file_name = "data/catechism/catechism.ma.txt"
komoran = Komoran()
hannanum = Hannanum()


with open(input_file_name, "r", encoding="utf-8") as input_file, \
        open(output_file_name, "w", encoding="utf-8") as output_file:
        
    for line in tqdm(input_file, desc="Reading documents", 
                                  total=get_num_lines(input_file_name)):
        
        doc_row = ujson.loads(line)
        qna_no, question_source, answer_source = parse_row(doc_row)
        refined_answer = refine_answer(answer_source)        

        #print("질문[{}]:{}".format(qna_no, question_source.translate({ ord('「'): '',ord('」'): ' ' })))
        #print("답변:{}".format(refined_answer))
        
        question_ma = get_morph_anal(komoran, question_source.translate({ ord('「'): '',ord('」'): ' ' }) )
        # 소요리 문답 질문에 대한 부분 리스트 치환에 의한 형태소 분석 결과 후처리
        for src, dst in post_proc_pairs:
            replace_sublist(question_ma[0], src, dst)

        answer_ma = get_morph_anal(komoran, refined_answer)
        # 소요리 문답 답변에 대한 부분 리스트 치환에 의한 형태소 분석 결과 후처리
        for src, dst in post_proc_pairs:
            replace_sublist(answer_ma[0], src, dst)

        print("질문[{}]:{}".format(qna_no, question_ma[0]))
        print("답변:{}".format(answer_ma[0]))
        print("{}".format("="*80))
        json_doc = compose_json_doc(qna_no, question_source, answer_source, refined_answer, question_ma[0], answer_ma[0])
        write_json_doc(output_file, json_doc)
# Out:
# Reading documents:  21%|████████████▌                                                | 22/107 [00:00<00:00, 206.16it/s]
# 질문[1]:[('사람', 'NNG'), ('의', 'JKG'), ('제일', 'NNG'), ('되', 'VV'), ('는', 'ETM'), ('목적', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('사람', 'NNG'), ('의', 'JKG'), ('제일', 'NNG'), ('되', 'VV'), ('는', 'ETM'), ('목적', 'NNG'), ('은', 'JX'), ('하나님', 'NNG'), ('을', 'JKO'), ('영화', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('영원', 'NNG'), ('하', 'XSV'), ('도록', 'EC'), ('그', 'NP'), ('를', 'JKO'), ('즐거워하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[2]:[('하나님', 'NNP'), ('께서', 'JKS'), ('무슨', 'MM'), ('규칙', 'NNG'), ('을', 'JKO'), ('우리', 'NP'), ('에게', 'JKB'), ('주', 'VX'), ('시', 'EP'), ('어', 'EC'), ('어떻', 'VA'), ('게', 'EC'), ('자기', 'NP'), ('를', 'JKO'), ('영화', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('고', 'EC'), ('즐거워하', 'VV'), ('ㄹ', 'ETM'), ('것', 'NNB'), ('을', 'JKO'), ('지시', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('신구약', 'NNG'), ('성경', 'NNP'), ('에', 'JKB'), ('기재', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETM'), ('하나님', 'NNP'), ('의', 'JKG'), ('말씀', 'NNG'), ('은', 'JX'), ('어떻', 'VA'), ('게', 'EC'), ('우리', 'NP'), ('가', 'JKS'), ('그', 'NP'), ('를', 'JKO'), ('영화', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('고', 'EC'), ('즐거워하', 'VV'), ('ㄹ', 'ETM'), ('것', 'NNB'), ('을', 'JKO'), ('지시', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('유일한', 'NNP'), ('규칙', 'NNG'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[3]:[('성경', 'NNP'), ('이', 'JKS'), ('제일', 'NNG'), ('요긴', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('교훈', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('성경', 'NNP'), ('이', 'JKS'), ('제일', 'NNG'), ('요긴', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('교훈', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('사람', 'NNG'), ('이', 'JKS'), ('하나님', 'NNP'), ('에', 'JKB'), ('대하', 'VV'), ('아', 'EC'), ('어떻', 'VA'), ('게', 'EC'), ('믿', 'VV'), ('을', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('하나님', 'NNP'), ('께서', 'JKS'), ('사람', 'NNG'), ('에게', 'JKB'), ('요구', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('본분', 'NNG'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[4]:[('하나님', 'NNP'), ('은', 'JX'), ('어떤', 'MM'), ('분', 'NNB'), ('이', 'VCP'), ('시', 'EP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('은', 'JX'), ('신', 'XPN'), ('이신', 'NNP'), ('데', 'NNB'), ('그', 'NP'), ('의', 'JKG'), ('존재', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('지혜', 'NNG'), ('와', 'JC'), ('권능', 'NNG'), ('과', 'JC'), ('거룩', 'XR'), ('하', 'XSA'), ('시', 'EP'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('공의', 'NNG'), ('와', 'JC'), ('인자', 'XR'), ('하', 'XSA'), ('시', 'EP'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('진실', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('이', 'JKS'), ('무한', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('며', 'EC'), (',', 'SP'), ('무궁', 'XR'), ('하', 'XSA'), ('시', 'EP'), ('며', 'EC'), (',', 'SP'), ('불변', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[5]:[('하나님', 'NNP'), ('한', 'MM'), ('분', 'NNB'), ('밖에', 'JX'), ('또', 'MAJ'), ('다른', 'MM'), ('하나님', 'NNP'), ('이', 'JKS'), ('계시', 'VX'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('한', 'MM'), ('분', 'NNB'), ('뿐', 'NNB'), ('이', 'VCP'), ('시', 'EP'), ('니', 'EC'), ('참되', 'VA'), ('시', 'EP'), ('며', 'EC'), ('살', 'VV'), ('아', 'EC'), ('계시', 'VV'), ('ㄴ', 'ETM'), ('하나님', 'NNG'), ('이', 'VCP'), ('시', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[6]:[('하나님', 'NNP'), ('의', 'JKG'), ('신격', 'NNP'), ('에', 'JKB'), ('몇', 'MM'), ('위', 'NNG'), ('가', 'JKS'), ('계시', 'VX'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('의', 'JKG'), ('신격', 'NNP'), ('에', 'JKB'), ('삼위', 'NNP'), ('가', 'JKS'), ('계시', 'VV'), ('니', 'EC'), ('성부', 'NNP'), ('와', 'JC'), ('성자', 'NNP'), ('와', 'JC'), ('성령', 'NNP'), ('이신', 'NNP'), ('데', 'NNB'), ('이', 'MM'), ('삼위', 'NNP'), ('는', 'JX'), ('한', 'MM'), ('하나님', 'NNG'), ('이', 'VCP'), ('시', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[7]:[('하나님', 'NNP'), ('의', 'JKG'), ('예정', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('의', 'JKG'), ('예정', 'NNG'), ('은', 'JX'), ('그', 'MM'), ('뜻대로', 'MAG'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('영원', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('경륜', 'NNP'), ('이신', 'NNP'), ('데', 'NNB'), (',', 'SP'), ('이', 'NP'), ('로', 'JKB'), ('말미암', 'VV'), ('아', 'EC'), ('자기', 'NP'), ('의', 'JKG'), ('영광', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('아', 'EC'), ('모든', 'MM'), ('되', 'VV'), ('어', 'EC'), ('가', 'VX'), ('는', 'ETM'), ('일', 'NNG'), ('을', 'JKO'), ('미리', 'MAG'), ('작정', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[8]:[('하나님', 'NNP'), ('께서', 'JKS'), ('그', 'MM'), ('예정', 'NNG'), ('을', 'JKO'), ('어떻', 'VA'), ('게', 'EC'), ('이루', 'VV'), ('시', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('께서', 'JKS'), ('그', 'MM'), ('예정', 'NNG'), ('을', 'JKO'), ('이루', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('창조', 'NNG'), ('와', 'JC'), ('섭리', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('일', 'NNG'), ('로', 'JKB'), ('하', 'VV'), ('시', 'EP'), ('ㄴ다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[9]:[('창조', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('일', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('창조', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('일', 'NNB'), ('은', 'JX'), ('하나님', 'NNP'), ('께서', 'JKS'), ('엿새', 'NNG'), ('동안', 'NNG'), ('에', 'JKB'), ('아무', 'MM'), ('것', 'NNB'), ('도', 'JX'), ('없', 'VA'), ('는', 'ETM'), ('중', 'NNB'), ('에서', 'JKB'), ('그', 'MM'), ('권능', 'NNG'), ('의', 'JKG'), ('말씀', 'NNG'), ('으로써', 'JKB'), ('만물', 'NNG'), ('을', 'JKO'), ('지', 'VX'), ('으시', 'EP'), ('ㄴ', 'ETM'), ('일', 'NNB'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('다', 'MAG'), ('매우', 'MAG'), ('좋', 'VA'), ('았', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[10]:[('하나님', 'NNP'), ('께서', 'JKS'), ('사람', 'NNG'), ('을', 'JKO'), ('어떻', 'VA'), ('게', 'EC'), ('지', 'VX'), ('으시', 'EP'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('께서', 'JKS'), ('사람', 'NNG'), ('을', 'JKO'), ('남녀', 'NNG'), ('로', 'JKB'), ('지', 'VX'), ('으시', 'EP'), ('되', 'EC'), ('자기', 'NP'), ('의', 'JKG'), ('형상', 'NNP'), ('대로', 'JX'), ('지식', 'NNG'), ('과', 'JC'), ('공의', 'NNG'), ('와', 'JC'), ('거룩', 'XR'), ('하', 'XSA'), ('ㅁ', 'ETN'), ('이', 'JKS'), ('있', 'VV'), ('게', 'EC'), ('지', 'NNG'), ('으', 'NNG'), ('사', 'NNG'), ('모든', 'MM'), ('생물', 'NNG'), ('을', 'JKO'), ('주관', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('었', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[11]:[('하나님', 'NNP'), ('의', 'JKG'), ('섭리', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('일', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('의', 'JKG'), ('섭리', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('일', 'NNB'), ('은', 'JX'), ('지극히', 'MAG'), ('거룩', 'XR'), ('하', 'XSA'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('지혜', 'NNG'), ('와', 'JC'), ('권능', 'NNG'), ('으로써', 'JKB'), ('모든', 'MM'), ('창조물', 'NNG'), ('과', 'JC'), ('그', 'MM'), ('모', 'MM'), ('들', 'VV'), ('ㄴ', 'ETM'), ('행동', 'NNG'), ('을', 'JKO'), ('보존', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('며', 'EC'), ('치', 'VV'), ('리', 'EC'), ('하', 'VX'), ('시', 'EP'), ('는', 'ETM'), ('일', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[12]:[('사람', 'NNG'), ('이', 'JKS'), ('창조', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETM'), ('보', 'VV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('을', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('하나님', 'NNP'), ('께서', 'JKS'), ('저', 'NP'), ('를', 'JKO'), ('향하', 'VV'), ('아', 'EC'), ('섭리', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('중', 'NNB'), ('에', 'JKB'), ('무슨', 'MM'), ('특별', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('작정', 'NNG'), ('을', 'JKO'), ('하', 'VV'), ('시', 'EP'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('께서', 'JKS'), ('사람', 'NNG'), ('을', 'JKO'), ('창조', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('후', 'NNG'), ('에', 'JKB'), ('완전히', 'MAG'), ('순', 'NNG'), ('복', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('을', 'JKO'), ('조건', 'NNG'), ('으로', 'JKB'), ('삼', 'VV'), ('아', 'EC'), ('생명', 'NNG'), ('의', 'JKG'), ('언약', 'NNG'), ('을', 'JKO'), ('맺', 'VV'), ('고', 'EC'), ('선악', 'NNG'), ('을', 'JKO'), ('분별', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('나무', 'NNG'), ('의', 'JKG'), ('실과', 'NNG'), ('를', 'JKO'), ('먹', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('사망', 'NNG'), ('의', 'JKG'), ('벌', 'NNG'), ('로써', 'JKB'), ('금하', 'VV'), ('시', 'EP'), ('었', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[13]:[('우리', 'NP'), ('시조', 'NNG'), ('가', 'JKS'), ('창조', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETM'), ('보', 'VV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에', 'JKB'), ('그대로', 'MAG'), ('있', 'VX'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('우리', 'NP'), ('시조', 'NNG'), ('가', 'JKS'), ('임의', 'NNG'), ('대로', 'JX'), ('자유', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('인하', 'VV'), ('아', 'EC'), ('하나님', 'NNP'), ('께', 'JKB'), ('죄', 'NNG'), ('를', 'JKO'), ('범하', 'VV'), ('므로', 'EC'), ('창조', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETM'), ('보', 'VV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('타락', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[14]:[('죄', 'NNG'), ('가', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('죄', 'NNG'), ('는', 'JX'), ('하나님', 'NNP'), ('의', 'JKG'), ('법', 'NNG'), ('을', 'JKO'), ('순종', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('에', 'JKB'), ('부족', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이나', 'JX'), ('혹', 'MAG'), ('어기', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[15]:[('우리', 'NP'), ('시조', 'NNG'), ('가', 'JKS'), ('창조', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETM'), ('보', 'VV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('타락', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('되', 'VV'), ('ㄴ', 'ETM'), ('죄', 'NNG'), ('가', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('우리', 'NP'), ('시조', 'NNG'), ('가', 'JKS'), ('창조', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETM'), ('보', 'VV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('타락', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('되', 'VV'), ('ㄴ', 'ETM'), ('죄', 'NNG'), ('는', 'JX'), ('그', 'MM'), ('금하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('실과', 'NNG'), ('를', 'JKO'), ('먹', 'VV'), ('은', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[16]:[('모든', 'MM'), ('인종', 'NNP'), ('은', 'JX'), ('아담', 'NNP'), ('의', 'JKG'), ('첫', 'MM'), ('범죄', 'NNG'), ('중', 'NNB'), ('에', 'JKB'), ('타락', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('아담', 'NNP'), ('으로', 'JKB'), ('더불', 'VV'), ('어', 'EC'), ('언약', 'NNG'), ('을', 'JKO'), ('세우', 'VV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('저', 'NP'), ('만', 'JX'), ('위하', 'VV'), ('아', 'EC'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('아니요', 'IC'), (',', 'SP'), ('그 후', 'NNP'), ('자손', 'NNG'), ('까지', 'JX'), ('위하', 'VV'), ('아', 'EC'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('므로', 'EC'), ('그', 'NP'), ('로부터', 'JKB'), ('보통', 'MAG'), ('생육', 'NNG'), ('법', 'NNG'), ('으로', 'JKB'), ('출생', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('인종', 'NNP'), ('은', 'JX'), ('모두', 'MAG'), ('그', 'NP'), ('의', 'JKG'), ('안', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('어서', 'EC'), ('그', 'NP'), ('의', 'JKG'), ('첫', 'MM'), ('범죄', 'NNG'), ('에', 'JKB'), ('참여', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('그', 'NP'), ('와', 'JKB'), ('함께', 'MAG'), ('타락', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[17]:[('이', 'MM'), ('타락', 'NNG'), ('이', 'JKS'), ('인종', 'NNP'), ('으로', 'JKB'), ('하여금', 'MAG'), ('어떠', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에', 'JKB'), ('이르', 'VV'), ('게', 'EC'), ('하', 'VV'), ('았', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('이', 'MM'), ('타락', 'NNG'), ('은', 'JX'), ('인종', 'NNP'), ('으로', 'JKB'), ('하여금', 'MAG'), ('죄', 'NNG'), ('와', 'JC'), ('비참', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('처지', 'NNG'), ('에', 'JKB'), ('이르', 'VV'), ('게', 'EC'), ('하', 'VV'), ('았', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[18]:[('사람', 'NNG'), ('이', 'JKS'), ('타락', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('죄', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('사람', 'NNG'), ('이', 'JKS'), ('타락', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('죄', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('아담', 'NNP'), ('의', 'JKG'), ('첫', 'MM'), ('범죄', 'NNG'), ('에', 'JKB'), ('유죄', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('근본', 'NNG'), ('의', 'NNG'), ('가', 'JKS'), ('없', 'VA'), ('는', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('오', 'VV'), ('ㄴ', 'ETM'), ('성품', 'NNP'), ('이', 'JKS'), ('부패', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('이것', 'NP'), ('은', 'JX'), ('보통', 'NNG'), ('으로', 'JKB'), ('원죄', 'NNP'), ('이', 'VCP'), ('라', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('요', 'EC'), (',', 'SP'), ('아울러', 'MAG'), ('원죄', 'NNP'), ('로', 'JKB'), ('말미암', 'VV'), ('아', 'EC'), ('나오', 'VV'), ('는', 'ETM'), ('모든', 'MM'), ('죄', 'VV'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[19]:[('사람', 'NNG'), ('이', 'JKS'), ('타락', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('비참', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('모든', 'MM'), ('인종', 'NNP'), ('이', 'JKS'), ('타락', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('인하', 'VV'), ('아', 'EC'), ('하나님', 'NNP'), ('과', 'JC'), ('교제', 'NNG'), ('가', 'JKS'), ('끊어지', 'VV'), ('고', 'EC'), ('또', 'MAJ'), ('그', 'NP'), ('의', 'JKG'), ('진노', 'NNP'), ('와', 'JC'), ('저주', 'NNP'), ('아래', 'NNG'), ('있', 'VV'), ('어서', 'EC'), ('생전', 'NNG'), ('에', 'JKB'), ('모든', 'MM'), ('비참', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('사망', 'NNG'), ('과', 'JC'), ('영원', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('지옥', 'NNP'), ('의', 'JKG'), ('벌', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('게', 'EC'), ('되', 'VV'), ('었', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[20]:[('하나님', 'NNP'), ('께서', 'JKS'), ('모든', 'MM'), ('인종', 'NNG'), ('을', 'JKO'), ('죄', 'NNG'), ('와', 'JC'), ('비참', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('멸망', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('버려두', 'VV'), ('시', 'EP'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('께서', 'JKS'), ('홀로', 'MAG'), ('그', 'MM'), ('선', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('뜻대로', 'MAG'), ('영원', 'NNP'), ('부터', 'JX'), ('구속', 'NNG'), ('받', 'VV'), ('을', 'ETM'), ('자', 'NNB'), ('들', 'XSN'), ('을', 'JKO'), ('영생', 'NNP'), ('얻', 'VV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('려고', 'EC'), ('서', 'VV'), ('ㄴ', 'ETM'), ('택하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('은혜', 'NNP'), ('의', 'JKG'), ('언약', 'NNG'), ('을', 'JKO'), ('세우', 'VV'), ('시', 'EP'), ('어서', 'EC'), ('구속자', 'NNG'), ('로', 'JKB'), ('말미암', 'VV'), ('아', 'EC'), ('저희', 'NP'), ('를', 'JKO'), ('죄', 'NNG'), ('와', 'JC'), ('비참', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에서', 'JKB'), ('건', 'NNB'), ('지', 'VX'), ('어', 'EC'), ('내', 'VX'), ('시', 'EP'), ('고', 'EC'), ('구원', 'NNP'), ('의', 'JKG'), ('자리', 'NNG'), ('에', 'JKB'), ('이르', 'VV'), ('게', 'EC'), ('하', 'VV'), ('려', 'EC'), ('하', 'VV'), ('시', 'EP'), ('었', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[21]:[('하나님', 'NNP'), ('의', 'JKG'), ('선택', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('자', 'NNB'), ('의', 'JKG'), ('구속자', 'NNG'), ('가', 'JKS'), ('누구', 'NNP'), ('신가', 'NNP'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('의', 'JKG'), ('선택', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('자', 'NNB'), ('의', 'JKG'), ('구속자', 'NNG'), ('는', 'JX'), ('다만', 'MAJ'), ('주', 'MM'), ('예수', 'NNP'), ('그리스도', 'NNP'), ('뿐', 'NNB'), ('이', 'VCP'), ('시', 'EP'), ('ㄴ데', 'EC'), (',', 'SP'), ('그', 'NP'), ('는', 'JX'), ('하나님', 'NNP'), ('의', 'JKG'), ('영원', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('아들', 'NNG'), ('로서', 'JKB'), ('사람', 'NNG'), ('이', 'JKS'), ('되', 'VV'), ('시', 'EP'), ('었', 'EP'), ('으니', 'EC'), ('그', 'MM'), ('후', 'NNG'), ('로', 'JKB'), ('한', 'MM'), ('위', 'NNG'), ('에', 'JKB'), ('특수', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('두', 'MM'), ('가지', 'NNB'), ('성품', 'NNP'), ('이', 'JKS'), ('있', 'VV'), ('어', 'EC'), ('영원', 'NNG'), ('하', 'XSV'), ('도록', 'EC'), ('하나님', 'NNG'), ('이', 'VCP'), ('시', 'EP'), ('오', 'EC'), ('사람', 'NNG'), ('이', 'VCP'), ('시', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[22]:[('그리스도', 'NNP'), ('께서', 'JKS'), ('하나님', 'NNP'), ('의', 'JKG'), ('아들', 'NNG'), ('로서', 'JKB'), ('어떻', 'VA'), ('게', 'EC'), ('사람', 'NNG'), ('이', 'JKS'), ('되', 'VV'), ('시', 'EP'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('의', 'JKG'), ('아들', 'NNG'), ('그리스도', 'NNP'), ('께서', 'JKS'), ('사람', 'NNG'), ('이', 'JKS'), ('되', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('참', 'MAG'), ('몸', 'NNG'), ('과', 'JC'), ('지각', 'NNG'), ('있', 'VV'), ('는', 'ETM'), ('영혼', 'NNG'), ('을', 'JKO'), ('취하', 'VV'), ('사', 'EC'), ('성령', 'NNP'), ('의', 'NNG'), ('권능', 'NNG'), ('으로', 'JKB'), ('동정녀', 'NNG'), ('마리아', 'NNP'), ('에게', 'JKB'), ('잉태', 'NNG'), ('되', 'XSV'), ('어', 'EC'), ('탄생', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('었', 'EP'), ('으나', 'EC'), ('죄', 'NNG'), ('는', 'JX'), ('없', 'VA'), ('으시', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[23]:[('그리스도', 'NNP'), ('께서', 'JKS'), ('우리', 'NP'), ('의', 'JKG'), ('구속자', 'NNG'), ('로', 'JKB'), ('무슨', 'MM'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('그리스도', 'NNP'), ('께서', 'JKS'), ('우리', 'NP'), ('의', 'JKG'), ('구속자', 'NNG'), ('로', 'JKB'), ('선지자', 'NNG'), ('와', 'JC'), ('제사장', 'NNG'), ('과', 'JC'), ('왕', 'NNG'), ('의', 'JKG'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('되', 'EC'), ('낮', 'VA'), ('아', 'EC'), ('지', 'VX'), ('시', 'EP'), ('고', 'EC'), ('높', 'VA'), ('아', 'EC'), ('지', 'VX'), ('시', 'EP'), ('ㄴ', 'ETM'), ('두', 'MM'), ('지위', 'NNG'), ('에서', 'JKB'), ('하', 'VV'), ('시', 'EP'), ('ㄴ다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[24]:[('그리스도', 'NNP'), ('께서', 'JKS'), ('어떻', 'VA'), ('게', 'EC'), ('선지자', 'NNG'), ('의', 'JKG'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('그리스도', 'NNP'), ('께서', 'JKS'), ('선지자', 'NNG'), ('의', 'JKG'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('우리', 'NP'), ('를', 'JKO'), ('구원', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('고자', 'EC'), ('하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('하나님', 'NNP'), ('의', 'JKG'), ('뜻', 'NNG'), ('을', 'JKO'), ('그', 'MM'), ('말씀', 'NNG'), ('과', 'JC'), ('성령', 'NNP'), ('으로', 'JKB'), ('말미암', 'VV'), ('아', 'EC'), ('우리', 'NP'), ('에게', 'JKB'), ('나타내', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[25]:[('그리스도', 'NNP'), ('께서', 'JKS'), ('어떻', 'VA'), ('게', 'EC'), ('제', 'XPN'), ('사장', 'NNP'), ('의', 'JKG'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('그리스도', 'NNP'), ('께서', 'JKS'), ('제', 'XPN'), ('사장', 'NNP'), ('의', 'JKG'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('단번에', 'MAG'), ('자기', 'NP'), ('를', 'JKO'), ('제물', 'NNP'), ('로', 'JKB'), ('드리', 'VV'), ('어', 'EC'), ('하나님', 'NNP'), ('의', 'JKG'), ('공의', 'NNG'), ('에', 'JKB'), ('만족', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('하', 'VV'), ('며', 'EC'), ('우리', 'NP'), ('를', 'JKO'), ('하나님', 'NNP'), ('으로', 'JKB'), ('더불', 'VV'), ('어', 'EC'), ('화목', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('또', 'MAJ'), ('우리', 'NP'), ('를', 'JKO'), ('위하', 'VV'), ('아', 'EC'), ('항상', 'MAG'), ('간구', 'XR'), ('하', 'XSA'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[26]:[('그리스도', 'NNP'), ('께서', 'JKS'), ('어떻', 'VA'), ('게', 'EC'), ('왕', 'NNG'), ('의', 'JKG'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('그리스도', 'NNP'), ('께서', 'JKS'), ('왕', 'NNG'), ('의', 'JKG'), ('직분', 'NNG'), ('을', 'JKO'), ('행하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('우리', 'NP'), ('로', 'JKB'), ('하여금', 'MAG'), ('자기', 'NP'), ('에게', 'JKB'), ('복종', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('리', 'NNB'), ('를', 'JKO'), ('다스리', 'VV'), ('시', 'EP'), ('며', 'EC'), ('보호', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('고', 'EC'), ('자기', 'NP'), ('와', 'JKB'), ('우리', 'NP'), ('의', 'JKG'), ('모든', 'MM'), ('원수', 'NNG'), ('를', 'JKO'), ('막', 'VV'), ('아', 'EC'), ('이기', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[27]:[('그리스도', 'NNP'), ('의', 'JKG'), ('낮', 'VA'), ('아', 'EC'), ('지', 'VX'), ('시', 'EP'), ('ㅁ', 'ETN'), ('이', 'JKS'), ('어떠', 'XR'), ('하', 'XSA'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('그리스도', 'NNP'), ('의', 'JKG'), ('낮', 'VA'), ('아', 'EC'), ('지', 'VX'), ('시', 'EP'), ('ㅁ', 'ETN'), ('은', 'JX'), ('곧', 'MAG'), ('그', 'NP'), ('의', 'JKG'), ('강생', 'NNP'), ('하심', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('또한', 'MAJ'), ('비천', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('지위', 'NNG'), ('에', 'JKB'), ('나', 'VV'), ('시', 'EP'), ('어서', 'EC'), ('율법', 'NNP'), ('아래', 'NNG'), ('복종', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('고', 'EC'), ('금', 'NNG'), ('생', 'XSN'), ('에', 'JKB'), ('여러', 'MM'), ('가지', 'NNB'), ('비참', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('하나님', 'NNP'), ('의', 'JKG'), ('진노', 'NNP'), ('하심', 'NNG'), ('과', 'JC'), ('십자가', 'NNP'), ('에서', 'JKB'), ('저주', 'NNP'), ('의', 'JKG'), ('죽음', 'NNG'), ('을', 'NNG'), ('받', 'VV'), ('으시', 'EP'), ('고', 'EC'), ('묻히', 'VV'), ('시', 'EP'), ('어서', 'EC'), ('얼마', 'NNG'), ('동안', 'NNG'), ('죽음', 'NNG'), ('의', 'JKG'), ('권세', 'NNG'), ('아래', 'NNG'), ('거하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[28]:[('그리스도', 'NNP'), ('의', 'JKG'), ('높', 'VA'), ('아', 'EC'), ('지', 'VX'), ('시', 'EP'), ('ㅁ', 'ETN'), ('이', 'JKS'), ('어떠', 'XR'), ('하', 'XSA'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('그리스도', 'NNP'), ('의', 'JKG'), ('높', 'VA'), ('아', 'EC'), ('지', 'VX'), ('시', 'EP'), ('ㅁ', 'ETN'), ('은', 'JX'), ('사흘', 'NNG'), ('만', 'NNB'), ('에', 'JKB'), ('죽', 'VV'), ('은', 'ETM'), ('가운데', 'NNG'), ('서', 'JKB'), ('다시', 'MAG'), ('살아나', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('하늘', 'NNG'), ('로', 'JKB'), ('올라가', 'VV'), ('아', 'EC'), ('신', 'NNG'), ('것', 'NNB'), ('과', 'JKB'), ('하나님', 'NNP'), ('아버지', 'NNG'), ('의', 'JKG'), ('우편', 'NNG'), ('에', 'JKB'), ('앉', 'VV'), ('아', 'EC'), ('계시', 'VV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('마지막', 'NNG'), ('날', 'NNG'), ('에', 'JKB'), ('세상', 'NNG'), ('을', 'JKO'), ('심판', 'NNG'), ('하', 'XSV'), ('러', 'EC'), ('오시', 'NNP'), ('는', 'JX'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[29]:[('우리', 'NP'), ('로', 'JKB'), ('어떻', 'VA'), ('게', 'EC'), ('그리스도', 'NNP'), ('의', 'JKG'), ('사신', 'NNP'), ('구속', 'NNG'), ('에', 'JKB'), ('참여', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('우리', 'NP'), ('로', 'JKB'), ('그리스도', 'NNP'), ('의', 'JKG'), ('사신', 'NNP'), ('구속', 'NNG'), ('에', 'JKB'), ('참여', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('그', 'NP'), ('의', 'JKG'), ('성령', 'NNP'), ('께서', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('구속', 'NNG'), ('을', 'NNG'), ('효력', 'NNG'), ('있', 'VV'), ('게', 'EC'), ('적용', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('인하', 'VV'), ('ㅁ', 'ETN'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[30]:[('성령', 'NNP'), ('께서', 'JKS'), ('그리스도', 'NNP'), ('의', 'JKG'), ('사신', 'NNP'), ('구속', 'NNG'), ('을', 'JKO'), ('우리', 'NP'), ('에게', 'JKB'), ('어떻', 'VA'), ('게', 'EC'), ('적용', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('성령', 'NNP'), ('께서', 'JKS'), ('그리스도', 'NNP'), ('의', 'JKG'), ('사신', 'NNP'), ('구속', 'NNG'), ('을', 'JKO'), ('우리', 'NP'), ('에게', 'JKB'), ('적용', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('우리', 'NP'), ('안', 'NNG'), ('에', 'JKB'), ('믿음', 'NNG'), ('을', 'JKO'), ('일', 'NNG'), ('으', 'NNG'), ('키시', 'NNP'), ('이', 'VCP'), ('고', 'EC'), ('또', 'MAJ'), ('효력', 'NNG'), ('있', 'VV'), ('는', 'ETM'), ('부르', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('으로써', 'JKB'), ('우리', 'NP'), ('를', 'JKO'), ('그리스도', 'NNP'), ('와', 'JC'), ('연합', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[31]:[('효력', 'NNG'), ('있', 'VV'), ('는', 'ETM'), ('부름', 'NNG'), ('심', 'NNP'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('효력', 'NNG'), ('있', 'VV'), ('는', 'ETM'), ('부르', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('은', 'JX'), ('하나님', 'NNP'), ('의', 'JKG'), ('신이', 'NNP'), ('하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('일', 'NNB'), ('이', 'VCP'), ('니', 'EC'), ('우리', 'NP'), ('의', 'JKG'), ('죄', 'NNG'), ('와', 'JC'), ('비참', 'NNG'), ('을', 'JKO'), ('깨닫', 'VV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('또', 'MAJ'), ('우리', 'NP'), ('의', 'JKG'), ('마음', 'NNG'), ('을', 'JKO'), ('밝히', 'VV'), ('어', 'EC'), ('그리스도', 'NNP'), ('를', 'JKO'), ('알', 'VV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('우리', 'NP'), ('의', 'JKG'), ('의지', 'NNG'), ('를', 'JKO'), ('새롭', 'VA'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('우리', 'NP'), ('를', 'JKO'), ('권', 'NNB'), ('하사', 'NNP'), ('능히', 'MAG'), ('복음', 'NNP'), ('중', 'NNB'), ('에', 'JKB'), ('값', 'NNG'), ('없이', 'MAG'), ('주시', 'NNP'), ('는', 'JX'), ('예수', 'NNP'), ('그리스도', 'NNP'), ('를', 'JKO'), ('믿', 'VV'), ('도록', 'EC'), ('하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[32]:[('효력', 'NNG'), ('있', 'VV'), ('는', 'ETM'), ('부르', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETM'), ('자', 'NNB'), ('들', 'XSN'), ('은', 'JX'), ('금', 'NNG'), ('생', 'XSN'), ('에서', 'JKB'), ('무슨', 'MM'), ('유익', 'NNG'), ('을', 'JKO'), ('얻', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('효력', 'NNG'), ('있', 'VV'), ('는', 'ETM'), ('부르', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETM'), ('자', 'NNB'), ('들', 'XSN'), ('은', 'JX'), ('금', 'NNG'), ('생', 'XSN'), ('에서', 'JKB'), ('의롭', 'VA'), ('다', 'EC'), ('하심', 'NNG'), ('과', 'JC'), ('양자', 'NNG'), ('로', 'JKB'), ('삼', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('하심', 'NNG'), ('을', 'JKO'), ('얻', 'VV'), ('고', 'EC'), ('또', 'MAJ'), ('금', 'NNG'), ('생', 'XSN'), ('에서', 'JKB'), ('이', 'NP'), ('와', 'JKB'), ('함께', 'MAG'), ('받', 'VV'), ('는', 'ETM'), ('여러', 'MM'), ('가지', 'NNB'), ('유익', 'NNG'), ('과', 'JC'), ('여기', 'NP'), ('서', 'JKB'), ('나오', 'VV'), ('는', 'ETM'), ('여러', 'MM'), ('가지', 'NNB'), ('유익', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('는다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[33]:[('의롭', 'VA'), ('다', 'EC'), ('하', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('은', 'JX'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('의롭', 'VA'), ('다', 'EC'), ('하', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('은', 'JX'), ('하나님', 'NNP'), ('의', 'JKG'), ('값', 'NNG'), ('없', 'VA'), ('는', 'ETM'), ('은혜', 'NNG'), ('로', 'JKB'), ('정하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('저', 'NP'), ('가', 'JKS'), ('우리', 'NP'), ('의', 'JKG'), ('모든', 'MM'), ('죄', 'NNG'), ('를', 'JKO'), ('사유', 'NNP'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('그', 'MM'), ('앞', 'NNG'), ('에서', 'JKB'), ('우리', 'NP'), ('를', 'JKO'), ('옳', 'VA'), ('게', 'EC'), ('여기', 'VV'), ('어', 'EC'), ('받', 'VV'), ('으시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('니', 'EC'), ('이', 'NP'), ('는', 'JX'), ('다만', 'MAJ'), ('그리스도', 'NNP'), ('의', 'JKG'), ('의', 'NNG'), ('를', 'JKO'), ('우', 'NNP'), ('리', 'NNB'), ('에게', 'JKB'), ('돌리', 'VV'), ('어', 'EC'), ('주심', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('우리', 'NP'), ('는', 'JX'), ('오직', 'MAG'), ('믿음', 'NNP'), ('만', 'NNB'), ('으로', 'JKB'), ('받', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[34]:[('양자', 'NNG'), ('로', 'JKB'), ('삼', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('양자', 'NNG'), ('로', 'JKB'), ('삼', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('하나님', 'NNP'), ('의', 'JKG'), ('값', 'NNG'), ('없', 'VA'), ('는', 'ETM'), ('은혜', 'NNG'), ('로', 'JKB'), ('정하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('이', 'NP'), ('로써', 'JKB'), ('우리', 'NP'), ('를', 'JKO'), ('하나님', 'NNP'), ('의', 'JKG'), ('자녀', 'NNG'), ('의', 'JKG'), ('수효', 'NNG'), ('중', 'NNB'), ('에', 'JKB'), ('들', 'VV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('그', 'MM'), ('모든', 'MM'), ('특권', 'NNG'), ('을', 'JKO'), ('누리', 'VV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[35]:[('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('하나님', 'NNP'), ('의', 'JKG'), ('값', 'NNG'), ('없', 'VA'), ('는', 'ETM'), ('은혜', 'NNP'), ('의', 'JKG'), ('역사', 'NNG'), ('이', 'VCP'), ('시', 'EP'), ('ㄴ데', 'EC'), ('이', 'NP'), ('로써', 'JKB'), ('우리', 'NP'), ('가', 'JKS'), ('하나님', 'NNP'), ('의형', 'NNP'), ('상', 'NNG'), ('을', 'JKO'), ('좇', 'VV'), ('아', 'EC'), ('오', 'VV'), ('ㄴ', 'ETM'), ('사람', 'NNG'), ('이', 'JKS'), ('새롭', 'VA'), ('어', 'EC'), ('지', 'VX'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('얻', 'VV'), ('고', 'EC'), ('점점', 'MAG'), ('죄', 'NNG'), ('에', 'JKB'), ('대하', 'VV'), ('아서', 'EC'), ('는', 'JX'), ('능히', 'MAG'), ('죽', 'VV'), ('고', 'EC'), (',', 'SP'), ('의', 'NNG'), ('에', 'JKB'), ('대하', 'VV'), ('아', 'EC'), ('서', 'VV'), ('는', 'ETM'), ('능히', 'MAG'), ('살', 'VV'), ('게', 'EC'), ('되', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[36]:[('금', 'NNG'), ('생', 'XSN'), ('에서', 'JKB'), ('의롭', 'VA'), ('다', 'EC'), ('하심', 'NNG'), ('과', 'JC'), ('양자', 'NNG'), ('로', 'JKB'), ('삼', 'VV'), ('으시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('하심', 'NNG'), ('에서', 'JKB'), ('함께', 'MAG'), ('받', 'VV'), ('는', 'ETM'), ('유익', 'NNG'), ('과', 'JC'), ('여기', 'NP'), ('서', 'JKB'), ('나오', 'VV'), ('는', 'ETM'), ('유익', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('금', 'NNG'), ('생', 'XSN'), ('에서', 'JKB'), ('의롭', 'VA'), ('다', 'EC'), ('하심', 'NNG'), ('과', 'JC'), ('양자', 'NNG'), ('로', 'JKB'), ('삼', 'VV'), ('으시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('하심', 'NNG'), ('에서', 'JKB'), ('함께', 'MAG'), ('받', 'VV'), ('는', 'ETM'), ('유익', 'NNG'), ('과', 'JC'), ('여기', 'NP'), ('서', 'JKB'), ('나오', 'VV'), ('는', 'ETM'), ('유익', 'NNG'), ('은', 'JX'), ('하나님', 'NNP'), ('의', 'JKG'), ('사랑', 'NNG'), ('을', 'JKO'), ('확실히', 'MAG'), ('알', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('양심', 'NNP'), ('의', 'JKG'), ('화평', 'NNP'), ('한', 'NNP'), ('것', 'NNB'), ('과', 'JKB'), ('성령', 'NNP'), ('안', 'NNG'), ('에서', 'JKB'), ('얻', 'VV'), ('는', 'ETM'), ('쾌락', 'NNG'), ('과', 'JC'), ('은혜', 'NNP'), ('의', 'JKG'), ('증가', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('끝', 'NNG'), ('까지', 'JX'), ('굳', 'VA'), ('게', 'EC'), ('참', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[37]:[('신자', 'NNG'), ('가', 'JKS'), ('죽', 'VV'), ('을', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('그리스도', 'NNP'), ('에게서', 'JKB'), ('무슨', 'MM'), ('유익', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('신자', 'NNG'), ('가', 'JKS'), ('죽', 'VV'), ('을', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('그', 'MM'), ('영혼', 'NNG'), ('이', 'JKS'), ('완전히', 'MAG'), ('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('되', 'VV'), ('어', 'EC'), ('즉시', 'MAG'), ('영광', 'NNP'), ('중', 'NNB'), ('에', 'JKB'), ('들어가', 'VV'), ('고', 'EC'), ('그', 'MM'), ('몸', 'NNG'), ('은', 'JX'), ('여전히', 'MAG'), ('그리스도', 'NNP'), ('께', 'JKB'), ('연합', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('부활', 'NNP'), ('활', 'NNG'), ('때', 'NNG'), ('까지', 'JX'), ('무덤', 'NNG'), ('에서', 'JKB'), ('쉬', 'VV'), ('ㄴ다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[38]:[('신자', 'NNG'), ('가', 'JKS'), ('부활', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('그리스도', 'NNP'), ('에게서', 'JKB'), ('무슨', 'MM'), ('유익', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('신자', 'NNG'), ('가', 'JKS'), ('부활', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('영광', 'NNP'), ('중', 'NNB'), ('에', 'JKB'), ('다시', 'MAG'), ('살아남', 'VV'), ('을', 'ETM'), ('입', 'VV'), ('어', 'EC'), ('심판', 'NNP'), ('날', 'NNG'), ('에', 'JKB'), ('밝히', 'MAG'), ('안다', 'NNP'), ('하심', 'NNG'), ('과', 'JC'), ('죄', 'NNG'), ('없', 'VA'), ('다', 'EC'), ('하심', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('고', 'EC'), ('완전히', 'MAG'), ('복', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('아', 'EC'), ('영원', 'NNG'), ('하', 'XSV'), ('도록', 'EC'), ('하나님', 'NNG'), ('을', 'JKO'), ('흡족', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('즐거워하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# Reading documents:  60%|████████████████████████████████████▍                        | 64/107 [00:00<00:00, 204.19it/s]
# ================================================================================
# 질문[39]:[('하나님', 'NNP'), ('께서', 'JKS'), ('사람', 'NNG'), ('에게', 'JKB'), ('요구', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('본분', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('께서', 'JKS'), ('사람', 'NNG'), ('에게', 'JKB'), ('요구', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('는', 'ETM'), ('본분', 'NNG'), ('은', 'JX'), ('그', 'MM'), ('나타내', 'VV'), ('어', 'EC'), ('보이', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('뜻', 'NNG'), ('을', 'JKO'), ('복종', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[40]:[('하나님', 'NNP'), ('께서', 'JKS'), ('자기', 'NP'), ('에게', 'JKB'), ('복종', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('규칙', 'NNG'), ('으로', 'JKB'), ('사람', 'NNG'), ('에게', 'JKB'), ('처음', 'NNG'), ('나타내', 'VV'), ('어', 'EC'), ('보이', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('께서', 'JKS'), ('자기', 'NP'), ('에게', 'JKB'), ('복종', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('규칙', 'NNG'), ('으로', 'JKB'), ('사람', 'NNG'), ('에게', 'JKB'), ('처음', 'NNG'), ('나타내', 'VV'), ('어', 'EC'), ('보이', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('도덕', 'NNG'), ('의', 'JKG'), ('법칙', 'NNG'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[41]:[('이', 'MM'), ('도덕', 'NNG'), ('의', 'JKG'), ('법칙', 'NNG'), ('이', 'JKS'), ('어디', 'NP'), ('에', 'JKB'), ('간략히', 'MAG'), ('포함', 'NNG'), ('되', 'XSV'), ('었', 'EP'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('이', 'MM'), ('도덕', 'NNG'), ('의', 'JKG'), ('법칙', 'NNG'), ('은', 'JX'), ('십계명', 'NNP'), ('에', 'JKB'), ('간략히', 'MAG'), ('포함', 'NNG'), ('되', 'XSV'), ('었', 'EP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[42]:[('십계명', 'NNP'), ('의', 'JKG'), ('대', 'XPN'), ('강령', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('십계명', 'NNP'), ('의', 'JKG'), ('대', 'XPN'), ('강령', 'NNG'), ('은', 'JX'), ('우리', 'NP'), ('의', 'JKG'), ('마음', 'NNG'), ('을', 'JKO'), ('다', 'MAG'), ('하', 'XSV'), ('고', 'EC'), ('성품', 'NNP'), ('을', 'JKO'), ('다', 'MAG'), ('하', 'XSV'), ('고', 'EC'), ('뜻', 'NNG'), ('을', 'JKO'), ('다', 'MAG'), ('하', 'XSV'), ('고', 'EC'), ('힘', 'NNG'), ('을', 'JKO'), ('다', 'MAG'), ('하', 'XSV'), ('아', 'EC'), ('주', 'MM'), ('우리', 'NP'), ('하나님', 'NNG'), ('을', 'JKO'), ('사랑', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('또', 'MAJ'), ('이웃', 'NNG'), ('사랑', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('를', 'JKO'), ('자기', 'NP'), ('몸', 'NNG'), ('과', 'JC'), ('같이', 'MAG'), ('하', 'VV'), ('라', 'EC'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[43]:[('십계명', 'NNP'), ('의', 'JKG'), ('서문', 'NNP'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('십계명', 'NNP'), ('의', 'JKG'), ('서문', 'NNP'), ('은', 'JX'), ('이러', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('말', 'NNG'), ('이', 'VCP'), ('니', 'EC'), ('곧', 'MAG'), ('나', 'NP'), ('는', 'JX'), ('너희', 'NP'), ('하나님', 'NNP'), ('이', 'NNP'), ('시니', 'NNP'), ('너', 'NP'), ('를', 'JKO'), ('종', 'NNG'), ('되', 'XSV'), ('었', 'EP'), ('던', 'ETM'), ('애', 'NNG'), ('굽', 'NNG'), ('땅', 'NNG'), ('에서', 'JKB'), ('나오', 'VV'), ('게', 'EC'), ('한', 'MM'), ('자로', 'NNP'), ('다', 'JX'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[44]:[('십계명', 'NNP'), ('의', 'JKG'), ('서문', 'NNP'), ('이', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('교훈', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('십계명', 'NNP'), ('의', 'JKG'), ('서문', 'NNP'), ('이', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('교훈', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('하나님', 'NNP'), ('께서', 'JKS'), ('주도', 'NNG'), ('되', 'XSV'), ('시', 'EP'), ('고', 'EC'), (',', 'SP'), ('우리', 'NP'), ('하나님', 'NNP'), ('도', 'JX'), ('되', 'VV'), ('시', 'EP'), ('고', 'EC'), ('또', 'MAJ'), ('우리', 'NP'), ('의', 'JKG'), ('구속자', 'NNG'), ('도', 'JX'), ('되', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('고로', 'MAG'), ('우리', 'NP'), ('가', 'JKS'), ('마땅히', 'MAG'), ('그', 'NP'), ('의', 'JKG'), ('계명', 'NNP'), ('을', 'JKO'), ('지키', 'VV'), ('어야', 'EC'), ('하', 'VV'), ('겠', 'EP'), ('다', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[45]:[('제일', 'NNG'), ('계명', 'NNP'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제일', 'NNG'), ('계명', 'NNP'), ('은', 'JX'), ('나', 'NP'), ('외', 'NNB'), ('에', 'JKB'), ('다른', 'MM'), ('신', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('지', 'EC'), ('말라', 'NNP'), ('하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[46]:[('제일', 'NNG'), ('계명', 'NNP'), ('이', 'JKS'), ('명', 'NNB'), ('하', 'XSA'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제일', 'NNG'), ('계명', 'NNP'), ('이', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('명', 'NNB'), ('하', 'XSA'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('하나님', 'NNP'), ('은', 'JX'), ('유일한', 'NNP'), ('참', 'MAG'), ('신이', 'NNG'), ('되', 'XSV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('과', 'JKB'), ('우리', 'NP'), ('의', 'JKG'), ('하나님', 'NNP'), ('이', 'JKS'), ('되', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('알', 'VV'), ('고', 'EC'), ('승인', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('그대로', 'MAG'), ('긍게', 'NA'), ('경배', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('영화', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('라', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[47]:[('제일', 'NNG'), ('계명', 'NNP'), ('이', 'JKS'), ('금하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제', 'XPN'), ('일', 'NNB'), ('계명', 'NNP'), ('이', 'JKS'), ('금하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('참', 'MAG'), ('신', 'NNG'), ('을', 'JKO'), ('하나님', 'NNP'), ('으로', 'JKB'), ('알', 'VV'), ('지', 'EC'), ('아니하', 'VX'), ('거나', 'EC'), ('우리', 'NP'), ('의', 'JKG'), ('하나님', 'NNP'), ('으로', 'JKB'), ('경배', 'NNG'), ('하', 'XSV'), ('지', 'EC'), ('않', 'VX'), ('고', 'EC'), ('영화', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('도', 'JX'), ('하', 'VV'), ('지', 'EC'), ('아니하', 'VX'), ('는', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('그', 'NP'), ('에게', 'JKB'), ('만', 'JX'), ('드리', 'VV'), ('기', 'ETN'), ('에', 'JKB'), ('합당', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('경배', 'NNG'), ('와', 'JC'), ('영화', 'NNG'), ('를', 'JKO'), ('다른', 'MM'), ('이', 'NP'), ('에게', 'JKB'), ('드리', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[48]:[('제', 'XPN'), ('일', 'NNB'), ('계명', 'NNP'), ('중', 'NNB'), ('에', 'JKB'), ('나', 'NP'), ('외', 'NNB'), ('에', 'JKB'), ('라', 'NNG'), ('한', 'MM'), ('말씀', 'NNG'), ('이', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('특별히', 'MAG'), ('교훈', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제', 'XPN'), ('일', 'NNB'), ('계명', 'NNP'), ('중', 'NNB'), ('에', 'JKB'), ('나', 'NP'), ('외', 'NNB'), ('에', 'JKB'), ('이', 'VCP'), ('라', 'EC'), ('한', 'MM'), ('말씀', 'NNG'), ('이', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('특별히', 'MAG'), ('교훈', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('만물', 'NNG'), ('을', 'JKO'), ('보', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('하나님', 'NNP'), ('이', 'JKS'), ('아무', 'MM'), ('다른', 'MM'), ('신', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('는', 'ETM'), ('죄', 'NNG'), ('를', 'JKO'), ('내리', 'VV'), ('어다', 'EC'), ('보', 'VV'), ('시', 'EP'), ('고', 'EC'), ('분하', 'VA'), ('게', 'EC'), ('여기', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[49]:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('은', 'JX'), ('우상', 'NNG'), ('을', 'JKO'), ('만들', 'VV'), ('지', 'EC'), ('말', 'NNG'), ('지니', 'NNP'), ('위', 'NNG'), ('로', 'JKB'), ('하늘', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이나', 'JX'), ('아래', 'NNG'), ('로', 'JKB'), ('땅', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이나', 'JX'), ('땅', 'NNG'), ('아래', 'NNG'), ('물속', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('의', 'JKG'), ('무슨', 'MM'), ('형상', 'NNG'), ('이', 'VCP'), ('든지', 'EC'), ('만들', 'VV'), ('지', 'EC'), ('말', 'VX'), ('고', 'EC'), ('절', 'NNG'), ('하', 'XSV'), ('지', 'EC'), ('말', 'VX'), ('고', 'EC'), ('섬기', 'VV'), ('지', 'EC'), ('말', 'VX'), ('라', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[50]:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('이', 'JKS'), ('명', 'NNB'), ('하', 'XSA'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('이', 'JKS'), ('명', 'NNB'), ('하', 'XSA'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('하나님', 'NNP'), ('이', 'JKS'), ('그', 'MM'), ('말씀', 'NNG'), ('중', 'NNB'), ('에', 'JKB'), ('정하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('종교', 'NNG'), ('상', 'XSN'), ('모든', 'MM'), ('예배', 'NNP'), ('와', 'JC'), ('규례', 'NNP'), ('를', 'JKO'), ('받', 'VV'), ('아', 'EC'), ('순종', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('깨끗', 'XR'), ('하', 'XSA'), ('고', 'EC'), ('완전', 'NNG'), ('하', 'XSV'), ('게', 'EC'), ('지키', 'VV'), ('라', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[51]:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('이', 'JKS'), ('금하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('이', 'JKS'), ('금하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('우상', 'NNP'), ('으로', 'JKB'), ('하나님', 'NNG'), ('을', 'JKO'), ('경배', 'NNG'), ('하', 'XSV'), ('거나', 'EC'), (',', 'SP'), ('하나님', 'NNP'), ('의', 'JKG'), ('말씀', 'NNG'), ('에', 'JKB'), ('정하', 'VV'), ('지', 'EC'), ('아니하', 'VX'), ('ㄴ', 'ETM'), ('어떤', 'MM'), ('다른', 'MM'), ('방법', 'NNG'), ('으로', 'JKB'), ('경배', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[52]:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('이', 'JKS'), ('지키', 'VV'), ('라', 'EC'), ('한', 'MM'), ('이유', 'NNG'), ('가', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('제', 'XPN'), ('이', 'MM'), ('계명', 'NNP'), ('에', 'JKB'), ('지키', 'VV'), ('라', 'EC'), ('한', 'MM'), ('이유', 'NNG'), ('는', 'JX'), ('하나님', 'NNP'), ('이', 'JKS'), ('우리', 'NP'), ('의', 'JKG'), ('주재', 'NNG'), ('가', 'JKS'), ('되', 'VV'), ('시', 'EP'), ('며', 'EC'), ('우리', 'NP'), ('의', 'JKG'), ('소유자', 'NNG'), ('가', 'JKS'), ('되', 'VV'), ('시', 'EP'), ('며', 'EC'), ('홀로', 'MAG'), ('자기', 'NP'), ('에게', 'JKB'), ('만', 'JX'), ('경배', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('을', 'JKO'), ('바라', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[53]:[('제', 'XPN'), ('삼', 'NR'), ('계명', 'NNP'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# ...
# ================================================================================
# 질문[93]:[('신약', 'NNG'), ('의', 'JKG'), ('성례가', 'NA'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('신약', 'NNG'), ('의', 'JKG'), ('성례는', 'NA'), ('세례', 'NNP'), ('와', 'JC'), ('성찬', 'NNP'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[94]:[('세례', 'NNP'), ('가', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('세례', 'NNP'), ('는', 'JX'), ('물', 'NNG'), ('을', 'JKO'), ('가지', 'VV'), ('고', 'EC'), ('성부', 'NNP'), ('와', 'JC'), ('성자', 'NNP'), ('와', 'JC'), ('성령', 'NNP'), ('의', 'JKG'), ('이름', 'NNG'), ('으로', 'JKB'), ('씻', 'VV'), ('는', 'ETM'), ('성례인데', 'NA'), ('우리', 'NP'), ('가', 'JKS'), ('그리스도', 'NNP'), ('에게', 'JKB'), ('접합', 'NNP')]
# ================================================================================
# 질문[95]:[('세례', 'NNP'), ('는', 'JX'), ('어떠', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('사람', 'NNG'), ('에게', 'JKB'), ('베풀', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('세례', 'NNP'), ('는', 'JX'), ('불', 'XPN'), ('신자', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('그리스도', 'NNP'), ('를', 'JKO'), ('믿', 'VV'), ('고', 'EC'), ('고백', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('그', 'NP'), ('에게', 'JKB'), ('복종', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('데', 'NNB'), ('까지', 'JX'), ('이르', 'VV'), ('어야', 'EC'), ('베풀', 'VV'), ('ㄹ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('요', 'EC'), (',', 'SP'), ('또', 'MAJ'), ('입교', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('자', 'NNB'), ('의', 'JKG'), ('자녀', 'NNG'), ('에게', 'JKB'), ('베풀', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[96]:[('주의', 'NNG'), ('성찬', 'NNP'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('주의', 'NNG'), ('성찬', 'NNP'), ('은', 'JX'), ('곧', 'MAG'), ('성례이니', 'NA'), ('그리스도', 'NNP'), ('의', 'JKG'), ('정하', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('대로', 'NNB'), ('떡', 'NNG'), ('과', 'JC'), ('포도', 'NNP'), ('즙', 'NNG'), ('을', 'JKO'), ('주', 'VX'), ('며', 'EC'), ('받', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('으로', 'JKB'), ('그', 'MM'), ('죽', 'VV'), ('으시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('나타내', 'VV'), ('ㅁ', 'ETN'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[97]:[('주의', 'NNG'), ('성찬', 'NNP'), ('에', 'JKB'), ('합당', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('참여', 'NNG'), ('하', 'XSV'), ('려면', 'EC'), ('어떻', 'VA'), ('게', 'EC'), ('하', 'VV'), ('아야', 'EC'), ('하', 'VX'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주의', 'NNG'), ('성찬', 'NNP'), ('에', 'JKB'), ('합당', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('참여', 'NNG'), ('하', 'XSV'), ('려면', 'EC'), ('마땅히', 'MAG'), ('주님', 'NNG'), ('의', 'JKG'), ('몸', 'NNG'), ('을', 'JKO'), ('분별', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('줄', 'NNB'), ('알', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('주님', 'NNG'), ('으로써', 'JKB'), ('양식', 'NNG'), ('을', 'JKO'), ('삼', 'VV'), ('는', 'ETM'), ('믿음', 'NNG'), ('과', 'JC'), ('회개', 'NNP'), ('와', 'JC'), ('사랑', 'NNG'), ('과', 'JC'), ('서로', 'MAG'), ('순종', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('에', 'JKB'), ('대하', 'VV'), ('아', 'EC'), ('스스로', 'MAG'), ('살피', 'VV'), ('ㄹ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('니', 'EC'), ('합당', 'XR'), ('하', 'XSA'), ('지', 'EC'), ('않', 'VX'), ('게', 'EC'), ('참여', 'NNG'), ('하', 'XSV'), ('면', 'EC'), ('두렵', 'VA'), ('건대', 'EC'), ('먹', 'VV'), ('고', 'EC'), ('마시', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('정죄', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('자청', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('이', 'JKS'), ('되', 'VV'), ('ㄹ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[98]:[('기도', 'NNG'), ('가', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('기도', 'NNG'), ('는', 'JX'), ('그리스도', 'NNP'), ('의', 'JKG'), ('이름', 'NNG'), ('으로', 'JKB'), ('우리', 'NP'), ('의', 'JKG'), ('기원', 'NNG'), ('을', 'JKO'), ('하나님', 'NNP'), ('께', 'JKB'), ('고하', 'VV'), ('고', 'EC'), ('그', 'NP'), ('의', 'JKG'), ('뜻', 'NNG'), ('에', 'JKB'), ('합당', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('을', 'JKO'), ('간구', 'XR'), ('하', 'XSA'), ('아', 'EC'), ('죄', 'NNG'), ('를', 'JKO'), ('자', 'NNG'), ('복', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('그', 'NP'), ('의', 'JKG'), ('자비', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('모든', 'MM'), ('은혜', 'NNG'), ('를', 'JKO'), ('감사', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[99]:[('하나님', 'NNP'), ('께서', 'JKS'), ('우리', 'NP'), ('의', 'JKG'), ('기도', 'NNG'), ('를', 'JKO'), ('지시', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('려고', 'EC'), ('주', 'VX'), ('시', 'EP'), ('ㄴ', 'ETM'), ('법칙', 'NNG'), ('이', 'JKS'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가', 'EF'), ('?', 'SF')]
# 답변:[('하나님', 'NNP'), ('의', 'JKG'), ('모든', 'MM'), ('말씀', 'NNG'), ('이', 'JKS'), ('우리', 'NP'), ('의', 'JKG'), ('기도', 'NNG'), ('를', 'JKO'), ('지시', 'NNG'), ('하', 'XSV'), ('ㅁ', 'ETN'), ('에', 'JKB'), ('유용', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이나', 'JX'), ('특별히', 'MAG'), ('지시', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('법칙', 'NNG'), ('은', 'JX'), ('그리스도', 'NNP'), ('께서', 'JKS'), ('그', 'MM'), ('제자', 'NNG'), ('들', 'XSN'), ('에게', 'JKB'), ('가르치', 'VV'), ('시', 'EP'), ('ㄴ', 'ETM'), ('기도', 'NNG'), ('이', 'VCP'), ('니', 'EC'), ('보통', 'NNG'), ('으로', 'JKB'), ('주기', 'NNP'), ('도문', 'NNP'), ('이', 'VCP'), ('라', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[100]:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('첫', 'NR'), ('말씀', 'NNG'), ('이', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('무엇', 'NP'), ('을', 'JKO'), ('교훈', 'NNG'), ('하', 'XSV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('첫', 'NR'), ('말씀', 'NNG'), ('은', 'JX'), ('곧', 'MAG'), ('하늘', 'NNG'), ('에', 'JKB'), ('계시', 'VV'), ('ㄴ', 'ETM'), ('우리 아버지', 'NNP'), ('이', 'VCP'), ('어', 'EC'), ('한', 'MM'), ('것', 'NNB'), ('이', 'VCP'), ('니', 'EC'), ('이', 'NP'), ('는', 'JX'), ('자식', 'NNG'), ('이', 'JKS'), ('그', 'MM'), ('능하', 'VA'), ('고', 'EC'), ('보호', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('기', 'ETN'), ('를', 'JKO'), ('예비', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('아버지', 'NNG'), ('에게', 'JKB'), ('가', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('과', 'JKB'), ('같이', 'MAG'), ('우리', 'NP'), ('가', 'JKS'), ('모든', 'MM'), ('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('공경', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('뜻', 'NNG'), ('과', 'JC'), ('든든', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('마음', 'NNG'), ('으로', 'JKB'), ('하나님', 'NNP'), ('께', 'JKB'), ('가까이', 'MAG'), ('오', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('을', 'JKO'), ('가르치', 'VV'), ('고', 'EC'), ('또', 'MAJ'), ('우리', 'NP'), ('가', 'JKS'), ('다른', 'MM'), ('사람', 'NNG'), ('으로', 'JKB'), ('더불', 'VV'), ('어', 'EC'), ('기도', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('다른', 'MM'), ('사람', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('아', 'EC'), ('기도', 'NNG'), ('하', 'XSV'), ('라', 'EC'), ('가르치', 'VV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[101]:[('첫', 'NR'), ('기도', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('가', 'JKS'), ('무엇', 'NP'), ('을', 'JKO'), ('구하', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('첫', 'NR'), ('기도', 'NNG'), ('는', 'JX'), ('곧', 'MAG'), ('이름', 'NNG'), ('을', 'JKO'), ('거룩', 'XR'), ('하', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('옵', 'EP'), ('소서', 'EC'), ('함', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('하나님', 'NNP'), ('께서', 'JKS'), ('자기', 'NP'), ('를', 'JKO'), ('나타내', 'VV'), ('시', 'EP'), ('는', 'ETM'), ('모든', 'MM'), ('일', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('와', 'JKB'), ('다른', 'MM'), ('이', 'NP'), ('로', 'JKB'), ('하여금', 'MAG'), ('능히', 'MAG'), ('그', 'NP'), ('를', 'JKO'), ('영화', 'NNG'), ('롭', 'XSA'), ('게', 'EC'), ('하', 'VV'), ('고', 'EC'), ('또', 'MAJ'), ('모든', 'MM'), ('것', 'NNB'), ('을', 'JKO'), ('처리', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('하나님', 'NNP'), ('의', 'JKG'), ('영광', 'NNG'), ('에', 'JKB'), ('이르', 'VV'), ('게', 'EC'), ('하', 'VV'), ('옵', 'EP'), ('시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('구하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# Reading documents: 100%|█████████████████████████████████████████████████████████████| 107/107 [00:01<00:00, 60.65it/s]
# 질문[102]:[('둘째', 'NR'), ('기도', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('가', 'JKS'), ('무엇', 'NP'), ('을', 'JKO'), ('구하', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('둘째', 'NR'), ('기도', 'NNG'), ('에', 'JKB'), ('나라', 'NNG'), ('이', 'NNP'), ('임하', 'VV'), ('옵', 'EP'), ('소서', 'EC'), ('하', 'VV'), ('ㅁ', 'ETN'), ('은', 'JX'), ('사단', 'NNP'), ('의', 'JKG'), ('나라', 'NNG'), ('가', 'JKS'), ('멸망', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('은혜', 'NNP'), ('의', 'JKG'), ('나라', 'NNG'), ('가', 'JKS'), ('흥', 'NNG'), ('왕', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('우리', 'NP'), ('와', 'JKB'), ('다른', 'MM'), ('사람', 'NNG'), ('으로', 'JKB'), ('하여금', 'MAG'), ('그리로', 'MAG'), ('들어가', 'VV'), ('아', 'EC'), ('항상', 'MAG'), ('있', 'VV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('고', 'EC'), ('또', 'MAJ'), ('영광', 'NNP'), ('의', 'JKG'), ('나라', 'NNG'), ('가', 'JKS'), ('속히', 'MAG'), ('임하', 'VV'), ('게', 'EC'), ('하', 'VV'), ('옵', 'EP'), ('시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('구하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[103]:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('셋째', 'NR'), ('기도', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('가', 'JKS'), ('무엇', 'NP'), ('을', 'JKO'), ('구하', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('셋째', 'NR'), ('기도', 'NNG'), ('는', 'JX'), ('뜻', 'NNG'), ('이', 'JKS'), ('하늘', 'NNG'), ('에서', 'JKB'), ('이루', 'VV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('같이', 'JKB'), ('땅', 'NNG'), ('에서', 'JKB'), ('도', 'JX'), ('이루어지', 'VV'), ('이', 'EC'), ('다', 'JX'), ('함', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('하나님', 'NNP'), ('께서', 'JKS'), ('은혜', 'NNG'), ('를', 'JKO'), ('베풀', 'VV'), ('시', 'EP'), ('사', 'EC'), ('우리', 'NP'), ('로', 'JKB'), ('하여금', 'MAG'), ('능히', 'MAG'), ('감', 'VV'), ('시', 'EP'), ('ㅁ', 'ETN')]
# ================================================================================
# 질문[104]:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('넷째', 'NR'), ('기도', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('가', 'JKS'), ('무엇', 'NP'), ('을', 'JKO'), ('구하', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('넷째', 'NR'), ('기도', 'NNG'), ('는', 'JX'), ('곧', 'MAG'), ('오늘날', 'NNG'), ('우리', 'NP'), ('에게', 'JKB'), ('일용', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('양식', 'NNG'), ('을', 'JKO'), ('주', 'VX'), ('옵', 'EP'), ('소서', 'EC'), ('함', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('하나님', 'NNP'), ('의', 'JKG'), ('은사', 'NNG'), ('로써', 'JKB'), ('이', 'MM'), ('세상', 'NNG'), ('에서', 'JKB'), ('여러', 'MM'), ('가지', 'NNB'), ('좋', 'VA'), ('은', 'ETM'), ('것', 'NNB'), ('중', 'NNB'), ('에', 'JKB'), ('만족', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('부분', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('며', 'EC'), ('아울러', 'MAG'), ('그', 'NP'), ('의', 'JKG'), ('축복', 'NNG'), ('을', 'JKO'), ('누리', 'VV'), ('게', 'EC'), ('하', 'VV'), ('옵', 'EP'), ('시', 'EP'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('구하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[105]:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('다섯째', 'NR'), ('기도', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('가', 'JKS'), ('무엇', 'NP'), ('을', 'JKO'), ('구하', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('다섯째', 'NR'), ('기도', 'NNG'), ('는', 'JX'), ('곧', 'MAG'), ('우리', 'NP'), ('가', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('죄', 'NNG'), ('지', 'VX'), ('은', 'ETM'), ('자', 'NNB'), ('를', 'JKO'), ('사', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('주', 'VX'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('같이', 'JKB'), ('우리', 'NP'), ('의', 'JKG'), ('죄', 'NNG'), ('를', 'JKO'), ('사', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('주', 'VX'), ('옵', 'EP'), ('소서', 'EC'), ('함', 'NNG'), ('이', 'VCP'), ('니', 'EC'), ('하나님', 'NNP'), ('께서', 'JKS'), ('그리스도', 'NNP'), ('를', 'JKO'), ('인하', 'VV'), ('아', 'EC'), ('우리', 'NP'), ('의', 'JKG'), ('모든', 'MM'), ('죄', 'NNG'), ('를', 'JKO'), ('값', 'NNG'), ('없이', 'MAG'), ('사', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('주', 'VX'), ('옵', 'EP'), ('소서', 'EC'), ('함', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('우리', 'NP'), ('가', 'JKS'), ('그', 'NP'), ('의', 'JKG'), ('은혜', 'NNG'), ('를', 'JKO'), ('힘입', 'VV'), ('어', 'EC'), ('능히', 'MAG'), ('진심', 'NNP'), ('으로', 'JKB'), ('다른', 'MM'), ('이', 'NP'), ('의', 'JKG'), ('죄', 'NNG'), ('를', 'JKO'), ('사', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('은즉', 'EC'), ('더욱', 'MAG'), ('용감히', 'MAG'), ('간구', 'XR'), ('하', 'XSA'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[106]:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('여섯째', 'NR'), ('기도', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('가', 'JKS'), ('무엇', 'NP'), ('을', 'JKO'), ('구하', 'VV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('여섯째', 'NR'), ('기도', 'NNG'), ('는', 'JX'), ('곧', 'MAG'), ('우리', 'NP'), ('를', 'JKO'), ('시험', 'NNG'), ('에', 'JKB'), ('들', 'VV'), ('지', 'EC'), ('말', 'VX'), ('게', 'EC'), ('하', 'VV'), ('옵', 'EP'), ('시', 'EP'), ('고', 'EC'), ('다만', 'MAJ'), ('악', 'NNG'), ('에서', 'JKB'), ('구원', 'NNG'), ('하', 'XSV'), ('옵', 'EP'), ('소서', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('니', 'EC'), ('이', 'NP'), ('는', 'JX'), ('하나님', 'NNP'), ('이', 'JKS'), ('혹', 'MAG'), ('우리', 'NP'), ('를', 'JKO'), ('시험', 'NNG'), ('에', 'JKB'), ('들', 'VV'), ('지', 'EC'), ('아니하', 'VX'), ('게', 'EC'), ('하', 'VV'), ('시', 'EP'), ('거나', 'EC'), ('시험', 'NNG'), ('을', 'JKO'), ('당하', 'VV'), ('ㄹ', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('우리', 'NP'), ('를', 'JKO'), ('보호', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('구원', 'NNG'), ('하', 'XSV'), ('옵', 'EP'), ('소서', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('기도', 'NNG'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
# 질문[107]:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('마지막', 'NNG'), ('구절', 'NNG'), ('이', 'JKS'), ('우리', 'NP'), ('에게', 'JKB'), ('무엇', 'NP'), ('을', 'JKO'), ('교훈', 'NNG'), ('하', 'XSV'), ('는가', 'EF'), ('?', 'SF')]
# 답변:[('주기', 'NNP'), ('도문', 'NNP'), ('의', 'JKG'), ('마지막', 'NNG'), ('말씀', 'NNG'), ('은', 'JX'), ('곧', 'MAG'), ('대개', 'MAG'), ('나라', 'NNG'), ('와', 'JC'), ('권세', 'NNG'), ('와', 'JC'), ('영광', 'NNP'), ('이', 'JKS'), ('아버지', 'NNG'), ('께', 'JKB'), ('영원히', 'MAG'), ('있', 'VV'), ('사', 'VV'), ('옵', 'EP'), ('나이다', 'EC'), ('아멘', 'NNP'), ('하', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('니', 'EC'), ('이', 'NP'), ('는', 'JX'), ('우리', 'NP'), ('로', 'JKB'), ('하여금', 'MAG'), ('기도', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('하나님', 'NNP'), ('만', 'JX'), ('믿', 'VV'), ('고', 'EC'), ('또', 'MAJ'), ('기도', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('때', 'NNG'), ('에', 'JKB'), ('그', 'NP'), ('를', 'JKO'), ('찬송', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('나라', 'NNG'), ('와', 'JC'), ('권세', 'NNG'), ('와', 'JC'), ('영광', 'NNP'), ('이', 'JKS'), ('아버지', 'NNG'), ('께', 'JKB'), ('있', 'VV'), ('다', 'EC'), ('하', 'VV'), ('라고', 'EC'), ('가르치', 'VV'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EF'), ('.', 'SF')]
# ================================================================================
