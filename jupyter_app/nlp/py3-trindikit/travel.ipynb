# %%
# -*- encoding: utf-8 -*-

#
# travel.py
#
# The author or authors of this code dedicate any and all 
# copyright interest in this code to the public domain.


from ibis import *
from cfg_grammar import *

preds0 = 'return', 'need-visa'

preds1 = {'price': 'int',
          'how': 'means',
          'dest_city': 'city',
          'depart_city': 'city',
          'depart_day': 'day',
          'class': 'flight_class',
          'return_day': 'day',
          }

means = 'plane', 'train'
cities = 'paris', 'london', 'berlin'
days = 'today', 'tomorrow'
classes = 'first', 'second'

sorts = {'means': means,
         'city': cities,
         'day': days,
         'flight_class': classes,
         }

domain = Domain(preds0, preds1, sorts)

domain.add_plan("?x.price(x)",
               [Findout("?x.how(x)"),
                Findout("?x.dest_city(x)"),
                Findout("?x.depart_city(x)"),
                Findout("?x.depart_day(x)"),
                Findout("?x.class(x)"),
                 Findout("?return()"),
                 If("?return()", 
                    [Findout("?x.return_day(x)")]),
                 ConsultDB("?x.price(x)")
                 ])


class TravelDB(Database):

    def __init__(self):
        self.entries = []

    def consultDB(self, question, context):
        depart_city = self.getContext(context, "depart_city")
        dest_city = self.getContext(context, "dest_city")
        day = self.getContext(context, "depart_day")
        entry = self.lookupEntry(depart_city, dest_city, day)
        price = entry['price']
        return Prop(Pred1("price"), Ind(price), True)

    def lookupEntry(self, depart_city, dest_city, day):
        for e in self.entries:
            if e['from'] == depart_city and e['to'] == dest_city and e['day'] == day:
                return e
        assert False

    def getContext(self, context, pred):
        for prop in context:
            if prop.pred.content == pred:
                return prop.ind.content
        assert False

    def addEntry(self, entry):
        self.entries.append(entry)

database = TravelDB()
database.addEntry({'price':'232', 'from':'berlin', 'to':'paris', 'day':'today'})
database.addEntry({'price':'345', 'from':'paris', 'to':'london', 'day':'today'})

class TravelGrammar(SimpleGenGrammar, CFG_Grammar):
    def generateMove(self, move):
        try:
            assert isinstance(move, Answer)
            prop = move.content
            assert isinstance(prop, Prop)
            assert prop.pred.content == "price"
            return "The price is " + str(prop.ind.content)
        except:
            return super(TravelGrammar, self).generateMove(move)

grammar = TravelGrammar()
grammar.loadGrammar("file:travel.fcfg")
grammar.addForm("Ask('?x.how(x)')", "How do you want to travel?")
grammar.addForm("Ask('?x.dest_city(x)')", "Where do you want to go?")
grammar.addForm("Ask('?x.depart_city(x)')", "From where are you leaving?")
grammar.addForm("Ask('?x.depart_day(x)')", "When do you want to leave?")
grammar.addForm("Ask('?x.return_day(x)')", "When do you want to return?")
grammar.addForm("Ask('?x.class(x)')", "First or second class?")
grammar.addForm("Ask('?return()')", "Do you want a return ticket?")

ibis = IBIS1(domain, database, grammar)




# Följande måste klaras av såsmåningom:
#
# contact_plan(change_contact_name, change, contact,
# 	     [],
# 	     [ findout(C^change_contact_new_name(C),
# 		       { type=text, default=change_contact_name, device=phone }),
# 	       dev_do(phone, 'ChangeContactName'),
# 	       forget(view_contact_name(_)),
# 	       forget(change_contact_name(_)),
# 	       if_then(change_contact_new_name(Name),
# 		       [ assume_shared(view_contact_name(Name)),
# 			 assume_shared(change_contact_name(Name)) ]),
# 	       forget(change_contact_new_name(_))
# 	     ]).
# postcond(change_contact_name, done('ChangeContactName')).
#
# OBS! if_then(..) binder en variabel Name som används i konsekvensen!
# Förslag:
#
#    If("change-contact-name(?x)", [assume_shared("view-contact-name(?x)"), ...])


######################################################################
# Running the dialogue system
######################################################################

if __name__=='__main__':
    ibis.run()
# Out:
# +------------------------ - -  -
# | INPUT:          <>
# | LATEST_SPEAKER: <>
# | LATEST_MOVES:   set()
# | NEXT_MOVES:     <[  <]
# | OUTPUT:         <>
# | PROGRAM_STATE:  <RUN>
# |
# | private:
# |     agenda: <[ 'Greet'() <]
# |     plan: <[  <]
# |     bel: set()
# | shared:
# |     com: set()
# |     qud: <{  <}
# |     lu:
# |         moves: set()
# +------------------------ - -  -
#
# ... move = 'Greet'()
# --> select_other
#
# --> generate
#
# S> Hello.
#
# --> output
#
# ... {'Greet'()}
# --> get_latest_moves
#
# ... move = 'Greet'()
# --> integrate_greet
#
# +------------------------ - -  -
# | INPUT:          <>
# | LATEST_SPEAKER: <SYS>
# | LATEST_MOVES:   {'Greet'()}
# | NEXT_MOVES:     <[  <]
# | OUTPUT:         <Hello.>
# | PROGRAM_STATE:  <RUN>
# |
# | private:
# |     agenda: <[  <]
# |     plan: <[  <]
# |     bel: set()
# | shared:
# |     com: set()
# |     qud: <{  <}
# |     lu:
# |         speaker: SYS
# |         moves: {'Greet'()}
# +------------------------ - -  -
#
# U> price
#
# --> input
#
# Did not understand: <price>
#
# --> interpret
#
# --> get_latest_moves
#
# +------------------------ - -  -
# | INPUT:          <price>
# | LATEST_SPEAKER: <USR>
# | LATEST_MOVES:   set()
# | NEXT_MOVES:     <[  <]
# | OUTPUT:         <Hello.>
# | PROGRAM_STATE:  <RUN>
# |
# | private:
# |     agenda: <[  <]
# |     plan: <[  <]
# |     bel: set()
# | shared:
# |     com: set()
# |     qud: <{  <}
# |     lu:
# |         speaker: USR
# |         moves: set()
# +------------------------ - -  -
#
# ... True
# --> select_icm_sem_neg
#
# --> generate
#
# S> I heard you say price. I don't understand.
#
# --> output
#
# ... {ICM(('per', 'pos', 'price')), ICM(('neg', 'sem', None))}
# --> get_latest_moves
#
# +------------------------ - -  -
# | INPUT:          <price>
# | LATEST_SPEAKER: <SYS>
# | LATEST_MOVES:   {ICM(('per', 'pos', 'price')), ICM(('neg', 'sem', None))}
# | NEXT_MOVES:     <[  <]
# | OUTPUT:         <I heard you say price. I don't understand.>
# | PROGRAM_STATE:  <RUN>
# |
# | private:
# |     agenda: <[  <]
# |     plan: <[  <]
# |     bel: set()
# | shared:
# |     com: set()
# |     qud: <{  <}
# |     lu:
# |         speaker: SYS
# |         moves: {ICM(('per', 'pos', 'price')), ICM(('neg', 'sem', None))}
# +------------------------ - -  -
#
# U> Ask("?x.price(x)")
#
# --> input
#
# --> interpret
#
# ... {Ask(WhQ(Pred1('price')))}
# --> get_latest_moves
#
# ... move = Ask('?x.price(x)')
# ... que = ?x.price(x)
# --> integrate_usr_ask
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-649df065b122> in <module>()
#     133
#     134 if __name__=='__main__':
# --> 135     ibis.run()
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\trindikit.py in run(self)
#     670         """
#     671         self.reset()
# --> 672         self.control()
#     673
#     674     def reset(self):
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\ibis.py in control(self)
#     234             self.input()
#     235             self.interpret()
# --> 236             self.update()
#     237             self.print_state()
#     238
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\ibis.py in update(self)
#     273         maybe(self.integrate)
#     274         maybe(self.downdate_qud)
# --> 275         maybe(self.load_plan)
#     276         repeat(self.exec_plan)
#     277
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\trindikit.py in maybe(*rules)
#     515     """
#     516     try:
# --> 517         return do(*rules)
#     518     except PreconditionFailure:
#     519         pass
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\trindikit.py in do(*rules)
#     500     for rule in rules:
#     501         try:
# --> 502             return rule(self) if self else rule()
#     503         except PreconditionFailure:
#     504             pass
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\trindikit.py in <lambda>(self)
#     541     precondition matches is executed, otherwise the group fails.
#     542     """
# --> 543     group = lambda self: do(self, *rules)
#     544     group.__name__ = '<' + '|'.join(rule.__name__ for rule in rules) + '>'
#     545     group.__doc__ = '\n'.join(
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\trindikit.py in do(*rules)
#     500     for rule in rules:
#     501         try:
# --> 502             return rule(self) if self else rule()
#     503         except PreconditionFailure:
#     504             pass
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\trindikit.py in rule(*args, **kw)
#     586                     "or %s(dm) where dm is a DialogueManager instance." % funcname
#     587             new_kw = dict((key, getattr(args[0], key, None)) for key in argkeys)
# --> 588         result = function(**new_kw)
#     589         print("-->", funcname)
#     590         print()
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\ibis_rules.py in find_plan(IS, DOMAIN)
#     170     in /private/plan, and pop the Respond move from /private/agenda.
#     171     """
# --> 172     @precondition
#     173     def V():
#     174         move = IS.private.agenda.top()
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\trindikit.py in precondition(test)
#     634             result = next(test)
#     635         elif hasattr(test, '__call__'):
# --> 636             result = next(test())
#     637         else:
#     638             raise SyntaxError("Precondition must be a generator or a generator "
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\ibis_rules.py in V()
#     177                            for prop in IS.private.bel)
#     178             if not resolved:
# --> 179                 plan = DOMAIN.get_plan(move.content)
#     180                 if plan:
#     181                     yield R(move=move, plan=plan)
#
# ~\textmining\python\text-mining-camp\note\arkwith\py3-trindikit\ibis.py in get_plan(self, question)
#     190         """
#     191         planstack = stack(PlanConstructor)
# --> 192         for construct in reversed(self.plans.get(question)):
#     193             planstack.push(construct)
#     194         return planstack
#
# TypeError: 'NoneType' object is not reversible
